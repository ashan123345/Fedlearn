# %% [markdown]
# olderversion

# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import sys
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("FraminghamClient")

# Client configuration
CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01  # FedProx hyperparameter (controls the proximal term strength)
}

# Model for Framingham Heart Study data
class HeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super(HeartDiseaseModel, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

# FedProx Loss Function
class FedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super(FedProxLoss, self).__init__()
        self.base_criterion = base_criterion
        self.mu = mu  # Proximal term coefficient
        
    def forward(self, y_pred, y_true, model_params, global_params):
        # Calculate the base loss (e.g., BCE loss)
        base_loss = self.base_criterion(y_pred, y_true)
        
        # Calculate the proximal term if global parameters are provided
        proximal_term = 0.0
        if global_params is not None:
            # Sum up the squared L2 norm of the difference between local and global model parameters
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
                
            # Add the weighted proximal term to the base loss
            loss = base_loss + (self.mu / 2) * proximal_term
            return loss
        
        # If no global parameters are provided, just return the base loss
        return base_loss

# Load and preprocess Framingham data
def load_data(data_path):
    """Load and preprocess Framingham Heart Study data"""
    try:
        # Read CSV data
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        
        # Check for missing values
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Found {missing_values} missing values, dropping rows with missing values")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing values: {df.shape}")
        
        # Ensure the target column exists
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' not found in dataset!")
            
        # Split features and target
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        
        # Show class distribution
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        
        # Standardize features
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        # Convert to tensors
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        
        # Create dataset and dataloader
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        
        logger.info(f"Created dataloader with {len(dataset)} samples and {X.shape[1]} features")
        return dataloader, X.shape[1]
    
    except Exception as e:
        logger.error(f"Error loading data: {str(e)}")
        raise

# Client class for Federated Learning with FedProx
class FraminghamClient(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.global_params = None  # Store global model parameters for FedProx
        logger.info(f"Initialized client with device: {device}")
        
    def get_parameters(self, config):
        """Get model parameters as a list of NumPy arrays"""
        # Using detach() to prevent gradient error
        return [val.detach().cpu().numpy() for val in self.model.parameters()]
    
    def set_parameters(self, parameters):
        """Set model parameters from a list of NumPy arrays"""
        # Convert to torch tensors
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        
        # Update model
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info("Parameters updated from server")
        
    def fit(self, parameters, config):
        """Train the model on local data with FedProx"""
        # Update model with server parameters
        self.set_parameters(parameters)
        
        # Train the model
        self.model.train()
        
        # Standard loss function
        criterion = nn.BCELoss()
        
        # FedProx loss function
        proximal_criterion = FedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        
        optimizer = torch.optim.Adam(
            self.model.parameters(), 
            lr=CLIENT_CONFIG["learning_rate"],
            weight_decay=CLIENT_CONFIG["weight_decay"]
        )
        
        # Metrics for tracking
        total_loss = 0.0
        total_samples = 0
        correct = 0
        
        # Train for multiple epochs
        for epoch in range(CLIENT_CONFIG["local_epochs"]):
            epoch_loss = 0.0
            epoch_samples = 0
            
            for batch_idx, (X, y) in enumerate(self.dataloader):
                # Move tensors to device
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                
                # Calculate loss with proximal term
                loss = proximal_criterion(
                    y_pred, 
                    y, 
                    self.model.parameters(),  # Current model parameters
                    self.global_params        # Global model parameters
                )
                
                # Backward pass
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                # Update metrics
                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
                
                # Log progress occasionally
                if batch_idx % 5 == 0:
                    logger.info(
                        f"Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - "
                        f"Batch {batch_idx}/{len(self.dataloader)} - "
                        f"Loss: {loss.item():.4f}"
                    )
            
            # Log epoch metrics
            logger.info(
                f"Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} completed - "
                f"Loss: {epoch_loss/epoch_samples:.4f}"
            )
        
        # Calculate final metrics
        avg_loss = total_loss / total_samples if total_samples > 0 else 0
        accuracy = correct / total_samples if total_samples > 0 else 0
        
        logger.info(f"Training completed - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        
        # Return updated model parameters and metrics
        return self.get_parameters({}), total_samples, {"loss": float(avg_loss), "accuracy": float(accuracy)}
    
    def evaluate(self, parameters, config):
        """Evaluate the model on local data"""
        # Update model with server parameters
        self.set_parameters(parameters)
        
        # Evaluate the model
        self.model.eval()
        criterion = nn.BCELoss()
        
        loss = 0.0
        total = 0
        correct = 0
        
        with torch.no_grad():
            for X, y in self.dataloader:
                # Move tensors to device
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                
                # Update metrics
                loss += batch_loss * X.size(0)
                total += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
        
        # Calculate final metrics
        avg_loss = loss / total if total > 0 else 0
        accuracy = correct / total if total > 0 else 0
        
        logger.info(f"Evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        
        # Return metrics
        return float(avg_loss), total, {"accuracy": float(accuracy)}

def start_client(client_id=0, server_address=None):
    """Initialize and start a client"""
    # Update server address if provided
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address
    
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")
    
    # Determine which data file to use based on client ID
    data_path = f"framingham_part{client_id+1}.csv"
    
    # Try alternative naming if file doesn't exist
    if not os.path.exists(data_path):
        alternative_path = f"framingham_part{client_id+1}.csv"
        if os.path.exists(alternative_path):
            data_path = alternative_path
        else:
            logger.error(f"Data file {data_path} not found")
            return
    
    # Load data
    dataloader, input_size = load_data(data_path)
    
    # Initialize model
    model = HeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size: {input_size}")
    
    # Create client
    client = FraminghamClient(model, dataloader, device)
    
    # Start client
    logger.info(f"Starting client {client_id} and connecting to {CLIENT_CONFIG['server_address']}")
    
    print(f"\n===== Framingham Heart Study FL Client {client_id} (FedProx) =====")
    print(f"Server:        {CLIENT_CONFIG['server_address']}")
    print(f"Data file:     {data_path}")
    print(f"Local epochs:  {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:    {CLIENT_CONFIG['batch_size']}")
    print(f"Proximal mu:   {CLIENT_CONFIG['proximal_mu']}")
    print(f"Device:        {device}")
    print("=================================================")
    print(f"\nConnecting to server...\n")
    
    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

# For Jupyter usage
if __name__ == "__main__":
    # Check if running in Jupyter
    if 'ipykernel' in sys.modules:
        print("Running in Jupyter/IPython environment")
        # Default to client ID 0, can be changed by user
        start_client(client_id=2)
    else:
        # For command line use
        import argparse
        parser = argparse.ArgumentParser(description="Framingham Heart Study FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID (0, 1, or 2)")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--mu", type=float, default=0.01, help="FedProx proximal term strength")
        
        args = parser.parse_args()
        
        if args.id not in [0, 1, 2]:
            logger.error("Client ID must be 0, 1, or 2")
        else:
            try:
                # Set FedProx hyperparameter
                CLIENT_CONFIG["proximal_mu"] = args.mu
                
                start_client(args.id, args.server)
            except Exception as e:
                logger.error(f"Client failed: {str(e)}")

# %% [markdown]
# test version clinet 1 cuurently running

# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("DP_SA_FraminghamClient")

CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01,

    # Differential Privacy parameters
    "dp_enabled": True,
    "dp_noise_multiplier": 1.0,
    "dp_max_grad_norm": 1.0,
    "dp_epsilon": 8.0,
    "dp_delta": 1e-5,

    # Secure Aggregation parameters
    "sa_enabled": True,
    "sa_noise_scale": 1e-3,

    # Additional security flags
    "smpc_enabled": False,
    "he_enabled": False,
}

class DifferentialPrivacyMechanism:
    def __init__(self, noise_multiplier, max_grad_norm, epsilon, delta):
        self.noise_multiplier = noise_multiplier
        self.max_grad_norm = max_grad_norm
        self.epsilon = epsilon
        self.delta = delta
        logger.info(f"DP initialized: ε={epsilon}, δ={delta}, noise_multiplier={noise_multiplier}")

    def clip_gradients(self, model):
        total_norm = 0.0
        for param in model.parameters():
            if param.grad is not None:
                param_norm = param.grad.data.norm(2)
                total_norm += param_norm.item() ** 2
        total_norm = total_norm ** 0.5

        clip_coef = self.max_grad_norm / (total_norm + 1e-6)
        if clip_coef < 1:
            for param in model.parameters():
                if param.grad is not None:
                    param.grad.data.mul_(clip_coef)
        return total_norm

    def add_noise(self, model):
        noise_scale = self.noise_multiplier * self.max_grad_norm
        for param in model.parameters():
            if param.grad is not None:
                noise = torch.normal(0, noise_scale, size=param.grad.shape, device=param.grad.device)
                param.grad.data.add_(noise)

class SecureAggregation:
    def __init__(self, noise_scale=1e-3):
        self.noise_scale = noise_scale

    def add_random_mask(self, parameters):
        masked_params = []
        for param in parameters:
            mask = np.random.normal(0, self.noise_scale, param.shape)
            masked_params.append(param + mask)
        return masked_params

class PrivacyEnhancedHeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

class PrivacyAwareFedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super().__init__()
        self.base_criterion = base_criterion
        self.mu = mu

    def forward(self, y_pred, y_true, model_params, global_params):
        base_loss = self.base_criterion(y_pred, y_true)
        proximal_term = 0.0
        if global_params is not None:
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
            loss = base_loss + (self.mu / 2) * proximal_term
        else:
            loss = base_loss
        return loss

def load_data(data_path):
    try:
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Dropping {missing_values} rows with missing data")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing data: {df.shape}")
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' missing")
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        return dataloader, X.shape[1]
    except Exception as e:
        logger.error(f"Error loading data: {e}")
        raise

class DP_SA_Client(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device, client_id):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.global_params = None

        self.dp_enabled = CLIENT_CONFIG["dp_enabled"]
        if self.dp_enabled:
            self.dp_mechanism = DifferentialPrivacyMechanism(
                CLIENT_CONFIG["dp_noise_multiplier"],
                CLIENT_CONFIG["dp_max_grad_norm"],
                CLIENT_CONFIG["dp_epsilon"],
                CLIENT_CONFIG["dp_delta"]
            )

        self.sa_enabled = CLIENT_CONFIG["sa_enabled"]
        if self.sa_enabled:
            self.secure_agg = SecureAggregation(noise_scale=CLIENT_CONFIG["sa_noise_scale"])

    def get_parameters(self, config):
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]

        if self.sa_enabled:
            params = self.secure_agg.add_random_mask(params)
            logger.info(f"Client {self.client_id} applied Secure Aggregation masking")

        return params

    def set_parameters(self, parameters):
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        criterion = nn.BCELoss()
        proximal_criterion = PrivacyAwareFedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        optimizer = torch.optim.Adam(self.model.parameters(), lr=CLIENT_CONFIG["learning_rate"], weight_decay=CLIENT_CONFIG["weight_decay"])

        total_loss, total_samples, correct = 0.0, 0, 0

        for epoch in range(CLIENT_CONFIG["local_epochs"]):
            epoch_loss, epoch_samples = 0.0, 0
            for batch_idx, (X, y) in enumerate(self.dataloader):
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                loss = proximal_criterion(y_pred, y, self.model.parameters(), self.global_params)
                optimizer.zero_grad()
                loss.backward()

                if self.dp_enabled:
                    grad_norm = self.dp_mechanism.clip_gradients(self.model)
                    self.dp_mechanism.add_noise(self.model)
                    if batch_idx % 10 == 0:
                        logger.info(f"Client {self.client_id} DP applied: grad_norm={grad_norm:.4f}")

                optimizer.step()

                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)

                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()

                if batch_idx % 5 == 0:
                    logger.info(f"Client {self.client_id} - Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - Batch {batch_idx}/{len(self.dataloader)} - Loss: {loss.item():.4f}")
            logger.info(f"Client {self.client_id} - Epoch {epoch+1} complete - Loss: {epoch_loss/epoch_samples:.4f}")

        avg_loss = total_loss / total_samples if total_samples else 0
        accuracy = correct / total_samples if total_samples else 0

        logger.info(f"Client {self.client_id} training finished - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Send security flags back in metrics including client ID
        return self.get_parameters({}), total_samples, {
            "loss": avg_loss,
            "accuracy": accuracy,
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id  # Send client ID here
        }

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.BCELoss()

        loss, total, correct = 0.0, 0, 0

        with torch.no_grad():
            for X, y in self.dataloader:
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                loss += batch_loss * X.size(0)
                total += X.size(0)
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()

        avg_loss = loss / total if total else 0
        accuracy = correct / total if total else 0

        logger.info(f"Client {self.client_id} evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Send security flags back in metrics including client ID
        return float(avg_loss), total, {
            "accuracy": accuracy,
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id  # Send client ID here
        }

def start_client(client_id=0, server_address=None):
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")

    data_path = f"framingham_part{client_id+1}.csv"
    if not os.path.exists(data_path):
        logger.error(f"Data file {data_path} not found")
        return

    dataloader, input_size = load_data(data_path)

    model = PrivacyEnhancedHeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size {input_size}")

    client = DP_SA_Client(model, dataloader, device, client_id)

    print(f"\n===== DP+SA Framingham FL Client {client_id} =====")
    print(f"Server:              {CLIENT_CONFIG['server_address']}")
    print(f"Data file:           {data_path}")
    print(f"Local epochs:        {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:          {CLIENT_CONFIG['batch_size']}")
    print(f"Device:              {device}")
    print("==============================================\n")

    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

if __name__ == "__main__":
    import sys
    import argparse

    if 'ipykernel' in sys.modules:
        start_client(client_id=0)
    else:
        parser = argparse.ArgumentParser(description="DP+SA Framingham FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--disable-sa", action="store_true", help="Disable Secure Aggregation masking")
        parser.add_argument("--dp-epsilon", type=float, default=8.0, help="DP epsilon parameter")
        parser.add_argument("--dp-noise", type=float, default=1.0, help="DP noise multiplier")
        args = parser.parse_args()

        CLIENT_CONFIG["dp_epsilon"] = args.dp_epsilon
        CLIENT_CONFIG["dp_noise_multiplier"] = args.dp_noise
        CLIENT_CONFIG["sa_enabled"] = not args.disable_sa

        start_client(args.id, args.server)
# Out:
# 2025-05-24 20:42:10,741 - DP_SA_FraminghamClient - INFO - Using device: cuda
# 2025-05-24 20:42:10,747 - DP_SA_FraminghamClient - INFO - Loaded framingham_part1.csv with shape (1060, 16)
# 2025-05-24 20:42:10,750 - DP_SA_FraminghamClient - INFO - Class distribution: {0: 884, 1: 176}
# 2025-05-24 20:42:10,758 - DP_SA_FraminghamClient - INFO - Model initialized with input size 15
# 2025-05-24 20:42:10,760 - DP_SA_FraminghamClient - INFO - DP initialized: ε=8.0, δ=1e-05, noise_multiplier=1.0
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 20:42:10,761 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 20:42:10,765 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 20:42:10,788 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 20:42:10,793 - flwr - DEBUG - ChannelConnectivity.CONNECTING
# 2025-05-24 20:42:10,794 - flwr - DEBUG - ChannelConnectivity.READY
# INFO :
# 2025-05-24 20:42:10,802 - flwr - INFO -
# INFO :      Received: train message 69c65621-09f1-4aba-acef-adf7bc459bfc
# 2025-05-24 20:42:10,804 - flwr - INFO - Received: train message 69c65621-09f1-4aba-acef-adf7bc459bfc
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:10,807 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:10,824 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:10,842 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.7612
# 2025-05-24 20:42:10,848 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.7527
# 2025-05-24 20:42:10,938 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.7410
# ===== DP+SA Framingham FL Client 0 =====
# Server:              localhost:8080
# Data file:           framingham_part1.csv
# Local epochs:        3
# Batch size:          32
# Device:              cuda
# ==============================================
# 2025-05-24 20:42:11,012 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6184
# 2025-05-24 20:42:11,015 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.7228
# 2025-05-24 20:42:11,060 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.7474
# 2025-05-24 20:42:11,102 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6345
# 2025-05-24 20:42:11,105 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.7415
# 2025-05-24 20:42:11,142 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.7263
# 2025-05-24 20:42:11,187 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5093
# 2025-05-24 20:42:11,190 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.7141
# 2025-05-24 20:42:11,217 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.7300
# 2025-05-24 20:42:11,228 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5885
# 2025-05-24 20:42:11,231 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.7187
# 2025-05-24 20:42:11,272 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.7357
# 2025-05-24 20:42:11,308 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5745
# 2025-05-24 20:42:11,311 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.7187
# 2025-05-24 20:42:11,352 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.7531
# 2025-05-24 20:42:11,391 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5726
# 2025-05-24 20:42:11,394 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.7251
# 2025-05-24 20:42:11,437 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.7061
# 2025-05-24 20:42:11,480 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5232
# 2025-05-24 20:42:11,483 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.7057
# 2025-05-24 20:42:11,511 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.7250
# 2025-05-24 20:42:11,521 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6914
# 2025-05-24 20:42:11,524 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.7301
# 2025-05-24 20:42:11,565 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.7019
# 2025-05-24 20:42:11,607 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4992
# 2025-05-24 20:42:11,611 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.7173
# 2025-05-24 20:42:11,658 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.7045
# 2025-05-24 20:42:11,694 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6962
# 2025-05-24 20:42:11,697 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.7244
# 2025-05-24 20:42:11,733 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.7255
# 2025-05-24 20:42:11,768 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.7413
# 2025-05-24 20:42:11,770 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.7027
# 2025-05-24 20:42:11,793 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.7144
# 2025-05-24 20:42:11,793 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 0.7231, Accuracy: 0.3233
# 2025-05-24 20:42:11,795 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:11,797 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:11,845 - flwr - INFO -
# INFO :      Received: evaluate message 7278e725-33a5-4bdc-98c3-dc1a05b9c27a
# 2025-05-24 20:42:11,847 - flwr - INFO - Received: evaluate message 7278e725-33a5-4bdc-98c3-dc1a05b9c27a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:11,849 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:11,853 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:11,911 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 0.6492, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 20:42:11,913 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:11,932 - flwr - INFO -
# INFO :      Received: train message 1ca163a9-ad3e-40e9-ae3a-00fca0df5755
# 2025-05-24 20:42:11,935 - flwr - INFO - Received: train message 1ca163a9-ad3e-40e9-ae3a-00fca0df5755
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:11,938 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:11,943 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:11,957 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.4107
# 2025-05-24 20:42:11,962 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 1.2851
# 2025-05-24 20:42:12,018 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.3727
# 2025-05-24 20:42:12,062 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.7173
# 2025-05-24 20:42:12,065 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.4138
# 2025-05-24 20:42:12,100 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.5251
# 2025-05-24 20:42:12,137 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6977
# 2025-05-24 20:42:12,140 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.4276
# 2025-05-24 20:42:12,173 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.6878
# 2025-05-24 20:42:12,206 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6807
# 2025-05-24 20:42:12,208 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.3689
# 2025-05-24 20:42:12,227 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.6822
# 2025-05-24 20:42:12,234 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.2157
# 2025-05-24 20:42:12,236 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.8232
# 2025-05-24 20:42:12,269 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.2545
# 2025-05-24 20:42:12,303 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.2966
# 2025-05-24 20:42:12,305 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.8834
# 2025-05-24 20:42:12,337 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 1.0678
# 2025-05-24 20:42:12,370 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.6356
# 2025-05-24 20:42:12,371 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.9047
# 2025-05-24 20:42:12,406 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.5480
# 2025-05-24 20:42:12,437 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.9951
# 2025-05-24 20:42:12,439 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.7010
# 2025-05-24 20:42:12,458 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.7056
# 2025-05-24 20:42:12,465 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.4686
# 2025-05-24 20:42:12,467 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.8830
# 2025-05-24 20:42:12,500 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.8060
# 2025-05-24 20:42:12,532 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.9224
# 2025-05-24 20:42:12,534 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.5827
# 2025-05-24 20:42:12,570 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 1.0969
# 2025-05-24 20:42:12,613 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.9021
# 2025-05-24 20:42:12,618 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.4752
# 2025-05-24 20:42:12,660 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.4215
# 2025-05-24 20:42:12,695 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.8877
# 2025-05-24 20:42:12,698 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6051
# 2025-05-24 20:42:12,723 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.6896
# 2025-05-24 20:42:12,724 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 0.6925, Accuracy: 0.8340
# 2025-05-24 20:42:12,725 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:12,727 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:12,787 - flwr - INFO -
# INFO :      Received: evaluate message f1e88763-a053-46ea-9b00-9299a4443b4a
# 2025-05-24 20:42:12,791 - flwr - INFO - Received: evaluate message f1e88763-a053-46ea-9b00-9299a4443b4a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:12,797 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:12,807 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:12,914 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 0.4927, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 20:42:12,918 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:12,942 - flwr - INFO -
# INFO :      Received: train message c3a4efc1-5516-4b35-a90f-343fdca5e42f
# 2025-05-24 20:42:12,944 - flwr - INFO - Received: train message c3a4efc1-5516-4b35-a90f-343fdca5e42f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:12,946 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:12,952 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:12,963 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4966
# 2025-05-24 20:42:12,966 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.3845
# 2025-05-24 20:42:13,014 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.4276
# 2025-05-24 20:42:13,057 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4554
# 2025-05-24 20:42:13,064 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.5246
# 2025-05-24 20:42:13,116 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.4413
# 2025-05-24 20:42:13,165 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6501
# 2025-05-24 20:42:13,169 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.3103
# 2025-05-24 20:42:13,225 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.5347
# 2025-05-24 20:42:13,272 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5089
# 2025-05-24 20:42:13,276 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.5184
# 2025-05-24 20:42:13,302 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.5057
# 2025-05-24 20:42:13,313 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.8280
# 2025-05-24 20:42:13,316 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.4927
# 2025-05-24 20:42:13,370 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.4393
# 2025-05-24 20:42:13,417 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5381
# 2025-05-24 20:42:13,420 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.4073
# 2025-05-24 20:42:13,463 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.6930
# 2025-05-24 20:42:13,506 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3883
# 2025-05-24 20:42:13,509 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.4882
# 2025-05-24 20:42:13,558 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6840
# 2025-05-24 20:42:13,598 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4251
# 2025-05-24 20:42:13,601 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.4116
# 2025-05-24 20:42:13,629 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.4881
# 2025-05-24 20:42:13,637 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5156
# 2025-05-24 20:42:13,640 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.5434
# 2025-05-24 20:42:13,689 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5208
# 2025-05-24 20:42:13,752 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5184
# 2025-05-24 20:42:13,755 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.4877
# 2025-05-24 20:42:13,807 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.4904
# 2025-05-24 20:42:13,855 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4432
# 2025-05-24 20:42:13,858 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.5862
# 2025-05-24 20:42:13,899 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.4831
# 2025-05-24 20:42:13,945 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3988
# 2025-05-24 20:42:13,948 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.4122
# 2025-05-24 20:42:13,975 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.4929
# 2025-05-24 20:42:13,976 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 0.4956, Accuracy: 0.8336
# 2025-05-24 20:42:13,979 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:13,981 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:14,256 - flwr - INFO -
# INFO :      Received: evaluate message d54f9be3-ac23-46c2-9794-face9c4dcb53
# 2025-05-24 20:42:14,258 - flwr - INFO - Received: evaluate message d54f9be3-ac23-46c2-9794-face9c4dcb53
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:14,261 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:14,267 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:14,337 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 0.4833, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 20:42:14,338 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:14,358 - flwr - INFO -
# INFO :      Received: train message d2b14932-1c87-4e8a-813d-1de9fff3dff9
# 2025-05-24 20:42:14,361 - flwr - INFO - Received: train message d2b14932-1c87-4e8a-813d-1de9fff3dff9
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:14,364 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:14,369 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:14,382 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3954
# 2025-05-24 20:42:14,387 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.3064
# 2025-05-24 20:42:14,444 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.3082
# 2025-05-24 20:42:14,488 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6114
# 2025-05-24 20:42:14,491 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.4174
# 2025-05-24 20:42:14,539 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.5191
# 2025-05-24 20:42:14,584 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4612
# 2025-05-24 20:42:14,587 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.4374
# 2025-05-24 20:42:14,635 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.3883
# 2025-05-24 20:42:14,675 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5194
# 2025-05-24 20:42:14,677 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.3995
# 2025-05-24 20:42:14,703 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.5176
# 2025-05-24 20:42:14,711 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.0588
# 2025-05-24 20:42:14,714 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6403
# 2025-05-24 20:42:14,764 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.4721
# 2025-05-24 20:42:14,808 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.2712
# 2025-05-24 20:42:14,812 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.5578
# 2025-05-24 20:42:14,858 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.2859
# 2025-05-24 20:42:14,913 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.0738
# 2025-05-24 20:42:14,917 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.6097
# 2025-05-24 20:42:14,961 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.5698
# 2025-05-24 20:42:15,013 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5087
# 2025-05-24 20:42:15,016 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.3473
# 2025-05-24 20:42:15,044 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.5173
# 2025-05-24 20:42:15,059 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2848
# 2025-05-24 20:42:15,064 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.3030
# 2025-05-24 20:42:15,105 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.7579
# 2025-05-24 20:42:15,145 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5999
# 2025-05-24 20:42:15,149 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.4150
# 2025-05-24 20:42:15,194 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.4247
# 2025-05-24 20:42:15,234 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5161
# 2025-05-24 20:42:15,237 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.2629
# 2025-05-24 20:42:15,279 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.4702
# 2025-05-24 20:42:15,313 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4763
# 2025-05-24 20:42:15,315 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.2299
# 2025-05-24 20:42:15,343 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.5227
# 2025-05-24 20:42:15,344 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 0.5192, Accuracy: 0.8340
# 2025-05-24 20:42:15,347 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:15,349 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:15,585 - flwr - INFO -
# INFO :      Received: evaluate message 1dfca661-7bdc-4221-ba07-efed7149ab60
# 2025-05-24 20:42:15,588 - flwr - INFO - Received: evaluate message 1dfca661-7bdc-4221-ba07-efed7149ab60
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:15,590 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:15,598 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:15,671 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 0.5606, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 20:42:15,674 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:15,709 - flwr - INFO -
# INFO :      Received: train message 39ffecf0-1135-4cf9-b319-46809c2ac111
# 2025-05-24 20:42:15,712 - flwr - INFO - Received: train message 39ffecf0-1135-4cf9-b319-46809c2ac111
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:15,715 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:15,724 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:15,739 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.9905
# 2025-05-24 20:42:15,747 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.5569
# 2025-05-24 20:42:15,806 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.3040
# 2025-05-24 20:42:15,862 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.1370
# 2025-05-24 20:42:15,866 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.4494
# 2025-05-24 20:42:15,915 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.6822
# 2025-05-24 20:42:15,959 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.8363
# 2025-05-24 20:42:15,961 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.5907
# 2025-05-24 20:42:16,002 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.3140
# 2025-05-24 20:42:16,049 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.4620
# 2025-05-24 20:42:16,052 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.5834
# 2025-05-24 20:42:16,079 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.5704
# 2025-05-24 20:42:16,087 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.2938
# 2025-05-24 20:42:16,090 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.4573
# 2025-05-24 20:42:16,139 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.6382
# 2025-05-24 20:42:16,181 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.7614
# 2025-05-24 20:42:16,183 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.5404
# 2025-05-24 20:42:16,235 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.7742
# 2025-05-24 20:42:16,286 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.2809
# 2025-05-24 20:42:16,289 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.2716
# 2025-05-24 20:42:16,335 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.5030
# 2025-05-24 20:42:16,387 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.0822
# 2025-05-24 20:42:16,390 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.4711
# 2025-05-24 20:42:16,422 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.5513
# 2025-05-24 20:42:16,432 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.1569
# 2025-05-24 20:42:16,435 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.5673
# 2025-05-24 20:42:16,480 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5936
# 2025-05-24 20:42:16,518 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.1998
# 2025-05-24 20:42:16,522 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.8062
# 2025-05-24 20:42:16,574 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.2598
# 2025-05-24 20:42:16,617 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.2369
# 2025-05-24 20:42:16,620 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.5240
# 2025-05-24 20:42:16,669 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.3263
# 2025-05-24 20:42:16,711 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.8401
# 2025-05-24 20:42:16,713 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.7042
# 2025-05-24 20:42:16,739 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.5382
# 2025-05-24 20:42:16,741 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 0.5533, Accuracy: 0.8248
# 2025-05-24 20:42:16,743 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:16,745 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:17,034 - flwr - INFO -
# INFO :      Received: evaluate message 59996d22-31e4-4db0-93d1-f2121a5fcade
# 2025-05-24 20:42:17,037 - flwr - INFO - Received: evaluate message 59996d22-31e4-4db0-93d1-f2121a5fcade
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:17,039 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:17,045 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:17,121 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 1.7681, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 20:42:17,123 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:17,150 - flwr - INFO -
# INFO :      Received: train message ec723b6d-eecf-4654-af0d-d1f6a0fcc8cd
# 2025-05-24 20:42:17,152 - flwr - INFO - Received: train message ec723b6d-eecf-4654-af0d-d1f6a0fcc8cd
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:17,155 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:17,162 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:17,175 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.7486
# 2025-05-24 20:42:17,179 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 1.4570
# 2025-05-24 20:42:17,252 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.1237
# 2025-05-24 20:42:17,326 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=5.3204
# 2025-05-24 20:42:17,330 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 4.4174
# 2025-05-24 20:42:17,389 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 3.4149
# 2025-05-24 20:42:17,441 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.6220
# 2025-05-24 20:42:17,444 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 2.0865
# 2025-05-24 20:42:17,495 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 3.0113
# 2025-05-24 20:42:17,541 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.4089
# 2025-05-24 20:42:17,544 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 1.1512
# 2025-05-24 20:42:17,572 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 1.8444
# 2025-05-24 20:42:17,581 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.7079
# 2025-05-24 20:42:17,584 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6459
# 2025-05-24 20:42:17,627 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 2.2074
# 2025-05-24 20:42:17,675 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.7650
# 2025-05-24 20:42:17,678 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 1.6123
# 2025-05-24 20:42:17,726 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 2.6552
# 2025-05-24 20:42:17,771 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.9228
# 2025-05-24 20:42:17,774 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 1.5548
# 2025-05-24 20:42:17,823 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 1.6394
# 2025-05-24 20:42:17,863 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.9236
# 2025-05-24 20:42:17,866 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.4258
# 2025-05-24 20:42:17,891 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 1.7305
# 2025-05-24 20:42:17,902 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.0378
# 2025-05-24 20:42:17,905 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 1.8321
# 2025-05-24 20:42:17,945 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 2.1186
# 2025-05-24 20:42:17,982 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.3339
# 2025-05-24 20:42:17,984 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 1.0708
# 2025-05-24 20:42:18,024 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 2.2457
# 2025-05-24 20:42:18,069 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.3610
# 2025-05-24 20:42:18,072 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 1.2975
# 2025-05-24 20:42:18,118 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 1.8815
# 2025-05-24 20:42:18,156 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=6.1712
# 2025-05-24 20:42:18,159 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 2.0732
# 2025-05-24 20:42:18,183 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 1.5553
# 2025-05-24 20:42:18,184 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 1.7100, Accuracy: 0.8340
# 2025-05-24 20:42:18,186 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:18,187 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:18,472 - flwr - INFO -
# INFO :      Received: evaluate message 9b1ff8f5-b32d-48eb-a339-425e0759b99f
# 2025-05-24 20:42:18,473 - flwr - INFO - Received: evaluate message 9b1ff8f5-b32d-48eb-a339-425e0759b99f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:18,476 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:18,483 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:18,566 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 1.2696, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 20:42:18,568 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:18,621 - flwr - INFO -
# INFO :      Received: train message 6c49fc58-9d6f-4dd3-9b63-bf61c4361a32
# 2025-05-24 20:42:18,623 - flwr - INFO - Received: train message 6c49fc58-9d6f-4dd3-9b63-bf61c4361a32
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:18,626 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:18,632 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:18,641 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.6013
# 2025-05-24 20:42:18,644 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.6341
# 2025-05-24 20:42:18,723 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6642
# 2025-05-24 20:42:18,783 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.5456
# 2025-05-24 20:42:18,789 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.8902
# 2025-05-24 20:42:18,838 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 1.2580
# 2025-05-24 20:42:18,890 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=5.7813
# 2025-05-24 20:42:18,892 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 1.4560
# 2025-05-24 20:42:18,934 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.4959
# 2025-05-24 20:42:18,986 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=7.0928
# 2025-05-24 20:42:18,989 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 1.7720
# 2025-05-24 20:42:19,023 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 1.2609
# 2025-05-24 20:42:19,033 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.7233
# 2025-05-24 20:42:19,037 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 1.0821
# 2025-05-24 20:42:19,083 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 2.2835
# 2025-05-24 20:42:19,129 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.8867
# 2025-05-24 20:42:19,132 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.5770
# 2025-05-24 20:42:19,187 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 1.0711
# 2025-05-24 20:42:19,228 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=5.7761
# 2025-05-24 20:42:19,232 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 1.5866
# 2025-05-24 20:42:19,275 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 1.7030
# 2025-05-24 20:42:19,338 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.8306
# 2025-05-24 20:42:19,342 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 1.1964
# 2025-05-24 20:42:19,373 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 1.2184
# 2025-05-24 20:42:19,383 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.3226
# 2025-05-24 20:42:19,387 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.8751
# 2025-05-24 20:42:19,430 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 1.4307
# 2025-05-24 20:42:19,473 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.8327
# 2025-05-24 20:42:19,477 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.7694
# 2025-05-24 20:42:19,529 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 1.5742
# 2025-05-24 20:42:19,582 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.8395
# 2025-05-24 20:42:19,585 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 1.3467
# 2025-05-24 20:42:19,628 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.4247
# 2025-05-24 20:42:19,675 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.8706
# 2025-05-24 20:42:19,680 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 1.2955
# 2025-05-24 20:42:19,712 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 1.1512
# 2025-05-24 20:42:19,714 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 1.2101, Accuracy: 0.8327
# 2025-05-24 20:42:19,716 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:19,719 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:19,987 - flwr - INFO -
# INFO :      Received: evaluate message 5dc18c32-e9f0-40dd-966a-0dba61517aac
# 2025-05-24 20:42:19,989 - flwr - INFO - Received: evaluate message 5dc18c32-e9f0-40dd-966a-0dba61517aac
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:19,992 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:20,001 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:20,075 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 28.9142, Accuracy: 0.3340
# INFO :      Sent reply
# 2025-05-24 20:42:20,077 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:20,099 - flwr - INFO -
# INFO :      Received: train message 07a0e3a5-e69f-4d74-932e-aea5c74d5def
# 2025-05-24 20:42:20,102 - flwr - INFO - Received: train message 07a0e3a5-e69f-4d74-932e-aea5c74d5def
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:20,104 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:20,110 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:20,126 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=21.6332
# 2025-05-24 20:42:20,132 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 15.1910
# 2025-05-24 20:42:20,182 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 24.4150
# 2025-05-24 20:42:20,248 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=15.2653
# 2025-05-24 20:42:20,253 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 29.3634
# 2025-05-24 20:42:20,312 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 35.2387
# 2025-05-24 20:42:20,369 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=15.6259
# 2025-05-24 20:42:20,372 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 20.9396
# 2025-05-24 20:42:20,423 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 15.4892
# 2025-05-24 20:42:20,467 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=20.3223
# 2025-05-24 20:42:20,471 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 14.5827
# 2025-05-24 20:42:20,497 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 25.0590
# 2025-05-24 20:42:20,507 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=26.5813
# 2025-05-24 20:42:20,510 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 14.3473
# 2025-05-24 20:42:20,556 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 20.5786
# 2025-05-24 20:42:20,594 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=15.4711
# 2025-05-24 20:42:20,597 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 23.9904
# 2025-05-24 20:42:20,638 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 14.5489
# 2025-05-24 20:42:20,701 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=23.1621
# 2025-05-24 20:42:20,704 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 24.7720
# 2025-05-24 20:42:20,750 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 26.2507
# 2025-05-24 20:42:20,792 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=9.1555
# 2025-05-24 20:42:20,795 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 16.5064
# 2025-05-24 20:42:20,825 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 22.2064
# 2025-05-24 20:42:20,834 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=14.4043
# 2025-05-24 20:42:20,837 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 20.9792
# 2025-05-24 20:42:20,878 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 19.6273
# 2025-05-24 20:42:20,920 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=12.0009
# 2025-05-24 20:42:20,923 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 24.8741
# 2025-05-24 20:42:20,967 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 6.5334
# 2025-05-24 20:42:21,009 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.1322
# 2025-05-24 20:42:21,011 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 11.3191
# 2025-05-24 20:42:21,055 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 22.4396
# 2025-05-24 20:42:21,098 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=17.3123
# 2025-05-24 20:42:21,102 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 20.7631
# 2025-05-24 20:42:21,141 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 18.7215
# 2025-05-24 20:42:21,144 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 21.9956, Accuracy: 0.4377
# 2025-05-24 20:42:21,147 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:21,151 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:21,488 - flwr - INFO -
# INFO :      Received: evaluate message 725868c1-e4e2-4336-abc4-67e7c5298117
# 2025-05-24 20:42:21,491 - flwr - INFO - Received: evaluate message 725868c1-e4e2-4336-abc4-67e7c5298117
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:21,493 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:21,498 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# ...
# 2025-05-24 20:42:35,512 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 72.0710
# 2025-05-24 20:42:35,538 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 71.7932
# 2025-05-24 20:42:35,549 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.8492
# 2025-05-24 20:42:35,551 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 69.8655
# 2025-05-24 20:42:35,647 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 69.6743
# 2025-05-24 20:42:35,706 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.0334
# 2025-05-24 20:42:35,709 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 69.9099
# 2025-05-24 20:42:35,765 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 72.4685
# 2025-05-24 20:42:35,817 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=6.2860
# 2025-05-24 20:42:35,820 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 71.0966
# 2025-05-24 20:42:35,863 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 66.3773
# 2025-05-24 20:42:35,922 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.1162
# 2025-05-24 20:42:35,925 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 79.1868
# 2025-05-24 20:42:35,952 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 71.9100
# 2025-05-24 20:42:35,963 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=5.2462
# 2025-05-24 20:42:35,967 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 64.4058
# 2025-05-24 20:42:36,030 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 61.8381
# 2025-05-24 20:42:36,085 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2291
# 2025-05-24 20:42:36,088 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 78.1607
# 2025-05-24 20:42:36,144 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 78.3110
# 2025-05-24 20:42:36,193 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=5.2728
# 2025-05-24 20:42:36,199 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 63.8676
# 2025-05-24 20:42:36,253 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 67.4274
# 2025-05-24 20:42:36,317 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.5243
# 2025-05-24 20:42:36,322 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 76.2133
# 2025-05-24 20:42:36,363 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 70.6607
# 2025-05-24 20:42:36,364 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 71.4546, Accuracy: 0.1692
# 2025-05-24 20:42:36,368 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:36,372 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:36,680 - flwr - INFO -
# INFO :      Received: evaluate message 10334958-cb83-4775-93c1-8232353a9526
# 2025-05-24 20:42:36,681 - flwr - INFO - Received: evaluate message 10334958-cb83-4775-93c1-8232353a9526
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:36,683 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:36,689 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:36,760 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 72.1582, Accuracy: 0.1660
# INFO :      Sent reply
# 2025-05-24 20:42:36,763 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:36,787 - flwr - INFO -
# INFO :      Received: train message 1eef379a-f781-40b5-a64c-e2b921f619f7
# 2025-05-24 20:42:36,789 - flwr - INFO - Received: train message 1eef379a-f781-40b5-a64c-e2b921f619f7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:36,792 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:36,799 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:36,811 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.3897
# 2025-05-24 20:42:36,815 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 72.3453
# 2025-05-24 20:42:36,874 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 56.6863
# 2025-05-24 20:42:36,958 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.4500
# 2025-05-24 20:42:36,963 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 82.1678
# 2025-05-24 20:42:37,032 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 66.5269
# 2025-05-24 20:42:37,095 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.3397
# 2025-05-24 20:42:37,099 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 72.7590
# 2025-05-24 20:42:37,153 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 66.3113
# 2025-05-24 20:42:37,197 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.0891
# 2025-05-24 20:42:37,200 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 72.5625
# 2025-05-24 20:42:37,229 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 72.5989
# 2025-05-24 20:42:37,238 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.7924
# 2025-05-24 20:42:37,242 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 81.4599
# 2025-05-24 20:42:37,308 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 78.8397
# 2025-05-24 20:42:37,365 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.4847
# 2025-05-24 20:42:37,368 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 67.6109
# 2025-05-24 20:42:37,410 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 81.7752
# 2025-05-24 20:42:37,460 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.4082
# 2025-05-24 20:42:37,464 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 72.5646
# 2025-05-24 20:42:37,512 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 63.8405
# 2025-05-24 20:42:37,577 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2118
# 2025-05-24 20:42:37,582 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 71.9181
# 2025-05-24 20:42:37,641 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 72.1507
# 2025-05-24 20:42:37,654 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.2044
# 2025-05-24 20:42:37,660 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 54.4322
# 2025-05-24 20:42:37,726 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 59.9020
# 2025-05-24 20:42:37,768 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=1.1551
# 2025-05-24 20:42:37,771 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 72.0489
# 2025-05-24 20:42:37,815 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 66.9194
# 2025-05-24 20:42:37,856 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=6.7701
# 2025-05-24 20:42:37,859 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 73.9487
# 2025-05-24 20:42:37,901 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 58.2365
# 2025-05-24 20:42:37,944 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.1635
# 2025-05-24 20:42:37,946 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 72.9643
# 2025-05-24 20:42:37,972 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 71.1701
# 2025-05-24 20:42:37,973 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 71.9732, Accuracy: 0.1704
# 2025-05-24 20:42:37,974 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:37,976 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:38,210 - flwr - INFO -
# INFO :      Received: evaluate message 3c8eec1c-2b42-4c7c-b2cb-9cd61d1600f8
# 2025-05-24 20:42:38,214 - flwr - INFO - Received: evaluate message 3c8eec1c-2b42-4c7c-b2cb-9cd61d1600f8
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:38,216 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:38,221 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:38,362 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 72.1582, Accuracy: 0.1660
# INFO :      Sent reply
# 2025-05-24 20:42:38,365 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:38,728 - flwr - INFO -
# INFO :      Received: train message 25d4eee6-34f9-4e93-b25b-77fcc13240df
# 2025-05-24 20:42:38,730 - flwr - INFO - Received: train message 25d4eee6-34f9-4e93-b25b-77fcc13240df
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:38,734 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:38,741 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:38,752 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=6.5894
# 2025-05-24 20:42:38,757 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 64.9669
# 2025-05-24 20:42:38,811 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 60.4520
# 2025-05-24 20:42:38,869 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.2365
# 2025-05-24 20:42:38,874 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 69.8230
# 2025-05-24 20:42:38,963 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 63.4631
# 2025-05-24 20:42:39,024 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.0635
# 2025-05-24 20:42:39,028 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 66.2969
# 2025-05-24 20:42:39,075 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 69.6610
# 2025-05-24 20:42:39,126 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.6680
# 2025-05-24 20:42:39,130 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 73.1830
# 2025-05-24 20:42:39,158 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 70.7424
# 2025-05-24 20:42:39,167 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.8434
# 2025-05-24 20:42:39,174 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 69.4473
# 2025-05-24 20:42:39,221 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 57.6323
# 2025-05-24 20:42:39,280 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=6.7196
# 2025-05-24 20:42:39,284 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 60.9860
# 2025-05-24 20:42:39,338 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 84.4306
# 2025-05-24 20:42:39,417 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=4.0972
# 2025-05-24 20:42:39,422 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 66.4428
# 2025-05-24 20:42:39,486 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 73.2739
# 2025-05-24 20:42:39,534 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=5.1228
# 2025-05-24 20:42:39,538 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 61.1891
# 2025-05-24 20:42:39,570 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 71.5477
# 2025-05-24 20:42:39,579 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.6667
# 2025-05-24 20:42:39,582 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 76.1099
# 2025-05-24 20:42:39,622 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 72.5421
# 2025-05-24 20:42:39,677 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=6.4084
# 2025-05-24 20:42:39,681 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 69.8622
# 2025-05-24 20:42:39,733 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 88.0532
# 2025-05-24 20:42:39,779 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=3.0068
# 2025-05-24 20:42:39,783 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 82.2996
# 2025-05-24 20:42:39,836 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 60.2450
# 2025-05-24 20:42:39,894 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=2.7326
# 2025-05-24 20:42:39,898 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 66.7324
# 2025-05-24 20:42:39,925 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 71.2352
# 2025-05-24 20:42:39,926 - DP_SA_FraminghamClient - INFO - Client 0 training finished - Loss: 71.1751, Accuracy: 0.1692
# 2025-05-24 20:42:39,928 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 20:42:39,930 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:40,172 - flwr - INFO -
# INFO :      Received: evaluate message 2655905d-5116-4c61-ae0a-e5b368c8788a
# 2025-05-24 20:42:40,174 - flwr - INFO - Received: evaluate message 2655905d-5116-4c61-ae0a-e5b368c8788a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:40,178 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:42:40,184 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 20:42:40,294 - DP_SA_FraminghamClient - INFO - Client 0 evaluation - Loss: 72.1582, Accuracy: 0.1660
# INFO :      Sent reply
# 2025-05-24 20:42:40,295 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:42:47,641 - flwr - INFO -
# INFO :      Received: reconnect message 537203a6-71cb-4aeb-997a-2ebfded8144f
# 2025-05-24 20:42:47,645 - flwr - INFO - Received: reconnect message 537203a6-71cb-4aeb-997a-2ebfded8144f
# 2025-05-24 20:42:47,679 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 20:42:47,682 - flwr - INFO - Disconnect and shut down
