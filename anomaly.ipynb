# %%
#!/usr/bin/env python3
"""
Anomalous Federated Learning Client (Non-Poisoning)
===================================================

This client creates various types of anomalies without traditional model poisoning:
- Parameter distribution anomalies
- Training behavior anomalies  
- Performance inconsistencies
- Statistical outliers
- Pattern irregularities

These anomalies test the anomaly detection system specifically.
"""

import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import sys
import logging
import random
from typing import Dict, List, Tuple

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("AnomalousClient")

# Client configuration
ANOMALY_CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01,
    
    # Anomaly configuration
    "anomaly_type": "mixed",  # "parameter", "training", "performance", "statistical", "mixed"
    "anomaly_intensity": 0.7,  # 0.0 (none) to 1.0 (maximum)
    "anomaly_frequency": 0.8,  # Probability of introducing anomaly each round
}

class HeartDiseaseModel(nn.Module):
    """Heart disease prediction model."""
    def __init__(self, input_size):
        super(HeartDiseaseModel, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(ANOMALY_CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(ANOMALY_CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

class FedProxLoss(nn.Module):
    """FedProx loss function."""
    def __init__(self, base_criterion, mu=0.01):
        super(FedProxLoss, self).__init__()
        self.base_criterion = base_criterion
        self.mu = mu
        
    def forward(self, y_pred, y_true, model_params, global_params):
        base_loss = self.base_criterion(y_pred, y_true)
        
        proximal_term = 0.0
        if global_params is not None:
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
            loss = base_loss + (self.mu / 2) * proximal_term
            return loss
        
        return base_loss

class AnomalyGenerator:
    """Generates various types of anomalies for testing."""
    
    def __init__(self, anomaly_type="mixed", intensity=0.7, frequency=0.8):
        self.anomaly_type = anomaly_type
        self.intensity = intensity
        self.frequency = frequency
        self.round_count = 0
        
    def should_introduce_anomaly(self):
        """Decide whether to introduce anomaly this round."""
        return random.random() < self.frequency
    
    def apply_parameter_anomalies(self, parameters: List[np.ndarray]) -> List[np.ndarray]:
        """Apply parameter-level anomalies (non-poisoning)."""
        anomalous_params = []
        
        for i, param in enumerate(parameters):
            anomalous_param = param.copy()
            
            if self.anomaly_type in ["parameter", "mixed"]:
                # Type 1: Add structured noise (more aggressive)
                if random.random() < 0.7:
                    noise_scale = 0.3 * self.intensity  # Increased from 0.1
                    structured_noise = np.sin(np.arange(param.size) * 0.1).reshape(param.shape) * noise_scale
                    anomalous_param += structured_noise
                    logger.info(f"  Applied STRONG structured noise to layer {i} (scale={noise_scale:.3f})")
                
                # Type 2: Introduce more aggressive sparsity patterns
                if random.random() < 0.5:
                    sparsity_ratio = 0.4 * self.intensity  # Increased from 0.2
                    mask = np.random.random(param.shape) < sparsity_ratio
                    anomalous_param[mask] = 0
                    logger.info(f"  Applied AGGRESSIVE sparsity to layer {i} ({np.sum(mask)} zeros, {sparsity_ratio:.1%} sparse)")
                
                # Type 3: Amplify parameters more dramatically
                if random.random() < 0.6 and param.size > 10:
                    amplification = 1 + 1.5 * self.intensity  # Increased from 0.5
                    # Amplify every 2nd parameter instead of every 3rd
                    indices = np.arange(0, param.size, 2)
                    flat_param = anomalous_param.flatten()
                    flat_param[indices] *= amplification
                    anomalous_param = flat_param.reshape(param.shape)
                    logger.info(f"  Applied STRONG amplification to layer {i} (factor={amplification:.2f})")
                
                # Type 4: Add systematic bias (new)
                if random.random() < 0.4:
                    bias = 0.5 * self.intensity * np.sign(np.mean(param))
                    anomalous_param += bias
                    logger.info(f"  Added systematic bias to layer {i} (bias={bias:.3f})")
                
                # Type 5: Create artificial patterns (new)
                if random.random() < 0.3 and param.size > 50:
                    pattern_size = min(10, param.size // 10)
                    pattern = np.tile([1, -1], pattern_size // 2 + 1)[:pattern_size]
                    pattern = pattern * 0.3 * self.intensity
                    flat_param = anomalous_param.flatten()
                    flat_param[:pattern_size] = pattern
                    anomalous_param = flat_param.reshape(param.shape)
                    logger.info(f"  Applied artificial pattern to layer {i}")
            
            anomalous_params.append(anomalous_param)
        
        return anomalous_params
    
    def get_anomalous_training_config(self) -> Dict:
        """Get anomalous training configuration."""
        config = {}
        
        if self.anomaly_type in ["training", "mixed"]:
            # Anomalous learning rates
            if random.random() < 0.4:
                if random.random() < 0.5:
                    config["learning_rate"] = 0.1 * self.intensity  # Too high
                    logger.info(f"  Using anomalously high learning rate: {config['learning_rate']}")
                else:
                    config["learning_rate"] = 0.0001 * (1 - self.intensity)  # Too low
                    logger.info(f"  Using anomalously low learning rate: {config['learning_rate']}")
            
            # Anomalous batch processing
            if random.random() < 0.3:
                config["process_partial_batches"] = True
                config["partial_ratio"] = 0.3 + 0.4 * self.intensity
                logger.info(f"  Processing only {config['partial_ratio']:.2f} of each batch")
            
            # Anomalous epoch patterns
            if random.random() < 0.2:
                config["skip_epochs"] = int(1 + 2 * self.intensity)
                logger.info(f"  Skipping {config['skip_epochs']} training epochs")
        
        return config
    
    def get_anomalous_metrics(self, true_accuracy: float, true_loss: float) -> Dict:
        """Generate anomalous (but not obviously fake) metrics."""
        metrics = {
            "accuracy": true_accuracy,
            "loss": true_loss,
            "poisoning_active": False  # Not doing traditional poisoning
        }
        
        if self.anomaly_type in ["performance", "mixed"]:
            # Type 1: Extreme inconsistent performance (more aggressive)
            if random.random() < 0.6:
                # Very high accuracy but very high loss (clearly inconsistent)
                metrics["accuracy"] = min(0.95, true_accuracy + 0.4 * self.intensity)
                metrics["loss"] = max(true_loss, true_loss + 2.0 * self.intensity)
                logger.info(f"  Reporting EXTREME inconsistent metrics: acc={metrics['accuracy']:.3f}, loss={metrics['loss']:.3f}")
            
            # Type 2: Oscillating performance (more extreme)
            elif random.random() < 0.4:
                oscillation = 0.5 * self.intensity * np.sin(self.round_count * np.pi / 2)
                metrics["accuracy"] = max(0.05, min(0.95, true_accuracy + oscillation))
                metrics["loss"] = max(0.1, true_loss - oscillation * 0.5)
                logger.info(f"  Applying EXTREME performance oscillation: {oscillation:.3f}")
            
            # Type 3: Suspicious performance patterns
            elif random.random() < 0.3:
                # Performance that's too good for early rounds
                if self.round_count <= 3:
                    metrics["accuracy"] = 0.85 + 0.1 * self.intensity
                    metrics["loss"] = 0.2 + 0.1 * self.intensity
                    logger.info(f"  Reporting suspiciously good early performance")
                
                # Or performance that degrades suddenly
                else:
                    metrics["accuracy"] = max(0.1, true_accuracy - 0.3 * self.intensity)
                    metrics["loss"] = true_loss + 1.5 * self.intensity
                    logger.info(f"  Reporting sudden performance degradation")
        
        return metrics

def load_data(data_path):
    """Load and preprocess data."""
    try:
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        
        if df.isnull().sum().sum() > 0:
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing values: {df.shape}")
        
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' not found in dataset!")
            
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=ANOMALY_CLIENT_CONFIG["batch_size"], shuffle=True)
        
        logger.info(f"Created dataloader with {len(dataset)} samples and {X.shape[1]} features")
        return dataloader, X.shape[1]
    
    except Exception as e:
        logger.error(f"Error loading data: {str(e)}")
        raise

class AnomalousFraminghamClient(fl.client.NumPyClient):
    """Anomalous client that generates various anomalies for testing."""
    
    def __init__(self, model, dataloader, device, client_id, anomaly_config=None):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.global_params = None
        
        # Initialize anomaly generator
        if anomaly_config is None:
            anomaly_config = {
                "anomaly_type": ANOMALY_CLIENT_CONFIG["anomaly_type"],
                "intensity": ANOMALY_CLIENT_CONFIG["anomaly_intensity"],
                "frequency": ANOMALY_CLIENT_CONFIG["anomaly_frequency"]
            }
        
        self.anomaly_generator = AnomalyGenerator(**anomaly_config)
        
        logger.info(f"[ANOMALOUS] Client {client_id} initialized")
        logger.info(f"  Anomaly Type: {anomaly_config['anomaly_type']}")
        logger.info(f"  Intensity: {anomaly_config['intensity']}")
        logger.info(f"  Frequency: {anomaly_config['frequency']}")
        
    def get_parameters(self, config):
        """Get model parameters with potential anomalies."""
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]
        
        # Apply anomalies if decided for this round
        if self.anomaly_generator.should_introduce_anomaly():
            logger.info(f"[ANOMALY] Client {self.client_id} introducing anomalies...")
            params = self.anomaly_generator.apply_parameter_anomalies(params)
            
            # Log parameter statistics
            original_norm = sum(np.linalg.norm(p) for p in [val.detach().cpu().numpy() for val in self.model.parameters()])
            anomalous_norm = sum(np.linalg.norm(p) for p in params)
            logger.info(f"  Parameter norm: {original_norm:.6f} -> {anomalous_norm:.6f}")
        else:
            logger.info(f"[NORMAL] Client {self.client_id} behaving normally this round")
        
        return params
    
    def set_parameters(self, parameters):
        """Set model parameters."""
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")
    
    def fit(self, parameters, config):
        """Train with potential anomalies."""
        self.set_parameters(parameters)
        self.anomaly_generator.round_count += 1
        
        # Get anomalous training configuration
        anomaly_config = self.anomaly_generator.get_anomalous_training_config()
        
        # Apply anomalous training settings
        learning_rate = anomaly_config.get("learning_rate", ANOMALY_CLIENT_CONFIG["learning_rate"])
        process_partial = anomaly_config.get("process_partial_batches", False)
        partial_ratio = anomaly_config.get("partial_ratio", 1.0)
        skip_epochs = anomaly_config.get("skip_epochs", 0)
        
        if anomaly_config:
            logger.info(f"[ANOMALY] Client {self.client_id} using anomalous training config")
        
        self.model.train()
        criterion = nn.BCELoss()
        proximal_criterion = FedProxLoss(criterion, mu=ANOMALY_CLIENT_CONFIG["proximal_mu"])
        
        optimizer = torch.optim.Adam(
            self.model.parameters(), 
            lr=learning_rate,
            weight_decay=ANOMALY_CLIENT_CONFIG["weight_decay"]
        )
        
        total_loss = 0.0
        total_samples = 0
        correct = 0
        
        # Training with potential anomalies
        effective_epochs = max(1, ANOMALY_CLIENT_CONFIG["local_epochs"] - skip_epochs)
        
        for epoch in range(effective_epochs):
            epoch_loss = 0.0
            epoch_samples = 0
            
            for batch_idx, (X, y) in enumerate(self.dataloader):
                # Anomalous batch processing
                if process_partial and random.random() > partial_ratio:
                    continue  # Skip this batch
                
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                
                # Loss calculation
                loss = proximal_criterion(
                    y_pred, y, 
                    self.model.parameters(),
                    self.global_params
                )
                
                # Backward pass
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                # Update metrics
                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
                
                if batch_idx % 10 == 0:
                    logger.info(f"Client {self.client_id} - Epoch {epoch+1}/{effective_epochs} - Batch {batch_idx} - Loss: {loss.item():.4f}")
        
        # Calculate metrics
        avg_loss = total_loss / total_samples if total_samples > 0 else 0
        accuracy = correct / total_samples if total_samples > 0 else 0
        
        # Apply anomalous metric reporting
        anomalous_metrics = self.anomaly_generator.get_anomalous_metrics(accuracy, avg_loss)
        
        logger.info(f"[TRAINING] Client {self.client_id} training completed")
        logger.info(f"  True metrics: Loss={avg_loss:.4f}, Accuracy={accuracy:.4f}")
        logger.info(f"  Reported metrics: Loss={anomalous_metrics['loss']:.4f}, Accuracy={anomalous_metrics['accuracy']:.4f}")
        
        return self.get_parameters({}), total_samples, {
            "loss": float(anomalous_metrics["loss"]), 
            "accuracy": float(anomalous_metrics["accuracy"]),
            "client_id": str(self.client_id),
            "poisoning_active": False,  # Not traditional poisoning
            "anomaly_active": True,     # But anomalous behavior
            "anomaly_type": self.anomaly_generator.anomaly_type,
            "anomaly_intensity": self.anomaly_generator.intensity
        }
    
    def evaluate(self, parameters, config):
        """Evaluate with potential anomalies."""
        self.set_parameters(parameters)
        
        self.model.eval()
        criterion = nn.BCELoss()
        
        loss = 0.0
        total = 0
        correct = 0
        
        with torch.no_grad():
            for X, y in self.dataloader:
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                
                loss += batch_loss * X.size(0)
                total += X.size(0)
                
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
        
        avg_loss = loss / total if total > 0 else 0
        accuracy = correct / total if total > 0 else 0
        
        # Apply anomalous evaluation metrics
        anomalous_metrics = self.anomaly_generator.get_anomalous_metrics(accuracy, avg_loss)
        
        logger.info(f"[EVALUATION] Client {self.client_id} evaluation completed")
        logger.info(f"  True metrics: Loss={avg_loss:.4f}, Accuracy={accuracy:.4f}")
        logger.info(f"  Reported metrics: Loss={anomalous_metrics['loss']:.4f}, Accuracy={anomalous_metrics['accuracy']:.4f}")
        
        return float(anomalous_metrics["loss"]), total, {
            "accuracy": float(anomalous_metrics["accuracy"]),
            "client_id": str(self.client_id),
            "poisoning_active": False,
            "anomaly_active": True,
            "anomaly_type": self.anomaly_generator.anomaly_type
        }

def start_anomalous_client(
    client_id=0, 
    server_address=None, 
    anomaly_type="mixed",
    anomaly_intensity=0.7,
    anomaly_frequency=0.8
):
    """Initialize and start an anomalous client."""
    
    if server_address:
        ANOMALY_CLIENT_CONFIG["server_address"] = server_address
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")
    
    # Data file
    data_path = f"framingham_part{client_id+1}.csv"
    if not os.path.exists(data_path):
        logger.error(f"Data file {data_path} not found")
        return
    
    # Load data
    dataloader, input_size = load_data(data_path)
    
    # Initialize model
    model = HeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size: {input_size}")
    
    # Anomaly configuration
    anomaly_config = {
        "anomaly_type": anomaly_type,
        "intensity": anomaly_intensity,
        "frequency": anomaly_frequency
    }
    
    # Create anomalous client
    client = AnomalousFraminghamClient(
        model, dataloader, device, client_id, anomaly_config
    )
    
    # Display client information
    print(f"\n{'='*80}")
    print(f"⚠️ ANOMALOUS FRAMINGHAM CLIENT {client_id}")
    print(f"{'='*80}")
    print(f"Server:           {ANOMALY_CLIENT_CONFIG['server_address']}")
    print(f"Data file:        {data_path}")
    print(f"Device:           {device}")
    print(f"")
    print(f"Anomaly Configuration:")
    print(f"  Type:           {anomaly_type}")
    print(f"  Intensity:      {anomaly_intensity} (0.0-1.0)")
    print(f"  Frequency:      {anomaly_frequency} (probability per round)")
    print(f"")
    print(f"Anomaly Types:")
    print(f"  parameter:      Parameter distribution anomalies")
    print(f"  training:       Training behavior anomalies")
    print(f"  performance:    Performance reporting anomalies")
    print(f"  statistical:    Statistical pattern anomalies")
    print(f"  mixed:          Combination of all types")
    print(f"")
    print(f"⚠️  This client will exhibit anomalous behavior for testing!")
    print(f"    (Not traditional model poisoning)")
    print(f"{'='*80}")
    print(f"\nConnecting to server...\n")
    
    # Start client
    fl.client.start_client(
        server_address=ANOMALY_CLIENT_CONFIG["server_address"], 
        client=client
    )

if __name__ == "__main__":
    if 'ipykernel' in sys.modules:
        print("Running in Jupyter/IPython environment")
        # Configuration for Jupyter
        client_id = 5                    # Change this to match your setup
        anomaly_type = "mixed"           # "parameter", "training", "performance", "statistical", "mixed"
        anomaly_intensity = 0.9          # Increased to 0.9 for stronger detection
        anomaly_frequency = 1.0          # 100% frequency for testing
        
        print(f"⚠️ Starting ANOMALOUS client {client_id}")
        print(f"   Type: {anomaly_type}")
        print(f"   Intensity: {anomaly_intensity}")
        print(f"   Frequency: {anomaly_frequency}")
        
        start_anomalous_client(
            client_id=client_id,
            anomaly_type=anomaly_type,
            anomaly_intensity=anomaly_intensity,
            anomaly_frequency=anomaly_frequency
        )
    else:
        import argparse
        parser = argparse.ArgumentParser(description="Anomalous Framingham FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--type", type=str, default="mixed", 
                           choices=["parameter", "training", "performance", "statistical", "mixed"],
                           help="Type of anomaly to introduce")
        parser.add_argument("--intensity", type=float, default=0.7, help="Anomaly intensity (0.0-1.0)")
        parser.add_argument("--frequency", type=float, default=0.8, help="Anomaly frequency (0.0-1.0)")
        
        args = parser.parse_args()
        
        start_anomalous_client(
            client_id=args.id,
            server_address=args.server,
            anomaly_type=args.type,
            anomaly_intensity=args.intensity,
            anomaly_frequency=args.frequency
        )
# Out:
# 2025-05-24 20:33:11,587 - AnomalousClient - INFO - Using device: cuda
# 2025-05-24 20:33:11,595 - AnomalousClient - INFO - Loaded framingham_part6.csv with shape (1060, 16)
# 2025-05-24 20:33:11,598 - AnomalousClient - INFO - Class distribution: {0: 898, 1: 162}
# 2025-05-24 20:33:11,602 - AnomalousClient - INFO - Created dataloader with 1060 samples and 15 features
# 2025-05-24 20:33:11,605 - AnomalousClient - INFO - Model initialized with input size: 15
# 2025-05-24 20:33:11,605 - AnomalousClient - INFO - [ANOMALOUS] Client 5 initialized
# 2025-05-24 20:33:11,606 - AnomalousClient - INFO -   Anomaly Type: mixed
# 2025-05-24 20:33:11,607 - AnomalousClient - INFO -   Intensity: 0.9
# 2025-05-24 20:33:11,608 - AnomalousClient - INFO -   Frequency: 1.0
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 20:33:11,608 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 20:33:11,611 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 20:33:11,631 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 20:33:11,636 - flwr - DEBUG - ChannelConnectivity.CONNECTING
# 2025-05-24 20:33:11,640 - flwr - DEBUG - ChannelConnectivity.READY
# Running in Jupyter/IPython environment
# ⚠️ Starting ANOMALOUS client 5
#    Type: mixed
#    Intensity: 0.9
#    Frequency: 1.0
#
# ================================================================================
# ⚠️ ANOMALOUS FRAMINGHAM CLIENT 5
# ================================================================================
# Server:           localhost:8080
# Data file:        framingham_part6.csv
# Device:           cuda
#
# Anomaly Configuration:
#   Type:           mixed
#   Intensity:      0.9 (0.0-1.0)
#   Frequency:      1.0 (probability per round)
#
# Anomaly Types:
#   parameter:      Parameter distribution anomalies
#   training:       Training behavior anomalies
#   performance:    Performance reporting anomalies
#   statistical:    Statistical pattern anomalies
#   mixed:          Combination of all types
#
# ⚠️  This client will exhibit anomalous behavior for testing!
#     (Not traditional model poisoning)
# ================================================================================
#
# Connecting to server...
# INFO :
# 2025-05-24 20:33:13,494 - flwr - INFO -
# INFO :      Received: train message f9f7297d-5f02-48cc-8617-51077596e3f4
# 2025-05-24 20:33:13,496 - flwr - INFO - Received: train message f9f7297d-5f02-48cc-8617-51077596e3f4
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:13,498 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:13,502 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:13,503 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 20:33:13,505 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:13,521 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.6494
# 2025-05-24 20:33:13,622 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.9142
# 2025-05-24 20:33:13,726 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.8004
# 2025-05-24 20:33:13,810 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.7935
# 2025-05-24 20:33:13,836 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.5457
# 2025-05-24 20:33:13,906 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 1.1921
# 2025-05-24 20:33:13,970 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.7598
# 2025-05-24 20:33:14,032 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.6029
# 2025-05-24 20:33:14,060 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.4664
# 2025-05-24 20:33:14,134 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.6306
# 2025-05-24 20:33:14,211 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.6811
# 2025-05-24 20:33:14,282 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.8182
# 2025-05-24 20:33:14,308 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: 0.450
# 2025-05-24 20:33:14,309 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:14,311 - AnomalousClient - INFO -   True metrics: Loss=0.7070, Accuracy=0.8374
# 2025-05-24 20:33:14,312 - AnomalousClient - INFO -   Reported metrics: Loss=0.4820, Accuracy=0.9500
# 2025-05-24 20:33:14,314 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:14,315 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 20:33:14,317 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 20:33:14,320 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:14,321 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 20:33:14,322 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:14,324 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:14,325 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 20:33:14,326 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:14,327 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (13 zeros, 36.0% sparse)
# 2025-05-24 20:33:14,328 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:14,329 - AnomalousClient - INFO -   Added systematic bias to layer 3 (bias=-0.450)
# 2025-05-24 20:33:14,331 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:14,332 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (10 zeros, 36.0% sparse)
# 2025-05-24 20:33:14,335 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:14,336 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:14,338 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:14,340 - AnomalousClient - INFO -   Parameter norm: 17.670486 -> 61.089168
# INFO :      Sent reply
# 2025-05-24 20:33:14,343 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:14,504 - flwr - INFO -
# INFO :      Received: evaluate message 900a962a-0b4c-40e4-ac0a-fdcdba3e3704
# 2025-05-24 20:33:14,507 - flwr - INFO - Received: evaluate message 900a962a-0b4c-40e4-ac0a-fdcdba3e3704
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:14,510 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:14,517 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:14,610 - AnomalousClient - INFO -   Reporting suspiciously good early performance
# 2025-05-24 20:33:14,611 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:14,611 - AnomalousClient - INFO -   True metrics: Loss=0.5123, Accuracy=0.8491
# 2025-05-24 20:33:14,612 - AnomalousClient - INFO -   Reported metrics: Loss=0.2900, Accuracy=0.9400
# INFO :      Sent reply
# 2025-05-24 20:33:14,613 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:14,628 - flwr - INFO -
# INFO :      Received: train message e7de408a-df03-43f6-bf7c-209ea36dde8a
# 2025-05-24 20:33:14,630 - flwr - INFO - Received: train message e7de408a-df03-43f6-bf7c-209ea36dde8a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:14,633 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:14,643 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:14,645 - AnomalousClient - INFO -   Skipping 2 training epochs
# 2025-05-24 20:33:14,650 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:14,663 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 0 - Loss: 0.5368
# 2025-05-24 20:33:14,744 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 10 - Loss: 0.5579
# 2025-05-24 20:33:14,835 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 20 - Loss: 0.5774
# 2025-05-24 20:33:14,907 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 30 - Loss: 0.4390
# 2025-05-24 20:33:14,924 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.308
# 2025-05-24 20:33:14,925 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:14,927 - AnomalousClient - INFO -   True metrics: Loss=0.5076, Accuracy=0.8509
# 2025-05-24 20:33:14,928 - AnomalousClient - INFO -   Reported metrics: Loss=2.3076, Accuracy=0.9500
# 2025-05-24 20:33:14,930 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:14,932 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 20:33:14,933 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (369 zeros, 36.0% sparse)
# 2025-05-24 20:33:14,935 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 20:33:14,936 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 20:33:14,937 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (18 zeros, 36.0% sparse)
# 2025-05-24 20:33:14,938 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 20:33:14,939 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:14,941 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (713 zeros, 36.0% sparse)
# 2025-05-24 20:33:14,943 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:14,944 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 20:33:14,946 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:14,947 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:14,951 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 20:33:14,953 - AnomalousClient - INFO -   Parameter norm: 32.602136 -> 76.125728
# INFO :      Sent reply
# 2025-05-24 20:33:14,956 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:15,444 - flwr - INFO -
# INFO :      Received: evaluate message a0a0f4fa-dbed-4ca9-a771-7c766bf10bd2
# 2025-05-24 20:33:15,447 - flwr - INFO - Received: evaluate message a0a0f4fa-dbed-4ca9-a771-7c766bf10bd2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:15,450 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:15,455 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:15,519 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.288
# 2025-05-24 20:33:15,520 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:15,521 - AnomalousClient - INFO -   True metrics: Loss=0.4882, Accuracy=0.8481
# 2025-05-24 20:33:15,522 - AnomalousClient - INFO -   Reported metrics: Loss=2.2882, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:15,523 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:15,538 - flwr - INFO -
# INFO :      Received: train message 711a4b76-a195-462a-b002-a66825e77811
# 2025-05-24 20:33:15,541 - flwr - INFO - Received: train message 711a4b76-a195-462a-b002-a66825e77811
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:15,547 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:15,557 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:15,574 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.4718
# 2025-05-24 20:33:15,665 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.4925
# 2025-05-24 20:33:15,737 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.4644
# 2025-05-24 20:33:15,809 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.4755
# 2025-05-24 20:33:15,841 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.4573
# 2025-05-24 20:33:15,914 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.5679
# 2025-05-24 20:33:15,980 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.4528
# 2025-05-24 20:33:16,043 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.5306
# 2025-05-24 20:33:16,066 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.4620
# 2025-05-24 20:33:16,123 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.5097
# 2025-05-24 20:33:16,178 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.5102
# 2025-05-24 20:33:16,246 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.6561
# 2025-05-24 20:33:16,273 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.282
# 2025-05-24 20:33:16,275 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:16,279 - AnomalousClient - INFO -   True metrics: Loss=0.4824, Accuracy=0.8487
# 2025-05-24 20:33:16,280 - AnomalousClient - INFO -   Reported metrics: Loss=2.2824, Accuracy=0.9500
# 2025-05-24 20:33:16,284 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:16,286 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 20:33:16,288 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:16,289 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (18 zeros, 36.0% sparse)
# 2025-05-24 20:33:16,291 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:16,292 - AnomalousClient - INFO -   Applied artificial pattern to layer 1
# 2025-05-24 20:33:16,294 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:16,295 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (759 zeros, 36.0% sparse)
# 2025-05-24 20:33:16,296 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:16,297 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 20:33:16,298 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:16,299 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:16,300 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (19 zeros, 36.0% sparse)
# 2025-05-24 20:33:16,302 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:16,304 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:16,306 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 20:33:16,308 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 20:33:16,310 - AnomalousClient - INFO -   Parameter norm: 41.551297 -> 71.323130
# INFO :      Sent reply
# 2025-05-24 20:33:16,313 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:16,430 - flwr - INFO -
# INFO :      Received: evaluate message 8f98f71b-d56a-4298-8f6f-9d3e4bd497ee
# 2025-05-24 20:33:16,432 - flwr - INFO - Received: evaluate message 8f98f71b-d56a-4298-8f6f-9d3e4bd497ee
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:16,434 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:16,438 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:16,529 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.265
# 2025-05-24 20:33:16,530 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:16,531 - AnomalousClient - INFO -   True metrics: Loss=0.4653, Accuracy=0.8406
# 2025-05-24 20:33:16,533 - AnomalousClient - INFO -   Reported metrics: Loss=2.2653, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:16,535 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:16,556 - flwr - INFO -
# INFO :      Received: train message a3d7f96a-5476-4eaa-818c-1af32dbc95f6
# 2025-05-24 20:33:16,558 - flwr - INFO - Received: train message a3d7f96a-5476-4eaa-818c-1af32dbc95f6
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:16,562 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:16,569 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:16,570 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 20:33:16,572 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:16,583 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.4725
# 2025-05-24 20:33:16,661 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.6308
# 2025-05-24 20:33:16,738 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.4107
# 2025-05-24 20:33:16,804 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.4722
# 2025-05-24 20:33:16,831 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.3392
# 2025-05-24 20:33:16,921 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.6451
# 2025-05-24 20:33:16,978 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.3867
# 2025-05-24 20:33:17,043 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.6742
# 2025-05-24 20:33:17,071 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.6133
# 2025-05-24 20:33:17,144 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.7768
# 2025-05-24 20:33:17,210 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.4797
# 2025-05-24 20:33:17,281 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.4790
# 2025-05-24 20:33:17,300 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.367
# 2025-05-24 20:33:17,302 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:17,303 - AnomalousClient - INFO -   True metrics: Loss=0.5671, Accuracy=0.8440
# 2025-05-24 20:33:17,305 - AnomalousClient - INFO -   Reported metrics: Loss=2.3671, Accuracy=0.9500
# 2025-05-24 20:33:17,307 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:17,309 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 20:33:17,311 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 20:33:17,312 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:17,313 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 20:33:17,314 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:17,316 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:17,317 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (773 zeros, 36.0% sparse)
# 2025-05-24 20:33:17,319 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:17,320 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (11 zeros, 36.0% sparse)
# 2025-05-24 20:33:17,321 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:17,322 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:17,323 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:17,325 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 20:33:17,327 - AnomalousClient - INFO -   Parameter norm: 54.348677 -> 65.872297
# INFO :      Sent reply
# 2025-05-24 20:33:17,330 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:17,464 - flwr - INFO -
# INFO :      Received: evaluate message e798c301-9a7c-417f-8eca-4de80911b3b1
# 2025-05-24 20:33:17,465 - flwr - INFO - Received: evaluate message e798c301-9a7c-417f-8eca-4de80911b3b1
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:17,467 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:17,472 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:17,558 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.251
# 2025-05-24 20:33:17,560 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:17,561 - AnomalousClient - INFO -   True metrics: Loss=0.4507, Accuracy=0.8349
# 2025-05-24 20:33:17,563 - AnomalousClient - INFO -   Reported metrics: Loss=2.2507, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:17,564 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:17,582 - flwr - INFO -
# INFO :      Received: train message a20c1155-d4b2-4158-b72c-e78633caa71c
# 2025-05-24 20:33:17,584 - flwr - INFO - Received: train message a20c1155-d4b2-4158-b72c-e78633caa71c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:17,586 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:17,591 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:17,602 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.6603
# 2025-05-24 20:33:17,692 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.5364
# 2025-05-24 20:33:17,763 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.4130
# 2025-05-24 20:33:17,828 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.5859
# 2025-05-24 20:33:17,856 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.3423
# 2025-05-24 20:33:17,928 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.4812
# 2025-05-24 20:33:17,997 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.4494
# 2025-05-24 20:33:18,062 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.3739
# 2025-05-24 20:33:18,087 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.5173
# 2025-05-24 20:33:18,150 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.5155
# 2025-05-24 20:33:18,216 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.5597
# 2025-05-24 20:33:18,277 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.5052
# 2025-05-24 20:33:18,297 - AnomalousClient - INFO -   Reporting sudden performance degradation
# 2025-05-24 20:33:18,299 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:18,300 - AnomalousClient - INFO -   True metrics: Loss=0.5264, Accuracy=0.8164
# 2025-05-24 20:33:18,301 - AnomalousClient - INFO -   Reported metrics: Loss=1.8764, Accuracy=0.5464
# 2025-05-24 20:33:18,303 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:18,304 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 20:33:18,305 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 20:33:18,306 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:18,308 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (26 zeros, 36.0% sparse)
# 2025-05-24 20:33:18,309 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:18,311 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:18,312 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:18,313 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 20:33:18,315 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 20:33:18,316 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:18,317 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (8 zeros, 36.0% sparse)
# 2025-05-24 20:33:18,319 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:18,320 - AnomalousClient - INFO -   Added systematic bias to layer 3 (bias=-0.450)
# 2025-05-24 20:33:18,322 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:18,323 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:18,325 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:18,325 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:18,327 - AnomalousClient - INFO -   Parameter norm: 57.332182 -> 144.644079
# INFO :      Sent reply
# 2025-05-24 20:33:18,329 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:18,460 - flwr - INFO -
# INFO :      Received: evaluate message b160ae59-50fd-4563-a000-01194156a8ab
# 2025-05-24 20:33:18,462 - flwr - INFO - Received: evaluate message b160ae59-50fd-4563-a000-01194156a8ab
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:18,464 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:18,469 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:18,564 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.240
# 2025-05-24 20:33:18,566 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:18,567 - AnomalousClient - INFO -   True metrics: Loss=0.4398, Accuracy=0.8472
# 2025-05-24 20:33:18,567 - AnomalousClient - INFO -   Reported metrics: Loss=2.2398, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:18,568 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:18,582 - flwr - INFO -
# INFO :      Received: train message 246722fd-a62d-4d51-9636-b549523c6fe8
# 2025-05-24 20:33:18,585 - flwr - INFO - Received: train message 246722fd-a62d-4d51-9636-b549523c6fe8
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:18,587 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:18,595 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:18,598 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 20:33:18,601 - AnomalousClient - INFO -   Skipping 2 training epochs
# 2025-05-24 20:33:18,602 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:18,614 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 0 - Loss: 0.5208
# 2025-05-24 20:33:18,684 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 10 - Loss: 0.7056
# 2025-05-24 20:33:18,753 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 20 - Loss: 0.7932
# 2025-05-24 20:33:18,826 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 30 - Loss: 0.6591
# 2025-05-24 20:33:18,843 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: 0.000
# 2025-05-24 20:33:18,845 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:18,846 - AnomalousClient - INFO -   True metrics: Loss=0.7965, Accuracy=0.8425
# 2025-05-24 20:33:18,847 - AnomalousClient - INFO -   Reported metrics: Loss=0.7965, Accuracy=0.8425
# 2025-05-24 20:33:18,848 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:18,849 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 20:33:18,850 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (325 zeros, 36.0% sparse)
# 2025-05-24 20:33:18,851 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 20:33:18,853 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:18,854 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (29 zeros, 36.0% sparse)
# 2025-05-24 20:33:18,856 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:18,858 - AnomalousClient - INFO -   Applied artificial pattern to layer 1
# 2025-05-24 20:33:18,859 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:18,861 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (804 zeros, 36.0% sparse)
# 2025-05-24 20:33:18,863 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:18,864 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (13 zeros, 36.0% sparse)
# 2025-05-24 20:33:18,866 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:18,869 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:18,871 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:18,872 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 20:33:18,875 - AnomalousClient - INFO -   Parameter norm: 100.114461 -> 190.367439
# INFO :      Sent reply
# 2025-05-24 20:33:18,877 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:19,415 - flwr - INFO -
# INFO :      Received: evaluate message b068decc-a3af-484f-831d-6a328c0d24fb
# 2025-05-24 20:33:19,416 - flwr - INFO - Received: evaluate message b068decc-a3af-484f-831d-6a328c0d24fb
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:19,418 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:19,423 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:19,500 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.238
# 2025-05-24 20:33:19,502 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:19,502 - AnomalousClient - INFO -   True metrics: Loss=0.4379, Accuracy=0.8443
# 2025-05-24 20:33:19,503 - AnomalousClient - INFO -   Reported metrics: Loss=2.2379, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:19,505 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:19,527 - flwr - INFO -
# INFO :      Received: train message df2fedd7-edad-4338-a8b8-aafbc64e93eb
# 2025-05-24 20:33:19,530 - flwr - INFO - Received: train message df2fedd7-edad-4338-a8b8-aafbc64e93eb
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:19,534 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:19,543 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:19,546 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 20:33:19,549 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:19,564 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 4.0175
# 2025-05-24 20:33:19,660 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.7151
# 2025-05-24 20:33:19,730 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.6415
# 2025-05-24 20:33:19,801 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.7626
# 2025-05-24 20:33:19,830 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 1.0964
# 2025-05-24 20:33:19,906 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.7155
# 2025-05-24 20:33:19,970 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.8835
# 2025-05-24 20:33:20,048 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.7770
# 2025-05-24 20:33:20,075 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.6382
# 2025-05-24 20:33:20,140 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.6615
# 2025-05-24 20:33:20,206 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.6057
# 2025-05-24 20:33:20,282 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.7287
# 2025-05-24 20:33:20,306 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.667
# 2025-05-24 20:33:20,307 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:20,308 - AnomalousClient - INFO -   True metrics: Loss=0.8665, Accuracy=0.8431
# 2025-05-24 20:33:20,309 - AnomalousClient - INFO -   Reported metrics: Loss=2.6665, Accuracy=0.9500
# 2025-05-24 20:33:20,311 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:20,312 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (351 zeros, 36.0% sparse)
# 2025-05-24 20:33:20,313 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 20:33:20,314 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 20:33:20,316 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:20,318 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 20:33:20,319 - AnomalousClient - INFO -   Applied artificial pattern to layer 1
# 2025-05-24 20:33:20,321 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:20,323 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (17 zeros, 36.0% sparse)
# 2025-05-24 20:33:20,325 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:20,326 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:20,327 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:20,328 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 20:33:20,332 - AnomalousClient - INFO -   Parameter norm: 117.331980 -> 140.561259
# INFO :      Sent reply
# 2025-05-24 20:33:20,335 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:20,469 - flwr - INFO -
# INFO :      Received: evaluate message 2fc36b25-60b4-4598-9f86-1aeed09896ea
# 2025-05-24 20:33:20,472 - flwr - INFO - Received: evaluate message 2fc36b25-60b4-4598-9f86-1aeed09896ea
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:20,474 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:20,479 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:20,571 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:20,573 - AnomalousClient - INFO -   True metrics: Loss=0.4338, Accuracy=0.8462
# 2025-05-24 20:33:20,574 - AnomalousClient - INFO -   Reported metrics: Loss=0.4338, Accuracy=0.8462
# INFO :      Sent reply
# 2025-05-24 20:33:20,576 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:20,596 - flwr - INFO -
# INFO :      Received: train message 6eb3af75-1906-434f-940e-f5f6f3f1a98f
# 2025-05-24 20:33:20,599 - flwr - INFO - Received: train message 6eb3af75-1906-434f-940e-f5f6f3f1a98f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:20,603 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:20,608 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:20,609 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 20:33:20,611 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:20,623 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.5326
# 2025-05-24 20:33:20,704 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.6156
# 2025-05-24 20:33:20,767 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.7679
# 2025-05-24 20:33:20,833 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.6591
# 2025-05-24 20:33:20,862 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.6895
# 2025-05-24 20:33:20,948 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.6651
# 2025-05-24 20:33:21,013 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.6338
# 2025-05-24 20:33:21,097 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.6719
# 2025-05-24 20:33:21,128 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.6480
# 2025-05-24 20:33:21,206 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.6143
# 2025-05-24 20:33:21,272 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.4586
# 2025-05-24 20:33:21,349 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.6355
# 2025-05-24 20:33:21,369 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: -0.000
# 2025-05-24 20:33:21,370 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:21,371 - AnomalousClient - INFO -   True metrics: Loss=0.7799, Accuracy=0.8434
# 2025-05-24 20:33:21,372 - AnomalousClient - INFO -   Reported metrics: Loss=0.7799, Accuracy=0.8434
# 2025-05-24 20:33:21,374 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:21,376 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 20:33:21,377 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (364 zeros, 36.0% sparse)
# 2025-05-24 20:33:21,379 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:21,380 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (22 zeros, 36.0% sparse)
# 2025-05-24 20:33:21,381 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:21,383 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (773 zeros, 36.0% sparse)
# 2025-05-24 20:33:21,384 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:21,385 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 20:33:21,386 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 20:33:21,388 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:21,389 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (16 zeros, 36.0% sparse)
# 2025-05-24 20:33:21,391 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:21,392 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:21,394 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:21,395 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (1 zeros, 36.0% sparse)
# 2025-05-24 20:33:21,396 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 20:33:21,398 - AnomalousClient - INFO -   Parameter norm: 127.084278 -> 211.881827
# INFO :      Sent reply
# 2025-05-24 20:33:21,402 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:21,550 - flwr - INFO -
# INFO :      Received: evaluate message 014025cc-2a6f-4068-9fd6-2d6ffd2f89be
# 2025-05-24 20:33:21,553 - flwr - INFO - Received: evaluate message 014025cc-2a6f-4068-9fd6-2d6ffd2f89be
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:21,555 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:21,560 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:21,655 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.261
# 2025-05-24 20:33:21,657 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:21,659 - AnomalousClient - INFO -   True metrics: Loss=0.4606, Accuracy=0.8472
# 2025-05-24 20:33:21,660 - AnomalousClient - INFO -   Reported metrics: Loss=2.2606, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:21,662 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:21,676 - flwr - INFO -
# INFO :      Received: train message 7b3eac44-eea8-4330-8443-b216872886b4
# 2025-05-24 20:33:21,678 - flwr - INFO - Received: train message 7b3eac44-eea8-4330-8443-b216872886b4
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:21,680 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:21,686 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:21,687 - AnomalousClient - INFO -   Using anomalously low learning rate: 9.999999999999997e-06
# 2025-05-24 20:33:21,688 - AnomalousClient - INFO -   Processing only 0.66 of each batch
# 2025-05-24 20:33:21,690 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:21,701 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.3995
# 2025-05-24 20:33:21,800 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.4227
# 2025-05-24 20:33:21,839 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.4648
# 2025-05-24 20:33:21,941 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.5952
# 2025-05-24 20:33:22,018 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.3669
# 2025-05-24 20:33:22,047 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.7910
# 2025-05-24 20:33:22,168 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.4647
# ...
# INFO :      Received: evaluate message b49b90eb-5489-42f0-802c-d9123d1408e7
# 2025-05-24 20:33:31,239 - flwr - INFO - Received: evaluate message b49b90eb-5489-42f0-802c-d9123d1408e7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:31,243 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:31,249 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:31,354 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: 0.450
# 2025-05-24 20:33:31,356 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:31,358 - AnomalousClient - INFO -   True metrics: Loss=6.7326, Accuracy=0.8000
# 2025-05-24 20:33:31,360 - AnomalousClient - INFO -   Reported metrics: Loss=6.5076, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 20:33:31,362 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:31,381 - flwr - INFO -
# INFO :      Received: train message 3e01e5b6-42df-4ae3-9bcb-d7ab2d019d99
# 2025-05-24 20:33:31,386 - flwr - INFO - Received: train message 3e01e5b6-42df-4ae3-9bcb-d7ab2d019d99
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:31,390 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:31,397 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:31,399 - AnomalousClient - INFO -   Using anomalously low learning rate: 9.999999999999997e-06
# 2025-05-24 20:33:31,400 - AnomalousClient - INFO -   Skipping 2 training epochs
# 2025-05-24 20:33:31,402 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:31,411 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 0 - Loss: 15.9790
# 2025-05-24 20:33:31,498 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 10 - Loss: 9.9066
# 2025-05-24 20:33:31,567 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 20 - Loss: 9.9626
# 2025-05-24 20:33:31,643 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 30 - Loss: 16.0350
# 2025-05-24 20:33:31,663 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=12.828
# 2025-05-24 20:33:31,664 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:31,666 - AnomalousClient - INFO -   True metrics: Loss=11.0284, Accuracy=0.7623
# 2025-05-24 20:33:31,667 - AnomalousClient - INFO -   Reported metrics: Loss=12.8284, Accuracy=0.9500
# 2025-05-24 20:33:31,670 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:31,671 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 20:33:31,673 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 20:33:31,674 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:31,675 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 20:33:31,676 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 20:33:31,678 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:31,679 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:31,680 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:31,681 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:31,686 - AnomalousClient - INFO -   Parameter norm: 1751.615823 -> 3837.966358
# INFO :      Sent reply
# 2025-05-24 20:33:31,693 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:32,272 - flwr - INFO -
# INFO :      Received: evaluate message 1a4e830e-698e-4072-ba3a-1b480591d92c
# 2025-05-24 20:33:32,275 - flwr - INFO - Received: evaluate message 1a4e830e-698e-4072-ba3a-1b480591d92c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:32,277 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:32,283 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:32,372 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:32,373 - AnomalousClient - INFO -   True metrics: Loss=7.1740, Accuracy=0.8028
# 2025-05-24 20:33:32,374 - AnomalousClient - INFO -   Reported metrics: Loss=7.1740, Accuracy=0.8028
# INFO :      Sent reply
# 2025-05-24 20:33:32,376 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:32,396 - flwr - INFO -
# INFO :      Received: train message 5d7eccc0-ffee-498a-bde9-7054bbebfafd
# 2025-05-24 20:33:32,398 - flwr - INFO - Received: train message 5d7eccc0-ffee-498a-bde9-7054bbebfafd
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:32,401 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:32,407 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:32,420 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 16.0863
# 2025-05-24 20:33:32,515 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 3.3726
# 2025-05-24 20:33:32,597 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 9.6090
# 2025-05-24 20:33:32,670 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 3.5565
# 2025-05-24 20:33:32,709 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 9.8435
# 2025-05-24 20:33:32,789 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 19.0466
# 2025-05-24 20:33:32,866 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 6.5057
# 2025-05-24 20:33:32,930 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 12.8027
# 2025-05-24 20:33:32,960 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 6.8428
# 2025-05-24 20:33:33,042 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 12.7473
# 2025-05-24 20:33:33,117 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 12.7991
# 2025-05-24 20:33:33,191 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 3.6169
# 2025-05-24 20:33:33,223 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=13.879
# 2025-05-24 20:33:33,224 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:33,224 - AnomalousClient - INFO -   True metrics: Loss=12.0794, Accuracy=0.7626
# 2025-05-24 20:33:33,226 - AnomalousClient - INFO -   Reported metrics: Loss=13.8794, Accuracy=0.9500
# 2025-05-24 20:33:33,228 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:33,230 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:33,231 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (28 zeros, 36.0% sparse)
# 2025-05-24 20:33:33,232 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 20:33:33,233 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 20:33:33,235 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 20:33:33,236 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:33,238 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:33,240 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (13 zeros, 36.0% sparse)
# 2025-05-24 20:33:33,242 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 20:33:33,244 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:33,250 - AnomalousClient - INFO -   Parameter norm: 2271.409310 -> 2359.236668
# INFO :      Sent reply
# 2025-05-24 20:33:33,254 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:33,371 - flwr - INFO -
# INFO :      Received: evaluate message a214bee4-ed16-4776-ac71-013ce46fd5ce
# 2025-05-24 20:33:33,375 - flwr - INFO - Received: evaluate message a214bee4-ed16-4776-ac71-013ce46fd5ce
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:33,379 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:33,386 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:33,466 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:33,468 - AnomalousClient - INFO -   True metrics: Loss=6.4501, Accuracy=0.8000
# 2025-05-24 20:33:33,469 - AnomalousClient - INFO -   Reported metrics: Loss=6.4501, Accuracy=0.8000
# INFO :      Sent reply
# 2025-05-24 20:33:33,470 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:33,486 - flwr - INFO -
# INFO :      Received: train message 20c65bed-ea81-44d1-b05c-a90423471d79
# 2025-05-24 20:33:33,489 - flwr - INFO - Received: train message 20c65bed-ea81-44d1-b05c-a90423471d79
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:33,491 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:33,498 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:33,499 - AnomalousClient - INFO -   Using anomalously low learning rate: 9.999999999999997e-06
# 2025-05-24 20:33:33,501 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 20:33:33,516 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 12.8491
# 2025-05-24 20:33:33,615 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 12.7377
# 2025-05-24 20:33:33,685 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.2572
# 2025-05-24 20:33:33,771 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 3.6050
# 2025-05-24 20:33:33,805 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 6.9696
# 2025-05-24 20:33:33,870 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 9.6733
# 2025-05-24 20:33:33,949 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 12.8032
# 2025-05-24 20:33:34,019 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 9.6225
# 2025-05-24 20:33:34,065 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 12.9097
# 2025-05-24 20:33:34,134 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 9.9058
# 2025-05-24 20:33:34,204 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 15.8022
# 2025-05-24 20:33:34,268 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 9.7387
# 2025-05-24 20:33:34,293 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=12.243
# 2025-05-24 20:33:34,295 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 20:33:34,296 - AnomalousClient - INFO -   True metrics: Loss=10.4428, Accuracy=0.7701
# 2025-05-24 20:33:34,298 - AnomalousClient - INFO -   Reported metrics: Loss=12.2428, Accuracy=0.9500
# 2025-05-24 20:33:34,300 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 20:33:34,302 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (346 zeros, 36.0% sparse)
# 2025-05-24 20:33:34,303 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 20:33:34,305 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 20:33:34,306 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 20:33:34,308 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (739 zeros, 36.0% sparse)
# 2025-05-24 20:33:34,310 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 20:33:34,311 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (9 zeros, 36.0% sparse)
# 2025-05-24 20:33:34,312 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 20:33:34,314 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 20:33:34,316 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (13 zeros, 36.0% sparse)
# 2025-05-24 20:33:34,317 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 20:33:34,319 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 20:33:34,322 - AnomalousClient - INFO -   Parameter norm: 2291.109959 -> 1964.922936
# INFO :      Sent reply
# 2025-05-24 20:33:34,324 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:34,515 - flwr - INFO -
# INFO :      Received: evaluate message aaabc50c-4735-4fff-81e7-c71b488fb85b
# 2025-05-24 20:33:34,518 - flwr - INFO - Received: evaluate message aaabc50c-4735-4fff-81e7-c71b488fb85b
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:34,519 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:33:34,527 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 20:33:34,604 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 20:33:34,605 - AnomalousClient - INFO -   True metrics: Loss=4.6447, Accuracy=0.8274
# 2025-05-24 20:33:34,605 - AnomalousClient - INFO -   Reported metrics: Loss=4.6447, Accuracy=0.8274
# INFO :      Sent reply
# 2025-05-24 20:33:34,607 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:33:39,951 - flwr - INFO -
# INFO :      Received: reconnect message 188398e2-94f6-447a-8101-d77e6bb8180d
# 2025-05-24 20:33:39,954 - flwr - INFO - Received: reconnect message 188398e2-94f6-447a-8101-d77e6bb8180d
# 2025-05-24 20:33:39,989 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 20:33:39,991 - flwr - INFO - Disconnect and shut down

# %%
#!/usr/bin/env python3
"""
Anomalous Federated Learning Client (Non-Poisoning)
===================================================

This client creates various types of anomalies without traditional model poisoning:
- Parameter distribution anomalies
- Training behavior anomalies  
- Performance inconsistencies
- Statistical outliers
- Pattern irregularities

These anomalies test the anomaly detection system specifically.
"""

import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import sys
import logging
import random
from typing import Dict, List, Tuple

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("AnomalousClient")

# Client configuration
ANOMALY_CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01,
    
    # Anomaly configuration
    "anomaly_type": "mixed",  # "parameter", "training", "performance", "statistical", "mixed"
    "anomaly_intensity": 0.7,  # 0.0 (none) to 1.0 (maximum)
    "anomaly_frequency": 0.8,  # Probability of introducing anomaly each round
}

class HeartDiseaseModel(nn.Module):
    """Heart disease prediction model."""
    def __init__(self, input_size):
        super(HeartDiseaseModel, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(ANOMALY_CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(ANOMALY_CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

class FedProxLoss(nn.Module):
    """FedProx loss function."""
    def __init__(self, base_criterion, mu=0.01):
        super(FedProxLoss, self).__init__()
        self.base_criterion = base_criterion
        self.mu = mu
        
    def forward(self, y_pred, y_true, model_params, global_params):
        base_loss = self.base_criterion(y_pred, y_true)
        
        proximal_term = 0.0
        if global_params is not None:
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
            loss = base_loss + (self.mu / 2) * proximal_term
            return loss
        
        return base_loss

class AnomalyGenerator:
    """Generates various types of anomalies for testing."""
    
    def __init__(self, anomaly_type="mixed", intensity=0.7, frequency=0.8):
        self.anomaly_type = anomaly_type
        self.intensity = intensity
        self.frequency = frequency
        self.round_count = 0
        
    def should_introduce_anomaly(self):
        """Decide whether to introduce anomaly this round."""
        return random.random() < self.frequency
    
    def apply_parameter_anomalies(self, parameters: List[np.ndarray]) -> List[np.ndarray]:
        """Apply parameter-level anomalies (non-poisoning)."""
        anomalous_params = []
        
        for i, param in enumerate(parameters):
            anomalous_param = param.copy()
            
            if self.anomaly_type in ["parameter", "mixed"]:
                # Type 1: Add structured noise (more aggressive)
                if random.random() < 0.7:
                    noise_scale = 0.3 * self.intensity  # Increased from 0.1
                    structured_noise = np.sin(np.arange(param.size) * 0.1).reshape(param.shape) * noise_scale
                    anomalous_param += structured_noise
                    logger.info(f"  Applied STRONG structured noise to layer {i} (scale={noise_scale:.3f})")
                
                # Type 2: Introduce more aggressive sparsity patterns
                if random.random() < 0.5:
                    sparsity_ratio = 0.4 * self.intensity  # Increased from 0.2
                    mask = np.random.random(param.shape) < sparsity_ratio
                    anomalous_param[mask] = 0
                    logger.info(f"  Applied AGGRESSIVE sparsity to layer {i} ({np.sum(mask)} zeros, {sparsity_ratio:.1%} sparse)")
                
                # Type 3: Amplify parameters more dramatically
                if random.random() < 0.6 and param.size > 10:
                    amplification = 1 + 1.5 * self.intensity  # Increased from 0.5
                    # Amplify every 2nd parameter instead of every 3rd
                    indices = np.arange(0, param.size, 2)
                    flat_param = anomalous_param.flatten()
                    flat_param[indices] *= amplification
                    anomalous_param = flat_param.reshape(param.shape)
                    logger.info(f"  Applied STRONG amplification to layer {i} (factor={amplification:.2f})")
                
                # Type 4: Add systematic bias (new)
                if random.random() < 0.4:
                    bias = 0.5 * self.intensity * np.sign(np.mean(param))
                    anomalous_param += bias
                    logger.info(f"  Added systematic bias to layer {i} (bias={bias:.3f})")
                
                # Type 5: Create artificial patterns (new)
                if random.random() < 0.3 and param.size > 50:
                    pattern_size = min(10, param.size // 10)
                    pattern = np.tile([1, -1], pattern_size // 2 + 1)[:pattern_size]
                    pattern = pattern * 0.3 * self.intensity
                    flat_param = anomalous_param.flatten()
                    flat_param[:pattern_size] = pattern
                    anomalous_param = flat_param.reshape(param.shape)
                    logger.info(f"  Applied artificial pattern to layer {i}")
            
            anomalous_params.append(anomalous_param)
        
        return anomalous_params
    
    def get_anomalous_training_config(self) -> Dict:
        """Get anomalous training configuration."""
        config = {}
        
        if self.anomaly_type in ["training", "mixed"]:
            # Anomalous learning rates
            if random.random() < 0.4:
                if random.random() < 0.5:
                    config["learning_rate"] = 0.1 * self.intensity  # Too high
                    logger.info(f"  Using anomalously high learning rate: {config['learning_rate']}")
                else:
                    config["learning_rate"] = 0.0001 * (1 - self.intensity)  # Too low
                    logger.info(f"  Using anomalously low learning rate: {config['learning_rate']}")
            
            # Anomalous batch processing
            if random.random() < 0.3:
                config["process_partial_batches"] = True
                config["partial_ratio"] = 0.3 + 0.4 * self.intensity
                logger.info(f"  Processing only {config['partial_ratio']:.2f} of each batch")
            
            # Anomalous epoch patterns
            if random.random() < 0.2:
                config["skip_epochs"] = int(1 + 2 * self.intensity)
                logger.info(f"  Skipping {config['skip_epochs']} training epochs")
        
        return config
    
    def get_anomalous_metrics(self, true_accuracy: float, true_loss: float) -> Dict:
        """Generate anomalous (but not obviously fake) metrics."""
        metrics = {
            "accuracy": true_accuracy,
            "loss": true_loss,
            "poisoning_active": False  # Not doing traditional poisoning
        }
        
        if self.anomaly_type in ["performance", "mixed"]:
            # Type 1: Extreme inconsistent performance (more aggressive)
            if random.random() < 0.6:
                # Very high accuracy but very high loss (clearly inconsistent)
                metrics["accuracy"] = min(0.95, true_accuracy + 0.4 * self.intensity)
                metrics["loss"] = max(true_loss, true_loss + 2.0 * self.intensity)
                logger.info(f"  Reporting EXTREME inconsistent metrics: acc={metrics['accuracy']:.3f}, loss={metrics['loss']:.3f}")
            
            # Type 2: Oscillating performance (more extreme)
            elif random.random() < 0.4:
                oscillation = 0.5 * self.intensity * np.sin(self.round_count * np.pi / 2)
                metrics["accuracy"] = max(0.05, min(0.95, true_accuracy + oscillation))
                metrics["loss"] = max(0.1, true_loss - oscillation * 0.5)
                logger.info(f"  Applying EXTREME performance oscillation: {oscillation:.3f}")
            
            # Type 3: Suspicious performance patterns
            elif random.random() < 0.3:
                # Performance that's too good for early rounds
                if self.round_count <= 3:
                    metrics["accuracy"] = 0.85 + 0.1 * self.intensity
                    metrics["loss"] = 0.2 + 0.1 * self.intensity
                    logger.info(f"  Reporting suspiciously good early performance")
                
                # Or performance that degrades suddenly
                else:
                    metrics["accuracy"] = max(0.1, true_accuracy - 0.3 * self.intensity)
                    metrics["loss"] = true_loss + 1.5 * self.intensity
                    logger.info(f"  Reporting sudden performance degradation")
        
        return metrics

def load_data(data_path):
    """Load and preprocess data."""
    try:
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        
        if df.isnull().sum().sum() > 0:
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing values: {df.shape}")
        
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' not found in dataset!")
            
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=ANOMALY_CLIENT_CONFIG["batch_size"], shuffle=True)
        
        logger.info(f"Created dataloader with {len(dataset)} samples and {X.shape[1]} features")
        return dataloader, X.shape[1]
    
    except Exception as e:
        logger.error(f"Error loading data: {str(e)}")
        raise

class AnomalousFraminghamClient(fl.client.NumPyClient):
    """Anomalous client that generates various anomalies for testing."""
    
    def __init__(self, model, dataloader, device, client_id, anomaly_config=None):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.global_params = None
        
        # Initialize anomaly generator
        if anomaly_config is None:
            anomaly_config = {
                "anomaly_type": ANOMALY_CLIENT_CONFIG["anomaly_type"],
                "intensity": ANOMALY_CLIENT_CONFIG["anomaly_intensity"],
                "frequency": ANOMALY_CLIENT_CONFIG["anomaly_frequency"]
            }
        
        self.anomaly_generator = AnomalyGenerator(**anomaly_config)
        
        logger.info(f"[ANOMALOUS] Client {client_id} initialized")
        logger.info(f"  Anomaly Type: {anomaly_config['anomaly_type']}")
        logger.info(f"  Intensity: {anomaly_config['intensity']}")
        logger.info(f"  Frequency: {anomaly_config['frequency']}")
        
    def get_parameters(self, config):
        """Get model parameters with potential anomalies."""
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]
        
        # Apply anomalies if decided for this round
        if self.anomaly_generator.should_introduce_anomaly():
            logger.info(f"[ANOMALY] Client {self.client_id} introducing anomalies...")
            params = self.anomaly_generator.apply_parameter_anomalies(params)
            
            # Log parameter statistics
            original_norm = sum(np.linalg.norm(p) for p in [val.detach().cpu().numpy() for val in self.model.parameters()])
            anomalous_norm = sum(np.linalg.norm(p) for p in params)
            logger.info(f"  Parameter norm: {original_norm:.6f} -> {anomalous_norm:.6f}")
        else:
            logger.info(f"[NORMAL] Client {self.client_id} behaving normally this round")
        
        return params
    
    def set_parameters(self, parameters):
        """Set model parameters."""
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")
    
    def fit(self, parameters, config):
        """Train with potential anomalies."""
        self.set_parameters(parameters)
        self.anomaly_generator.round_count += 1
        
        # Get anomalous training configuration
        anomaly_config = self.anomaly_generator.get_anomalous_training_config()
        
        # Apply anomalous training settings
        learning_rate = anomaly_config.get("learning_rate", ANOMALY_CLIENT_CONFIG["learning_rate"])
        process_partial = anomaly_config.get("process_partial_batches", False)
        partial_ratio = anomaly_config.get("partial_ratio", 1.0)
        skip_epochs = anomaly_config.get("skip_epochs", 0)
        
        if anomaly_config:
            logger.info(f"[ANOMALY] Client {self.client_id} using anomalous training config")
        
        self.model.train()
        criterion = nn.BCELoss()
        proximal_criterion = FedProxLoss(criterion, mu=ANOMALY_CLIENT_CONFIG["proximal_mu"])
        
        optimizer = torch.optim.Adam(
            self.model.parameters(), 
            lr=learning_rate,
            weight_decay=ANOMALY_CLIENT_CONFIG["weight_decay"]
        )
        
        total_loss = 0.0
        total_samples = 0
        correct = 0
        
        # Training with potential anomalies
        effective_epochs = max(1, ANOMALY_CLIENT_CONFIG["local_epochs"] - skip_epochs)
        
        for epoch in range(effective_epochs):
            epoch_loss = 0.0
            epoch_samples = 0
            
            for batch_idx, (X, y) in enumerate(self.dataloader):
                # Anomalous batch processing
                if process_partial and random.random() > partial_ratio:
                    continue  # Skip this batch
                
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                
                # Loss calculation
                loss = proximal_criterion(
                    y_pred, y, 
                    self.model.parameters(),
                    self.global_params
                )
                
                # Backward pass
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                # Update metrics
                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
                
                if batch_idx % 10 == 0:
                    logger.info(f"Client {self.client_id} - Epoch {epoch+1}/{effective_epochs} - Batch {batch_idx} - Loss: {loss.item():.4f}")
        
        # Calculate metrics
        avg_loss = total_loss / total_samples if total_samples > 0 else 0
        accuracy = correct / total_samples if total_samples > 0 else 0
        
        # Apply anomalous metric reporting
        anomalous_metrics = self.anomaly_generator.get_anomalous_metrics(accuracy, avg_loss)
        
        logger.info(f"[TRAINING] Client {self.client_id} training completed")
        logger.info(f"  True metrics: Loss={avg_loss:.4f}, Accuracy={accuracy:.4f}")
        logger.info(f"  Reported metrics: Loss={anomalous_metrics['loss']:.4f}, Accuracy={anomalous_metrics['accuracy']:.4f}")
        
        return self.get_parameters({}), total_samples, {
            "loss": float(anomalous_metrics["loss"]), 
            "accuracy": float(anomalous_metrics["accuracy"]),
            "client_id": str(self.client_id),
            "poisoning_active": False,  # Not traditional poisoning
            "anomaly_active": True,     # But anomalous behavior
            "anomaly_type": self.anomaly_generator.anomaly_type,
            "anomaly_intensity": self.anomaly_generator.intensity
        }
    
    def evaluate(self, parameters, config):
        """Evaluate with potential anomalies."""
        self.set_parameters(parameters)
        
        self.model.eval()
        criterion = nn.BCELoss()
        
        loss = 0.0
        total = 0
        correct = 0
        
        with torch.no_grad():
            for X, y in self.dataloader:
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                
                loss += batch_loss * X.size(0)
                total += X.size(0)
                
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
        
        avg_loss = loss / total if total > 0 else 0
        accuracy = correct / total if total > 0 else 0
        
        # Apply anomalous evaluation metrics
        anomalous_metrics = self.anomaly_generator.get_anomalous_metrics(accuracy, avg_loss)
        
        logger.info(f"[EVALUATION] Client {self.client_id} evaluation completed")
        logger.info(f"  True metrics: Loss={avg_loss:.4f}, Accuracy={accuracy:.4f}")
        logger.info(f"  Reported metrics: Loss={anomalous_metrics['loss']:.4f}, Accuracy={anomalous_metrics['accuracy']:.4f}")
        
        return float(anomalous_metrics["loss"]), total, {
            "accuracy": float(anomalous_metrics["accuracy"]),
            "client_id": str(self.client_id),
            "poisoning_active": False,
            "anomaly_active": True,
            "anomaly_type": self.anomaly_generator.anomaly_type
        }

def start_anomalous_client(
    client_id=0, 
    server_address=None, 
    anomaly_type="mixed",
    anomaly_intensity=0.7,
    anomaly_frequency=0.8
):
    """Initialize and start an anomalous client."""
    
    if server_address:
        ANOMALY_CLIENT_CONFIG["server_address"] = server_address
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")
    
    # Data file
    data_path = f"framingham_part{client_id+1}.csv"
    if not os.path.exists(data_path):
        logger.error(f"Data file {data_path} not found")
        return
    
    # Load data
    dataloader, input_size = load_data(data_path)
    
    # Initialize model
    model = HeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size: {input_size}")
    
    # Anomaly configuration
    anomaly_config = {
        "anomaly_type": anomaly_type,
        "intensity": anomaly_intensity,
        "frequency": anomaly_frequency
    }
    
    # Create anomalous client
    client = AnomalousFraminghamClient(
        model, dataloader, device, client_id, anomaly_config
    )
    
    # Display client information
    print(f"\n{'='*80}")
    print(f"⚠️ ANOMALOUS FRAMINGHAM CLIENT {client_id}")
    print(f"{'='*80}")
    print(f"Server:           {ANOMALY_CLIENT_CONFIG['server_address']}")
    print(f"Data file:        {data_path}")
    print(f"Device:           {device}")
    print(f"")
    print(f"Anomaly Configuration:")
    print(f"  Type:           {anomaly_type}")
    print(f"  Intensity:      {anomaly_intensity} (0.0-1.0)")
    print(f"  Frequency:      {anomaly_frequency} (probability per round)")
    print(f"")
    print(f"Anomaly Types:")
    print(f"  parameter:      Parameter distribution anomalies")
    print(f"  training:       Training behavior anomalies")
    print(f"  performance:    Performance reporting anomalies")
    print(f"  statistical:    Statistical pattern anomalies")
    print(f"  mixed:          Combination of all types")
    print(f"")
    print(f"⚠️  This client will exhibit anomalous behavior for testing!")
    print(f"    (Not traditional model poisoning)")
    print(f"{'='*80}")
    print(f"\nConnecting to server...\n")
    
    # Start client
    fl.client.start_client(
        server_address=ANOMALY_CLIENT_CONFIG["server_address"], 
        client=client
    )

if __name__ == "__main__":
    if 'ipykernel' in sys.modules:
        print("Running in Jupyter/IPython environment")
        # Configuration for Jupyter
        client_id = 5                    # Change this to match your setup
        anomaly_type = "mixed"           # "parameter", "training", "performance", "statistical", "mixed"
        anomaly_intensity = 0.9          # Increased to 0.9 for stronger detection
        anomaly_frequency = 1.0          # 100% frequency for testing
        
        print(f"⚠️ Starting ANOMALOUS client {client_id}")
        print(f"   Type: {anomaly_type}")
        print(f"   Intensity: {anomaly_intensity}")
        print(f"   Frequency: {anomaly_frequency}")
        
        start_anomalous_client(
            client_id=client_id,
            anomaly_type=anomaly_type,
            anomaly_intensity=anomaly_intensity,
            anomaly_frequency=anomaly_frequency
        )
    else:
        import argparse
        parser = argparse.ArgumentParser(description="Anomalous Framingham FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--type", type=str, default="mixed", 
                           choices=["parameter", "training", "performance", "statistical", "mixed"],
                           help="Type of anomaly to introduce")
        parser.add_argument("--intensity", type=float, default=0.7, help="Anomaly intensity (0.0-1.0)")
        parser.add_argument("--frequency", type=float, default=0.8, help="Anomaly frequency (0.0-1.0)")
        
        args = parser.parse_args()
        
        start_anomalous_client(
            client_id=args.id,
            server_address=args.server,
            anomaly_type=args.type,
            anomaly_intensity=args.intensity,
            anomaly_frequency=args.frequency
        )
# Out:
# 2025-05-24 22:45:37,489 - AnomalousClient - INFO - Using device: cuda
# 2025-05-24 22:45:37,496 - AnomalousClient - INFO - Loaded framingham_part6.csv with shape (1060, 16)
# 2025-05-24 22:45:37,498 - AnomalousClient - INFO - Class distribution: {0: 898, 1: 162}
# 2025-05-24 22:45:37,504 - AnomalousClient - INFO - Created dataloader with 1060 samples and 15 features
# 2025-05-24 22:45:37,507 - AnomalousClient - INFO - Model initialized with input size: 15
# 2025-05-24 22:45:37,508 - AnomalousClient - INFO - [ANOMALOUS] Client 5 initialized
# 2025-05-24 22:45:37,509 - AnomalousClient - INFO -   Anomaly Type: mixed
# 2025-05-24 22:45:37,509 - AnomalousClient - INFO -   Intensity: 0.9
# 2025-05-24 22:45:37,510 - AnomalousClient - INFO -   Frequency: 1.0
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 22:45:37,511 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 22:45:37,513 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 22:45:37,533 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 22:45:37,536 - flwr - DEBUG - ChannelConnectivity.READY
# Running in Jupyter/IPython environment
# ⚠️ Starting ANOMALOUS client 5
#    Type: mixed
#    Intensity: 0.9
#    Frequency: 1.0
#
# ================================================================================
# ⚠️ ANOMALOUS FRAMINGHAM CLIENT 5
# ================================================================================
# Server:           localhost:8080
# Data file:        framingham_part6.csv
# Device:           cuda
#
# Anomaly Configuration:
#   Type:           mixed
#   Intensity:      0.9 (0.0-1.0)
#   Frequency:      1.0 (probability per round)
#
# Anomaly Types:
#   parameter:      Parameter distribution anomalies
#   training:       Training behavior anomalies
#   performance:    Performance reporting anomalies
#   statistical:    Statistical pattern anomalies
#   mixed:          Combination of all types
#
# ⚠️  This client will exhibit anomalous behavior for testing!
#     (Not traditional model poisoning)
# ================================================================================
#
# Connecting to server...
# INFO :
# 2025-05-24 22:45:40,090 - flwr - INFO -
# INFO :      Received: train message 03388672-e75c-4b3e-815c-ac69abef5a8e
# 2025-05-24 22:45:40,093 - flwr - INFO - Received: train message 03388672-e75c-4b3e-815c-ac69abef5a8e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:40,093 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:40,111 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:40,114 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 22:45:40,116 - AnomalousClient - INFO -   Skipping 2 training epochs
# 2025-05-24 22:45:40,119 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:45:40,136 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 0 - Loss: 0.6825
# 2025-05-24 22:45:40,234 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 10 - Loss: 0.9208
# 2025-05-24 22:45:40,325 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 20 - Loss: 0.8054
# 2025-05-24 22:45:40,408 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 30 - Loss: 0.9275
# 2025-05-24 22:45:40,425 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: 0.450
# 2025-05-24 22:45:40,426 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:40,427 - AnomalousClient - INFO -   True metrics: Loss=0.8351, Accuracy=0.8226
# 2025-05-24 22:45:40,428 - AnomalousClient - INFO -   Reported metrics: Loss=0.6101, Accuracy=0.9500
# 2025-05-24 22:45:40,429 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:40,432 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:40,434 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (326 zeros, 36.0% sparse)
# 2025-05-24 22:45:40,435 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 22:45:40,435 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 22:45:40,436 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:40,438 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (25 zeros, 36.0% sparse)
# 2025-05-24 22:45:40,439 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:40,440 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:45:40,441 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:40,443 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (752 zeros, 36.0% sparse)
# 2025-05-24 22:45:40,446 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:40,447 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 22:45:40,448 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 22:45:40,449 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:45:40,450 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (9 zeros, 36.0% sparse)
# 2025-05-24 22:45:40,452 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 22:45:40,453 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:40,454 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (12 zeros, 36.0% sparse)
# 2025-05-24 22:45:40,455 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:40,455 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:40,455 - AnomalousClient - INFO -   Parameter norm: 16.931252 -> 55.457632
# INFO :      Sent reply
# 2025-05-24 22:45:40,461 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:41,091 - flwr - INFO -
# INFO :      Received: evaluate message ea168dcc-d55c-40b0-94ce-a3f2dcc58417
# 2025-05-24 22:45:41,093 - flwr - INFO - Received: evaluate message ea168dcc-d55c-40b0-94ce-a3f2dcc58417
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,095 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,100 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:41,149 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.406
# 2025-05-24 22:45:41,149 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:41,149 - AnomalousClient - INFO -   True metrics: Loss=0.6064, Accuracy=0.8472
# 2025-05-24 22:45:41,149 - AnomalousClient - INFO -   Reported metrics: Loss=2.4064, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:45:41,149 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:41,178 - flwr - INFO -
# INFO :      Received: train message f2cbc338-dade-4028-ae14-a72c9e983c0f
# 2025-05-24 22:45:41,181 - flwr - INFO - Received: train message f2cbc338-dade-4028-ae14-a72c9e983c0f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,185 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,191 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:41,192 - AnomalousClient - INFO -   Using anomalously low learning rate: 9.999999999999997e-06
# 2025-05-24 22:45:41,194 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:45:41,205 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.5729
# 2025-05-24 22:45:41,271 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.6048
# 2025-05-24 22:45:41,329 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.6299
# 2025-05-24 22:45:41,418 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.6081
# 2025-05-24 22:45:41,452 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.6028
# 2025-05-24 22:45:41,515 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.6101
# 2025-05-24 22:45:41,575 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.5860
# 2025-05-24 22:45:41,630 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.5983
# 2025-05-24 22:45:41,656 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.5996
# 2025-05-24 22:45:41,715 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.6081
# 2025-05-24 22:45:41,775 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.5880
# 2025-05-24 22:45:41,830 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.6234
# 2025-05-24 22:45:41,850 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.407
# 2025-05-24 22:45:41,851 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:41,852 - AnomalousClient - INFO -   True metrics: Loss=0.6067, Accuracy=0.8472
# 2025-05-24 22:45:41,854 - AnomalousClient - INFO -   Reported metrics: Loss=2.4067, Accuracy=0.9500
# 2025-05-24 22:45:41,855 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:41,858 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 22:45:41,858 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 22:45:41,858 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:41,861 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (714 zeros, 36.0% sparse)
# 2025-05-24 22:45:41,862 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 22:45:41,863 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:41,864 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:41,865 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:41,866 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:41,870 - AnomalousClient - INFO -   Parameter norm: 16.995706 -> 54.630943
# INFO :      Sent reply
# 2025-05-24 22:45:41,872 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:42,172 - flwr - INFO -
# INFO :      Received: evaluate message eb7ca7d8-51dc-4b09-9e2f-f32c572c87e7
# 2025-05-24 22:45:42,172 - flwr - INFO - Received: evaluate message eb7ca7d8-51dc-4b09-9e2f-f32c572c87e7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,175 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,178 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:42,239 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.414
# 2025-05-24 22:45:42,240 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:42,241 - AnomalousClient - INFO -   True metrics: Loss=0.6144, Accuracy=0.8019
# 2025-05-24 22:45:42,242 - AnomalousClient - INFO -   Reported metrics: Loss=2.4144, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:45:42,243 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:42,260 - flwr - INFO -
# INFO :      Received: train message b8d9c4cb-0f67-42d3-8c1a-799af6ae0aba
# 2025-05-24 22:45:42,264 - flwr - INFO - Received: train message b8d9c4cb-0f67-42d3-8c1a-799af6ae0aba
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,268 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,276 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:42,290 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.6216
# 2025-05-24 22:45:42,372 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.6247
# 2025-05-24 22:45:42,432 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.6294
# 2025-05-24 22:45:42,497 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.5938
# 2025-05-24 22:45:42,519 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.6202
# 2025-05-24 22:45:42,573 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.6164
# 2025-05-24 22:45:42,634 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.6015
# 2025-05-24 22:45:42,693 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.5803
# 2025-05-24 22:45:42,718 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.5758
# 2025-05-24 22:45:42,779 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.6132
# 2025-05-24 22:45:42,835 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.6119
# 2025-05-24 22:45:42,894 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.5864
# 2025-05-24 22:45:42,915 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.398
# 2025-05-24 22:45:42,916 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:42,916 - AnomalousClient - INFO -   True metrics: Loss=0.5980, Accuracy=0.8211
# 2025-05-24 22:45:42,917 - AnomalousClient - INFO -   Reported metrics: Loss=2.3980, Accuracy=0.9500
# 2025-05-24 22:45:42,920 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:42,921 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:42,922 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (393 zeros, 36.0% sparse)
# 2025-05-24 22:45:42,923 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 22:45:42,924 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:42,925 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:42,926 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:45:42,927 - AnomalousClient - INFO -   Applied artificial pattern to layer 1
# 2025-05-24 22:45:42,929 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:42,931 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:42,933 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (9 zeros, 36.0% sparse)
# 2025-05-24 22:45:42,934 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:42,935 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (8 zeros, 36.0% sparse)
# 2025-05-24 22:45:42,936 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:42,937 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 22:45:42,938 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:42,940 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:45:42,941 - AnomalousClient - INFO -   Parameter norm: 34.772167 -> 62.751219
# INFO :      Sent reply
# 2025-05-24 22:45:42,945 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:43,219 - flwr - INFO -
# INFO :      Received: evaluate message deb7a026-461c-44ea-919a-092035c104c4
# 2025-05-24 22:45:43,219 - flwr - INFO - Received: evaluate message deb7a026-461c-44ea-919a-092035c104c4
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,224 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,230 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:43,317 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.340
# 2025-05-24 22:45:43,318 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:43,319 - AnomalousClient - INFO -   True metrics: Loss=0.5400, Accuracy=0.8292
# 2025-05-24 22:45:43,320 - AnomalousClient - INFO -   Reported metrics: Loss=2.3400, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:45:43,322 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:43,338 - flwr - INFO -
# INFO :      Received: train message 5837db1a-eec5-4063-9345-1194a12e44ca
# 2025-05-24 22:45:43,339 - flwr - INFO - Received: train message 5837db1a-eec5-4063-9345-1194a12e44ca
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,342 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,347 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:43,349 - AnomalousClient - INFO -   Processing only 0.66 of each batch
# 2025-05-24 22:45:43,350 - AnomalousClient - INFO -   Skipping 2 training epochs
# 2025-05-24 22:45:43,352 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:45:43,428 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 20 - Loss: 0.5912
# 2025-05-24 22:45:43,473 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 30 - Loss: 0.5709
# 2025-05-24 22:45:43,482 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.347
# 2025-05-24 22:45:43,482 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:43,482 - AnomalousClient - INFO -   True metrics: Loss=0.5468, Accuracy=0.8172
# 2025-05-24 22:45:43,482 - AnomalousClient - INFO -   Reported metrics: Loss=2.3468, Accuracy=0.9500
# 2025-05-24 22:45:43,489 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:43,489 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:43,494 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 22:45:43,495 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (25 zeros, 36.0% sparse)
# 2025-05-24 22:45:43,496 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:45:43,498 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (734 zeros, 36.0% sparse)
# 2025-05-24 22:45:43,501 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 22:45:43,503 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (12 zeros, 36.0% sparse)
# 2025-05-24 22:45:43,504 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 22:45:43,506 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:43,507 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:43,508 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:43,509 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:45:43,511 - AnomalousClient - INFO -   Parameter norm: 46.563970 -> 63.175225
# INFO :      Sent reply
# 2025-05-24 22:45:43,513 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:44,217 - flwr - INFO -
# INFO :      Received: evaluate message d5430e84-fbb3-4185-a337-e71b40f738d0
# 2025-05-24 22:45:44,220 - flwr - INFO - Received: evaluate message d5430e84-fbb3-4185-a337-e71b40f738d0
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,220 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,226 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:44,288 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:44,288 - AnomalousClient - INFO -   True metrics: Loss=0.5271, Accuracy=0.8085
# 2025-05-24 22:45:44,288 - AnomalousClient - INFO -   Reported metrics: Loss=0.5271, Accuracy=0.8085
# INFO :      Sent reply
# 2025-05-24 22:45:44,293 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:44,313 - flwr - INFO -
# INFO :      Received: train message 7f16964c-db86-49bf-b7bb-b8a7e18c17b5
# 2025-05-24 22:45:44,316 - flwr - INFO - Received: train message 7f16964c-db86-49bf-b7bb-b8a7e18c17b5
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,319 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,325 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:44,326 - AnomalousClient - INFO -   Using anomalously low learning rate: 9.999999999999997e-06
# 2025-05-24 22:45:44,328 - AnomalousClient - INFO -   Processing only 0.66 of each batch
# 2025-05-24 22:45:44,329 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:45:44,339 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.5448
# 2025-05-24 22:45:44,379 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.5418
# 2025-05-24 22:45:44,420 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.5840
# 2025-05-24 22:45:44,460 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.5440
# 2025-05-24 22:45:44,531 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.4947
# 2025-05-24 22:45:44,588 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.5094
# 2025-05-24 22:45:44,615 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.6134
# 2025-05-24 22:45:44,657 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.4750
# 2025-05-24 22:45:44,725 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.5608
# 2025-05-24 22:45:44,741 - AnomalousClient - INFO -   Reporting sudden performance degradation
# 2025-05-24 22:45:44,741 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:44,743 - AnomalousClient - INFO -   True metrics: Loss=0.5395, Accuracy=0.8066
# 2025-05-24 22:45:44,744 - AnomalousClient - INFO -   Reported metrics: Loss=1.8895, Accuracy=0.5366
# 2025-05-24 22:45:44,746 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:44,747 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:44,748 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 22:45:44,749 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 22:45:44,750 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 22:45:44,752 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:44,753 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (24 zeros, 36.0% sparse)
# 2025-05-24 22:45:44,754 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:44,756 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:45:44,756 - AnomalousClient - INFO -   Applied artificial pattern to layer 1
# 2025-05-24 22:45:44,758 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:44,759 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (744 zeros, 36.0% sparse)
# 2025-05-24 22:45:44,760 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:44,761 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 22:45:44,762 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (16 zeros, 36.0% sparse)
# 2025-05-24 22:45:44,764 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 22:45:44,767 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:44,767 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (10 zeros, 36.0% sparse)
# 2025-05-24 22:45:44,767 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:44,767 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 22:45:44,771 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:45:44,774 - AnomalousClient - INFO -   Parameter norm: 48.532606 -> 119.053165
# INFO :      Sent reply
# 2025-05-24 22:45:44,776 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:45,210 - flwr - INFO -
# INFO :      Received: evaluate message d3d0da96-bf78-4e1e-b415-09baf766270c
# 2025-05-24 22:45:45,212 - flwr - INFO - Received: evaluate message d3d0da96-bf78-4e1e-b415-09baf766270c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,212 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,222 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:45,313 - AnomalousClient - INFO -   Reporting sudden performance degradation
# 2025-05-24 22:45:45,314 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:45,314 - AnomalousClient - INFO -   True metrics: Loss=0.5163, Accuracy=0.7821
# 2025-05-24 22:45:45,314 - AnomalousClient - INFO -   Reported metrics: Loss=1.8663, Accuracy=0.5121
# INFO :      Sent reply
# 2025-05-24 22:45:45,314 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:45,342 - flwr - INFO -
# INFO :      Received: train message d4a49bfa-c145-47eb-a13c-7452358764d2
# 2025-05-24 22:45:45,344 - flwr - INFO - Received: train message d4a49bfa-c145-47eb-a13c-7452358764d2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,347 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,352 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:45,362 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.7782
# 2025-05-24 22:45:45,434 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.4322
# 2025-05-24 22:45:45,490 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.5275
# 2025-05-24 22:45:45,539 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.5724
# 2025-05-24 22:45:45,567 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.5805
# 2025-05-24 22:45:45,621 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.5543
# 2025-05-24 22:45:45,678 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.4576
# 2025-05-24 22:45:45,734 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.5029
# 2025-05-24 22:45:45,760 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.5133
# 2025-05-24 22:45:45,813 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.3707
# 2025-05-24 22:45:45,870 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.4722
# 2025-05-24 22:45:45,924 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.5120
# 2025-05-24 22:45:45,940 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.313
# 2025-05-24 22:45:45,940 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:45,940 - AnomalousClient - INFO -   True metrics: Loss=0.5126, Accuracy=0.8148
# 2025-05-24 22:45:45,940 - AnomalousClient - INFO -   Reported metrics: Loss=2.3126, Accuracy=0.9500
# 2025-05-24 22:45:45,946 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:45,947 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:45,948 - AnomalousClient - INFO -   Applied artificial pattern to layer 1
# 2025-05-24 22:45:45,949 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:45,950 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (741 zeros, 36.0% sparse)
# 2025-05-24 22:45:45,951 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:45,952 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:45,953 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:45,954 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:45,955 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:45:45,958 - AnomalousClient - INFO -   Parameter norm: 73.074983 -> 106.705043
# INFO :      Sent reply
# 2025-05-24 22:45:45,961 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:46,262 - flwr - INFO -
# INFO :      Received: evaluate message 12eead73-368b-4a3d-a838-08bfdb48999b
# 2025-05-24 22:45:46,265 - flwr - INFO - Received: evaluate message 12eead73-368b-4a3d-a838-08bfdb48999b
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,269 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,274 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:46,351 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=2.383
# 2025-05-24 22:45:46,351 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:46,355 - AnomalousClient - INFO -   True metrics: Loss=0.5830, Accuracy=0.8028
# 2025-05-24 22:45:46,356 - AnomalousClient - INFO -   Reported metrics: Loss=2.3830, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:45:46,358 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:46,381 - flwr - INFO -
# INFO :      Received: train message aa5aa566-4997-48ec-93b2-da76de9c98b6
# 2025-05-24 22:45:46,383 - flwr - INFO - Received: train message aa5aa566-4997-48ec-93b2-da76de9c98b6
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,385 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,390 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:46,399 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 0.6919
# 2025-05-24 22:45:46,462 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 0.8006
# 2025-05-24 22:45:46,518 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 0.5646
# 2025-05-24 22:45:46,574 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 0.3864
# 2025-05-24 22:45:46,599 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 0.9489
# 2025-05-24 22:45:46,650 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 0.4765
# 2025-05-24 22:45:46,712 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 0.4463
# 2025-05-24 22:45:46,769 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 0.5417
# 2025-05-24 22:45:46,797 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 0.6039
# 2025-05-24 22:45:46,851 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 0.8799
# 2025-05-24 22:45:46,908 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 0.7470
# 2025-05-24 22:45:46,963 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 0.8955
# 2025-05-24 22:45:46,985 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: -0.450
# 2025-05-24 22:45:46,986 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:46,987 - AnomalousClient - INFO -   True metrics: Loss=0.7251, Accuracy=0.8022
# 2025-05-24 22:45:46,988 - AnomalousClient - INFO -   Reported metrics: Loss=0.9501, Accuracy=0.3522
# 2025-05-24 22:45:46,989 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:46,991 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 22:45:46,991 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 22:45:46,992 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:46,994 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (22 zeros, 36.0% sparse)
# 2025-05-24 22:45:46,995 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:46,995 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:46,995 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:46,995 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:45:47,001 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (16 zeros, 36.0% sparse)
# 2025-05-24 22:45:47,002 - AnomalousClient - INFO -   Added systematic bias to layer 3 (bias=-0.450)
# 2025-05-24 22:45:47,003 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:47,005 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 22:45:47,006 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:47,006 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:47,009 - AnomalousClient - INFO -   Parameter norm: 87.676160 -> 204.089308
# INFO :      Sent reply
# 2025-05-24 22:45:47,010 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:47,344 - flwr - INFO -
# INFO :      Received: evaluate message cc6c6d13-fa2e-4a81-b5ee-1f415b316343
# 2025-05-24 22:45:47,349 - flwr - INFO - Received: evaluate message cc6c6d13-fa2e-4a81-b5ee-1f415b316343
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,351 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,356 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:47,417 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=5.538
# 2025-05-24 22:45:47,418 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:47,418 - AnomalousClient - INFO -   True metrics: Loss=3.7384, Accuracy=0.7642
# 2025-05-24 22:45:47,420 - AnomalousClient - INFO -   Reported metrics: Loss=5.5384, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:45:47,422 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:47,437 - flwr - INFO -
# INFO :      Received: train message 5d93f9fe-a95b-4307-b4ae-c1a4739ec370
# 2025-05-24 22:45:47,439 - flwr - INFO - Received: train message 5d93f9fe-a95b-4307-b4ae-c1a4739ec370
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,441 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,445 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:47,447 - AnomalousClient - INFO -   Skipping 2 training epochs
# 2025-05-24 22:45:47,448 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:45:47,458 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 0 - Loss: 0.8458
# 2025-05-24 22:45:47,518 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 10 - Loss: 7.2378
# 2025-05-24 22:45:47,577 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 20 - Loss: 7.4884
# 2025-05-24 22:45:47,636 - AnomalousClient - INFO - Client 5 - Epoch 1/1 - Batch 30 - Loss: 9.7955
# 2025-05-24 22:45:47,655 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: -0.000
# 2025-05-24 22:45:47,656 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:47,657 - AnomalousClient - INFO -   True metrics: Loss=6.8831, Accuracy=0.7443
# 2025-05-24 22:45:47,659 - AnomalousClient - INFO -   Reported metrics: Loss=6.8831, Accuracy=0.7443
# 2025-05-24 22:45:47,660 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:47,662 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:47,663 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (367 zeros, 36.0% sparse)
# 2025-05-24 22:45:47,664 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:47,665 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:47,666 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:47,668 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (719 zeros, 36.0% sparse)
# 2025-05-24 22:45:47,668 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:45:47,668 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (11 zeros, 36.0% sparse)
# 2025-05-24 22:45:47,668 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:47,668 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:47,674 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:47,676 - AnomalousClient - INFO -   Parameter norm: 144.506119 -> 142.685786
# INFO :      Sent reply
# 2025-05-24 22:45:47,678 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:48,338 - flwr - INFO -
# INFO :      Received: evaluate message ed72c678-6eec-4740-9d1b-b408df9496d6
# 2025-05-24 22:45:48,338 - flwr - INFO - Received: evaluate message ed72c678-6eec-4740-9d1b-b408df9496d6
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:48,343 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:48,344 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:48,402 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=9.540
# 2025-05-24 22:45:48,402 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:48,404 - AnomalousClient - INFO -   True metrics: Loss=7.7397, Accuracy=0.6962
# 2025-05-24 22:45:48,405 - AnomalousClient - INFO -   Reported metrics: Loss=9.5397, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:45:48,405 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:48,423 - flwr - INFO -
# INFO :      Received: train message 3b167d84-788e-44ea-8f20-ccad858b9559
# 2025-05-24 22:45:48,425 - flwr - INFO - Received: train message 3b167d84-788e-44ea-8f20-ccad858b9559
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:48,427 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:48,435 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:48,450 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 20.1331
# 2025-05-24 22:45:48,546 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 3.9921
# 2025-05-24 22:45:48,600 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 16.2527
# 2025-05-24 22:45:48,662 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 9.9230
# 2025-05-24 22:45:48,687 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 7.7890
# 2025-05-24 22:45:48,746 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 13.3981
# 2025-05-24 22:45:48,802 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 6.5290
# 2025-05-24 22:45:48,859 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 6.9998
# 2025-05-24 22:45:48,882 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 10.3705
# 2025-05-24 22:45:48,938 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 9.8490
# 2025-05-24 22:45:48,990 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 10.1967
# 2025-05-24 22:45:49,050 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 4.1014
# 2025-05-24 22:45:49,065 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=11.227
# 2025-05-24 22:45:49,069 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:49,070 - AnomalousClient - INFO -   True metrics: Loss=9.4268, Accuracy=0.7031
# 2025-05-24 22:45:49,072 - AnomalousClient - INFO -   Reported metrics: Loss=11.2268, Accuracy=0.9500
# 2025-05-24 22:45:49,073 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:49,074 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 22:45:49,076 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 22:45:49,077 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:49,078 - AnomalousClient - INFO -   Applied STRONG amplification to layer 1 (factor=2.35)
# 2025-05-24 22:45:49,079 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:49,080 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (715 zeros, 36.0% sparse)
# 2025-05-24 22:45:49,081 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:49,081 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 22:45:49,083 - AnomalousClient - INFO -   Applied artificial pattern to layer 2
# 2025-05-24 22:45:49,085 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:45:49,086 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (10 zeros, 36.0% sparse)
# 2025-05-24 22:45:49,087 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 22:45:49,087 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 4 (12 zeros, 36.0% sparse)
# ...
# INFO :
# 2025-05-24 22:45:57,883 - flwr - INFO -
# INFO :      Received: train message 6064c609-8c96-4bf0-8e62-a26fdf207ce9
# 2025-05-24 22:45:57,885 - flwr - INFO - Received: train message 6064c609-8c96-4bf0-8e62-a26fdf207ce9
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:57,887 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:57,894 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:57,913 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 12.6687
# 2025-05-24 22:45:58,003 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 12.7444
# 2025-05-24 22:45:58,065 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 20 - Loss: 9.6751
# 2025-05-24 22:45:58,121 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 16.1484
# 2025-05-24 22:45:58,148 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 3.5563
# 2025-05-24 22:45:58,201 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 6.5908
# 2025-05-24 22:45:58,265 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 9.6732
# 2025-05-24 22:45:58,313 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 7.0890
# 2025-05-24 22:45:58,345 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 19.0967
# 2025-05-24 22:45:58,410 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 12.8031
# 2025-05-24 22:45:58,475 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 9.6736
# 2025-05-24 22:45:58,537 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 9.7361
# 2025-05-24 22:45:58,556 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=11.087
# 2025-05-24 22:45:58,557 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:58,558 - AnomalousClient - INFO -   True metrics: Loss=9.2872, Accuracy=0.7881
# 2025-05-24 22:45:58,559 - AnomalousClient - INFO -   Reported metrics: Loss=11.0872, Accuracy=0.9500
# 2025-05-24 22:45:58,561 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:58,562 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:58,565 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 0 (355 zeros, 36.0% sparse)
# 2025-05-24 22:45:58,566 - AnomalousClient - INFO -   Applied artificial pattern to layer 0
# 2025-05-24 22:45:58,567 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:58,568 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:45:58,569 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:58,571 - AnomalousClient - INFO -   Applied STRONG amplification to layer 2 (factor=2.35)
# 2025-05-24 22:45:58,572 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:45:58,574 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (11 zeros, 36.0% sparse)
# 2025-05-24 22:45:58,575 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 22:45:58,577 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:58,578 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:58,580 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:58,581 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:45:58,583 - AnomalousClient - INFO -   Parameter norm: 1097.439345 -> 1946.184349
# INFO :      Sent reply
# 2025-05-24 22:45:58,587 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:58,897 - flwr - INFO -
# INFO :      Received: evaluate message 92a6161e-6f3e-4f59-b0f4-9c14a480df4a
# 2025-05-24 22:45:58,899 - flwr - INFO - Received: evaluate message 92a6161e-6f3e-4f59-b0f4-9c14a480df4a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:58,899 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:58,906 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:58,976 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:45:58,976 - AnomalousClient - INFO -   True metrics: Loss=8.5991, Accuracy=0.7896
# 2025-05-24 22:45:58,976 - AnomalousClient - INFO -   Reported metrics: Loss=8.5991, Accuracy=0.7896
# INFO :      Sent reply
# 2025-05-24 22:45:58,981 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:58,997 - flwr - INFO -
# INFO :      Received: train message 5d0b59e9-934e-47c5-a447-dcba1286ba1c
# 2025-05-24 22:45:58,999 - flwr - INFO - Received: train message 5d0b59e9-934e-47c5-a447-dcba1286ba1c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,001 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,006 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:45:59,008 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 22:45:59,009 - AnomalousClient - INFO -   Processing only 0.66 of each batch
# 2025-05-24 22:45:59,011 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:45:59,019 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 0 - Loss: 12.8626
# 2025-05-24 22:45:59,097 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 10 - Loss: 16.0453
# 2025-05-24 22:45:59,182 - AnomalousClient - INFO - Client 5 - Epoch 1/3 - Batch 30 - Loss: 25.3593
# 2025-05-24 22:45:59,202 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 19.3966
# 2025-05-24 22:45:59,287 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 10.0029
# 2025-05-24 22:45:59,365 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 16.6796
# 2025-05-24 22:45:59,447 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 20 - Loss: 16.9285
# 2025-05-24 22:45:59,485 - AnomalousClient - INFO -   Applying EXTREME performance oscillation: -0.450
# 2025-05-24 22:45:59,486 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:45:59,486 - AnomalousClient - INFO -   True metrics: Loss=14.7189, Accuracy=0.7445
# 2025-05-24 22:45:59,487 - AnomalousClient - INFO -   Reported metrics: Loss=14.9439, Accuracy=0.2945
# 2025-05-24 22:45:59,491 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:45:59,492 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:45:59,495 - AnomalousClient - INFO -   Applied STRONG amplification to layer 0 (factor=2.35)
# 2025-05-24 22:45:59,497 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:45:59,498 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (28 zeros, 36.0% sparse)
# 2025-05-24 22:45:59,500 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:45:59,502 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 2 (scale=0.270)
# 2025-05-24 22:45:59,506 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 2 (754 zeros, 36.0% sparse)
# 2025-05-24 22:45:59,507 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:45:59,508 - AnomalousClient - INFO -   Applied STRONG amplification to layer 3 (factor=2.35)
# 2025-05-24 22:45:59,510 - AnomalousClient - INFO -   Added systematic bias to layer 3 (bias=-0.450)
# 2025-05-24 22:45:59,511 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 4 (scale=0.270)
# 2025-05-24 22:45:59,513 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:45:59,515 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 22:45:59,516 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 5 (scale=0.270)
# 2025-05-24 22:45:59,518 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 5 (0 zeros, 36.0% sparse)
# 2025-05-24 22:45:59,519 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:45:59,522 - AnomalousClient - INFO -   Parameter norm: 1509.926631 -> 1871.915183
# INFO :      Sent reply
# 2025-05-24 22:45:59,524 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:59,950 - flwr - INFO -
# INFO :      Received: evaluate message e895fcd5-0b9c-4685-a0f0-81458134202a
# 2025-05-24 22:45:59,952 - flwr - INFO - Received: evaluate message e895fcd5-0b9c-4685-a0f0-81458134202a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,955 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,960 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:46:00,046 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=10.399
# 2025-05-24 22:46:00,046 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:46:00,047 - AnomalousClient - INFO -   True metrics: Loss=8.5991, Accuracy=0.7896
# 2025-05-24 22:46:00,048 - AnomalousClient - INFO -   Reported metrics: Loss=10.3991, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:46:00,049 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:46:00,065 - flwr - INFO -
# INFO :      Received: train message 37f91722-364e-4b0e-8db4-c91de31bb6b8
# 2025-05-24 22:46:00,067 - flwr - INFO - Received: train message 37f91722-364e-4b0e-8db4-c91de31bb6b8
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:00,070 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:00,074 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:46:00,075 - AnomalousClient - INFO -   Using anomalously high learning rate: 0.09000000000000001
# 2025-05-24 22:46:00,077 - AnomalousClient - INFO -   Processing only 0.66 of each batch
# 2025-05-24 22:46:00,078 - AnomalousClient - INFO - [ANOMALY] Client 5 using anomalous training config
# 2025-05-24 22:46:00,229 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 0 - Loss: 12.7363
# 2025-05-24 22:46:00,274 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 10 - Loss: 16.0135
# 2025-05-24 22:46:00,325 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 20 - Loss: 9.7640
# 2025-05-24 22:46:00,366 - AnomalousClient - INFO - Client 5 - Epoch 2/3 - Batch 30 - Loss: 19.1255
# 2025-05-24 22:46:00,385 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 0 - Loss: 19.3493
# 2025-05-24 22:46:00,413 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 10 - Loss: 12.7852
# 2025-05-24 22:46:00,497 - AnomalousClient - INFO - Client 5 - Epoch 3/3 - Batch 30 - Loss: 22.2901
# 2025-05-24 22:46:00,510 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=17.535
# 2025-05-24 22:46:00,515 - AnomalousClient - INFO - [TRAINING] Client 5 training completed
# 2025-05-24 22:46:00,517 - AnomalousClient - INFO -   True metrics: Loss=15.7354, Accuracy=0.7355
# 2025-05-24 22:46:00,519 - AnomalousClient - INFO -   Reported metrics: Loss=17.5354, Accuracy=0.9500
# 2025-05-24 22:46:00,521 - AnomalousClient - INFO - [ANOMALY] Client 5 introducing anomalies...
# 2025-05-24 22:46:00,522 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 0 (scale=0.270)
# 2025-05-24 22:46:00,523 - AnomalousClient - INFO -   Added systematic bias to layer 0 (bias=-0.450)
# 2025-05-24 22:46:00,525 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 1 (scale=0.270)
# 2025-05-24 22:46:00,526 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 1 (25 zeros, 36.0% sparse)
# 2025-05-24 22:46:00,527 - AnomalousClient - INFO -   Added systematic bias to layer 1 (bias=-0.450)
# 2025-05-24 22:46:00,528 - AnomalousClient - INFO -   Added systematic bias to layer 2 (bias=-0.450)
# 2025-05-24 22:46:00,529 - AnomalousClient - INFO -   Applied STRONG structured noise to layer 3 (scale=0.270)
# 2025-05-24 22:46:00,531 - AnomalousClient - INFO -   Applied AGGRESSIVE sparsity to layer 3 (9 zeros, 36.0% sparse)
# 2025-05-24 22:46:00,532 - AnomalousClient - INFO -   Applied STRONG amplification to layer 4 (factor=2.35)
# 2025-05-24 22:46:00,533 - AnomalousClient - INFO -   Added systematic bias to layer 4 (bias=0.450)
# 2025-05-24 22:46:00,536 - AnomalousClient - INFO -   Added systematic bias to layer 5 (bias=-0.450)
# 2025-05-24 22:46:00,538 - AnomalousClient - INFO -   Parameter norm: 1509.478122 -> 1724.511312
# INFO :      Sent reply
# 2025-05-24 22:46:00,540 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:46:01,052 - flwr - INFO -
# INFO :      Received: evaluate message 7bf973df-17e6-4912-928f-4fb50785c21e
# 2025-05-24 22:46:01,054 - flwr - INFO - Received: evaluate message 7bf973df-17e6-4912-928f-4fb50785c21e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:01,056 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:01,059 - AnomalousClient - INFO - Client 5: parameters updated from server
# 2025-05-24 22:46:01,128 - AnomalousClient - INFO -   Reporting EXTREME inconsistent metrics: acc=0.950, loss=9.147
# 2025-05-24 22:46:01,133 - AnomalousClient - INFO - [EVALUATION] Client 5 evaluation completed
# 2025-05-24 22:46:01,134 - AnomalousClient - INFO -   True metrics: Loss=7.3470, Accuracy=0.8085
# 2025-05-24 22:46:01,135 - AnomalousClient - INFO -   Reported metrics: Loss=9.1470, Accuracy=0.9500
# INFO :      Sent reply
# 2025-05-24 22:46:01,135 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:46:06,439 - flwr - INFO -
# INFO :      Received: reconnect message 9b307d31-3ccc-41ff-81f7-3a8e648c8c89
# 2025-05-24 22:46:06,441 - flwr - INFO - Received: reconnect message 9b307d31-3ccc-41ff-81f7-3a8e648c8c89
# 2025-05-24 22:46:06,479 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 22:46:06,482 - flwr - INFO - Disconnect and shut down
