# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import sys
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("FraminghamClient")

# Client configuration
CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01  # FedProx hyperparameter (controls the proximal term strength)
}

# Model for Framingham Heart Study data
class HeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super(HeartDiseaseModel, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

# FedProx Loss Function
class FedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super(FedProxLoss, self).__init__()
        self.base_criterion = base_criterion
        self.mu = mu  # Proximal term coefficient
        
    def forward(self, y_pred, y_true, model_params, global_params):
        # Calculate the base loss (e.g., BCE loss)
        base_loss = self.base_criterion(y_pred, y_true)
        
        # Calculate the proximal term if global parameters are provided
        proximal_term = 0.0
        if global_params is not None:
            # Sum up the squared L2 norm of the difference between local and global model parameters
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
                
            # Add the weighted proximal term to the base loss
            loss = base_loss + (self.mu / 2) * proximal_term
            return loss
        
        # If no global parameters are provided, just return the base loss
        return base_loss

# Load and preprocess Framingham data
def load_data(data_path):
    """Load and preprocess Framingham Heart Study data"""
    try:
        # Read CSV data
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        
        # Check for missing values
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Found {missing_values} missing values, dropping rows with missing values")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing values: {df.shape}")
        
        # Ensure the target column exists
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' not found in dataset!")
            
        # Split features and target
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        
        # Show class distribution
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        
        # Standardize features
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        # Convert to tensors
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        
        # Create dataset and dataloader
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        
        logger.info(f"Created dataloader with {len(dataset)} samples and {X.shape[1]} features")
        return dataloader, X.shape[1]
    
    except Exception as e:
        logger.error(f"Error loading data: {str(e)}")
        raise

# Client class for Federated Learning with FedProx
class FraminghamClient(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.global_params = None  # Store global model parameters for FedProx
        logger.info(f"Initialized client with device: {device}")
        
    def get_parameters(self, config):
        """Get model parameters as a list of NumPy arrays"""
        # Using detach() to prevent gradient error
        return [val.detach().cpu().numpy() for val in self.model.parameters()]
    
    def set_parameters(self, parameters):
        """Set model parameters from a list of NumPy arrays"""
        # Convert to torch tensors
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        
        # Update model
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info("Parameters updated from server")
        
    def fit(self, parameters, config):
        """Train the model on local data with FedProx"""
        # Update model with server parameters
        self.set_parameters(parameters)
        
        # Train the model
        self.model.train()
        
        # Standard loss function
        criterion = nn.BCELoss()
        
        # FedProx loss function
        proximal_criterion = FedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        
        optimizer = torch.optim.Adam(
            self.model.parameters(), 
            lr=CLIENT_CONFIG["learning_rate"],
            weight_decay=CLIENT_CONFIG["weight_decay"]
        )
        
        # Metrics for tracking
        total_loss = 0.0
        total_samples = 0
        correct = 0
        
        # Train for multiple epochs
        for epoch in range(CLIENT_CONFIG["local_epochs"]):
            epoch_loss = 0.0
            epoch_samples = 0
            
            for batch_idx, (X, y) in enumerate(self.dataloader):
                # Move tensors to device
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                
                # Calculate loss with proximal term
                loss = proximal_criterion(
                    y_pred, 
                    y, 
                    self.model.parameters(),  # Current model parameters
                    self.global_params        # Global model parameters
                )
                
                # Backward pass
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                # Update metrics
                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
                
                # Log progress occasionally
                if batch_idx % 5 == 0:
                    logger.info(
                        f"Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - "
                        f"Batch {batch_idx}/{len(self.dataloader)} - "
                        f"Loss: {loss.item():.4f}"
                    )
            
            # Log epoch metrics
            logger.info(
                f"Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} completed - "
                f"Loss: {epoch_loss/epoch_samples:.4f}"
            )
        
        # Calculate final metrics
        avg_loss = total_loss / total_samples if total_samples > 0 else 0
        accuracy = correct / total_samples if total_samples > 0 else 0
        
        logger.info(f"Training completed - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        
        # Return updated model parameters and metrics
        return self.get_parameters({}), total_samples, {"loss": float(avg_loss), "accuracy": float(accuracy)}
    
    def evaluate(self, parameters, config):
        """Evaluate the model on local data"""
        # Update model with server parameters
        self.set_parameters(parameters)
        
        # Evaluate the model
        self.model.eval()
        criterion = nn.BCELoss()
        
        loss = 0.0
        total = 0
        correct = 0
        
        with torch.no_grad():
            for X, y in self.dataloader:
                # Move tensors to device
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                
                # Update metrics
                loss += batch_loss * X.size(0)
                total += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
        
        # Calculate final metrics
        avg_loss = loss / total if total > 0 else 0
        accuracy = correct / total if total > 0 else 0
        
        logger.info(f"Evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        
        # Return metrics
        return float(avg_loss), total, {"accuracy": float(accuracy)}

def start_client(client_id=0, server_address=None):
    """Initialize and start a client"""
    # Update server address if provided
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address
    
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")
    
    # Determine which data file to use based on client ID
    data_path = f"framingham_part{client_id+1}.csv"
    
    # Try alternative naming if file doesn't exist
    if not os.path.exists(data_path):
        alternative_path = f"framingham_part{client_id+1}.csv"
        if os.path.exists(alternative_path):
            data_path = alternative_path
        else:
            logger.error(f"Data file {data_path} not found")
            return
    
    # Load data
    dataloader, input_size = load_data(data_path)
    
    # Initialize model
    model = HeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size: {input_size}")
    
    # Create client
    client = FraminghamClient(model, dataloader, device)
    
    # Start client
    logger.info(f"Starting client {client_id} and connecting to {CLIENT_CONFIG['server_address']}")
    
    print(f"\n===== Framingham Heart Study FL Client {client_id} (FedProx) =====")
    print(f"Server:        {CLIENT_CONFIG['server_address']}")
    print(f"Data file:     {data_path}")
    print(f"Local epochs:  {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:    {CLIENT_CONFIG['batch_size']}")
    print(f"Proximal mu:   {CLIENT_CONFIG['proximal_mu']}")
    print(f"Device:        {device}")
    print("=================================================")
    print(f"\nConnecting to server...\n")
    
    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

# For Jupyter usage
if __name__ == "__main__":
    # Check if running in Jupyter
    if 'ipykernel' in sys.modules:
        print("Running in Jupyter/IPython environment")
        # Default to client ID 0, can be changed by user
        start_client(client_id=2)
    else:
        # For command line use
        import argparse
        parser = argparse.ArgumentParser(description="Framingham Heart Study FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID (0, 1, or 2)")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--mu", type=float, default=0.01, help="FedProx proximal term strength")
        
        args = parser.parse_args()
        
        if args.id not in [0, 1, 2]:
            logger.error("Client ID must be 0, 1, or 2")
        else:
            try:
                # Set FedProx hyperparameter
                CLIENT_CONFIG["proximal_mu"] = args.mu
                
                start_client(args.id, args.server)
            except Exception as e:
                logger.error(f"Client failed: {str(e)}")

# %% [markdown]
# test versions

# %% [markdown]
# test version clinet 2 cuurently running

# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("DP_SA_FraminghamClient")

CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01,

    # Differential Privacy parameters
    "dp_enabled": True,
    "dp_noise_multiplier": 1.0,
    "dp_max_grad_norm": 1.0,
    "dp_epsilon": 8.0,
    "dp_delta": 1e-5,

    # Secure Aggregation parameters
    "sa_enabled": True,
    "sa_noise_scale": 1e-3,

    # Additional security flags
    "smpc_enabled": False,
    "he_enabled": False,
}

class DifferentialPrivacyMechanism:
    def __init__(self, noise_multiplier, max_grad_norm, epsilon, delta):
        self.noise_multiplier = noise_multiplier
        self.max_grad_norm = max_grad_norm
        self.epsilon = epsilon
        self.delta = delta
        logger.info(f"DP initialized: ε={epsilon}, δ={delta}, noise_multiplier={noise_multiplier}")

    def clip_gradients(self, model):
        total_norm = 0.0
        for param in model.parameters():
            if param.grad is not None:
                param_norm = param.grad.data.norm(2)
                total_norm += param_norm.item() ** 2
        total_norm = total_norm ** 0.5

        clip_coef = self.max_grad_norm / (total_norm + 1e-6)
        if clip_coef < 1:
            for param in model.parameters():
                if param.grad is not None:
                    param.grad.data.mul_(clip_coef)
        return total_norm

    def add_noise(self, model):
        noise_scale = self.noise_multiplier * self.max_grad_norm
        for param in model.parameters():
            if param.grad is not None:
                noise = torch.normal(0, noise_scale, size=param.grad.shape, device=param.grad.device)
                param.grad.data.add_(noise)

class SecureAggregation:
    def __init__(self, noise_scale=1e-3):
        self.noise_scale = noise_scale

    def add_random_mask(self, parameters):
        masked_params = []
        for param in parameters:
            mask = np.random.normal(0, self.noise_scale, param.shape)
            masked_params.append(param + mask)
        return masked_params

class PrivacyEnhancedHeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

class PrivacyAwareFedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super().__init__()
        self.base_criterion = base_criterion
        self.mu = mu

    def forward(self, y_pred, y_true, model_params, global_params):
        base_loss = self.base_criterion(y_pred, y_true)
        proximal_term = 0.0
        if global_params is not None:
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
            loss = base_loss + (self.mu / 2) * proximal_term
        else:
            loss = base_loss
        return loss

def load_data(data_path):
    try:
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Dropping {missing_values} rows with missing data")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing data: {df.shape}")
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' missing")
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        return dataloader, X.shape[1]
    except Exception as e:
        logger.error(f"Error loading data: {e}")
        raise

class DP_SA_Client(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device, client_id):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.global_params = None

        self.dp_enabled = CLIENT_CONFIG["dp_enabled"]
        if self.dp_enabled:
            self.dp_mechanism = DifferentialPrivacyMechanism(
                CLIENT_CONFIG["dp_noise_multiplier"],
                CLIENT_CONFIG["dp_max_grad_norm"],
                CLIENT_CONFIG["dp_epsilon"],
                CLIENT_CONFIG["dp_delta"]
            )

        self.sa_enabled = CLIENT_CONFIG["sa_enabled"]
        if self.sa_enabled:
            self.secure_agg = SecureAggregation(noise_scale=CLIENT_CONFIG["sa_noise_scale"])

    def get_parameters(self, config):
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]

        if self.sa_enabled:
            params = self.secure_agg.add_random_mask(params)
            logger.info(f"Client {self.client_id} applied Secure Aggregation masking")

        return params

    def set_parameters(self, parameters):
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        criterion = nn.BCELoss()
        proximal_criterion = PrivacyAwareFedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        optimizer = torch.optim.Adam(self.model.parameters(), lr=CLIENT_CONFIG["learning_rate"], weight_decay=CLIENT_CONFIG["weight_decay"])

        total_loss, total_samples, correct = 0.0, 0, 0

        for epoch in range(CLIENT_CONFIG["local_epochs"]):
            epoch_loss, epoch_samples = 0.0, 0
            for batch_idx, (X, y) in enumerate(self.dataloader):
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                loss = proximal_criterion(y_pred, y, self.model.parameters(), self.global_params)
                optimizer.zero_grad()
                loss.backward()

                if self.dp_enabled:
                    grad_norm = self.dp_mechanism.clip_gradients(self.model)
                    self.dp_mechanism.add_noise(self.model)
                    if batch_idx % 10 == 0:
                        logger.info(f"Client {self.client_id} DP applied: grad_norm={grad_norm:.4f}")

                optimizer.step()

                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)

                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()

                if batch_idx % 5 == 0:
                    logger.info(f"Client {self.client_id} - Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - Batch {batch_idx}/{len(self.dataloader)} - Loss: {loss.item():.4f}")
            logger.info(f"Client {self.client_id} - Epoch {epoch+1} complete - Loss: {epoch_loss/epoch_samples:.4f}")

        avg_loss = total_loss / total_samples if total_samples else 0
        accuracy = correct / total_samples if total_samples else 0

        logger.info(f"Client {self.client_id} training finished - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Send security flags back in metrics including client ID
        return self.get_parameters({}), total_samples, {
            "loss": avg_loss,
            "accuracy": accuracy,
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id  # Send client ID here
        }

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.BCELoss()

        loss, total, correct = 0.0, 0, 0

        with torch.no_grad():
            for X, y in self.dataloader:
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                loss += batch_loss * X.size(0)
                total += X.size(0)
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()

        avg_loss = loss / total if total else 0
        accuracy = correct / total if total else 0

        logger.info(f"Client {self.client_id} evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Send security flags back in metrics including client ID
        return float(avg_loss), total, {
            "accuracy": accuracy,
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id  # Send client ID here
        }

def start_client(client_id=0, server_address=None):
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")

    data_path = f"framingham_part{client_id+1}.csv"
    if not os.path.exists(data_path):
        logger.error(f"Data file {data_path} not found")
        return

    dataloader, input_size = load_data(data_path)

    model = PrivacyEnhancedHeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size {input_size}")

    client = DP_SA_Client(model, dataloader, device, client_id)

    print(f"\n===== DP+SA Framingham FL Client {client_id} =====")
    print(f"Server:              {CLIENT_CONFIG['server_address']}")
    print(f"Data file:           {data_path}")
    print(f"Local epochs:        {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:          {CLIENT_CONFIG['batch_size']}")
    print(f"Device:              {device}")
    print("==============================================\n")

    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

if __name__ == "__main__":
    import sys
    import argparse

    if 'ipykernel' in sys.modules:
        start_client(client_id=1)
    else:
        parser = argparse.ArgumentParser(description="DP+SA Framingham FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--disable-sa", action="store_true", help="Disable Secure Aggregation masking")
        parser.add_argument("--dp-epsilon", type=float, default=8.0, help="DP epsilon parameter")
        parser.add_argument("--dp-noise", type=float, default=1.0, help="DP noise multiplier")
        args = parser.parse_args()

        CLIENT_CONFIG["dp_epsilon"] = args.dp_epsilon
        CLIENT_CONFIG["dp_noise_multiplier"] = args.dp_noise
        CLIENT_CONFIG["sa_enabled"] = not args.disable_sa

        start_client(args.id, args.server)
# Out:
# 2025-05-24 22:45:40,035 - DP_SA_FraminghamClient - INFO - Using device: cuda
# 2025-05-24 22:45:40,040 - DP_SA_FraminghamClient - INFO - Loaded framingham_part2.csv with shape (1060, 16)
# 2025-05-24 22:45:40,042 - DP_SA_FraminghamClient - INFO - Class distribution: {0: 914, 1: 146}
# 2025-05-24 22:45:40,049 - DP_SA_FraminghamClient - INFO - Model initialized with input size 15
# 2025-05-24 22:45:40,050 - DP_SA_FraminghamClient - INFO - DP initialized: ε=8.0, δ=1e-05, noise_multiplier=1.0
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 22:45:40,050 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 22:45:40,053 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 22:45:40,076 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 22:45:40,082 - flwr - DEBUG - ChannelConnectivity.READY
# INFO :
# 2025-05-24 22:45:40,091 - flwr - INFO -
# INFO :      Received: train message 4031ad39-2a0b-4963-b0d5-f1e3777642f2
# 2025-05-24 22:45:40,093 - flwr - INFO - Received: train message 4031ad39-2a0b-4963-b0d5-f1e3777642f2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:40,093 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:40,111 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:40,133 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5946
# 2025-05-24 22:45:40,136 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.7047
# 2025-05-24 22:45:40,218 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 0.7007
# ===== DP+SA Framingham FL Client 1 =====
# Server:              localhost:8080
# Data file:           framingham_part2.csv
# Local epochs:        3
# Batch size:          32
# Device:              cuda
# ==============================================
# 2025-05-24 22:45:40,301 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6829
# 2025-05-24 22:45:40,304 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.6887
# 2025-05-24 22:45:40,378 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.6998
# 2025-05-24 22:45:40,428 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5840
# 2025-05-24 22:45:40,430 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.6826
# 2025-05-24 22:45:40,471 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.6736
# 2025-05-24 22:45:40,509 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4144
# 2025-05-24 22:45:40,511 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.6566
# 2025-05-24 22:45:40,533 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.6870
# 2025-05-24 22:45:40,538 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4113
# 2025-05-24 22:45:40,538 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.6752
# 2025-05-24 22:45:40,580 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.6718
# 2025-05-24 22:45:40,613 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6817
# 2025-05-24 22:45:40,616 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.6825
# 2025-05-24 22:45:40,650 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.6852
# 2025-05-24 22:45:40,686 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4488
# 2025-05-24 22:45:40,689 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.6769
# 2025-05-24 22:45:40,726 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.6596
# 2025-05-24 22:45:40,760 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.7278
# 2025-05-24 22:45:40,761 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 0.6748
# 2025-05-24 22:45:40,785 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.6787
# 2025-05-24 22:45:40,793 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4512
# 2025-05-24 22:45:40,793 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.6766
# 2025-05-24 22:45:40,826 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.6861
# 2025-05-24 22:45:40,865 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6888
# 2025-05-24 22:45:40,867 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.6715
# 2025-05-24 22:45:40,902 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.6666
# 2025-05-24 22:45:40,940 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6607
# 2025-05-24 22:45:40,942 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.6469
# 2025-05-24 22:45:40,969 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.6666
# 2025-05-24 22:45:41,016 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6502
# 2025-05-24 22:45:41,018 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.6698
# 2025-05-24 22:45:41,040 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.6688
# 2025-05-24 22:45:41,040 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.6781, Accuracy: 0.6258
# 2025-05-24 22:45:41,041 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:41,045 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:41,089 - flwr - INFO -
# INFO :      Received: evaluate message 8b81e9d7-de11-4600-b138-b95878c0408e
# 2025-05-24 22:45:41,091 - flwr - INFO - Received: evaluate message 8b81e9d7-de11-4600-b138-b95878c0408e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,094 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,098 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:41,149 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 0.6023, Accuracy: 0.8623
# INFO :      Sent reply
# 2025-05-24 22:45:41,149 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:41,180 - flwr - INFO -
# INFO :      Received: train message 30f5dc9b-5e57-4920-b3ed-943873a86547
# 2025-05-24 22:45:41,184 - flwr - INFO - Received: train message 30f5dc9b-5e57-4920-b3ed-943873a86547
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,187 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:41,194 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:41,204 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2775
# 2025-05-24 22:45:41,209 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.6076
# 2025-05-24 22:45:41,259 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 0.6065
# 2025-05-24 22:45:41,305 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2562
# 2025-05-24 22:45:41,307 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.6166
# 2025-05-24 22:45:41,351 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.6042
# 2025-05-24 22:45:41,418 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2107
# 2025-05-24 22:45:41,418 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.6233
# 2025-05-24 22:45:41,475 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.6048
# 2025-05-24 22:45:41,515 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2479
# 2025-05-24 22:45:41,515 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.6140
# 2025-05-24 22:45:41,550 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.6015
# 2025-05-24 22:45:41,560 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3390
# 2025-05-24 22:45:41,562 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.5897
# 2025-05-24 22:45:41,602 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.5878
# 2025-05-24 22:45:41,642 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3396
# 2025-05-24 22:45:41,642 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.5904
# 2025-05-24 22:45:41,690 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.5884
# 2025-05-24 22:45:41,728 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2709
# 2025-05-24 22:45:41,731 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.6040
# 2025-05-24 22:45:41,776 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.6043
# 2025-05-24 22:45:41,820 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2438
# 2025-05-24 22:45:41,823 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 0.6147
# 2025-05-24 22:45:41,845 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.5998
# 2025-05-24 22:45:41,853 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.1828
# 2025-05-24 22:45:41,856 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.6280
# 2025-05-24 22:45:41,899 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.5982
# 2025-05-24 22:45:41,934 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3358
# 2025-05-24 22:45:41,936 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.5857
# 2025-05-24 22:45:41,978 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.5892
# 2025-05-24 22:45:42,015 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2489
# 2025-05-24 22:45:42,018 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.6139
# 2025-05-24 22:45:42,053 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.6022
# 2025-05-24 22:45:42,093 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2377
# 2025-05-24 22:45:42,096 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.6124
# 2025-05-24 22:45:42,118 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.5981
# 2025-05-24 22:45:42,120 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.5998, Accuracy: 0.8623
# 2025-05-24 22:45:42,121 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:42,124 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:42,170 - flwr - INFO -
# INFO :      Received: evaluate message b4b80673-ba37-4c7c-bfc6-861ba37d142b
# 2025-05-24 22:45:42,172 - flwr - INFO - Received: evaluate message b4b80673-ba37-4c7c-bfc6-861ba37d142b
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,174 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,178 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:42,240 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 0.6124, Accuracy: 0.8104
# INFO :      Sent reply
# 2025-05-24 22:45:42,241 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:42,262 - flwr - INFO -
# INFO :      Received: train message d078273c-7a09-4427-8062-3df332ff99a1
# 2025-05-24 22:45:42,266 - flwr - INFO - Received: train message d078273c-7a09-4427-8062-3df332ff99a1
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,270 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:42,279 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:42,295 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3037
# 2025-05-24 22:45:42,302 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.6413
# 2025-05-24 22:45:42,353 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 0.5971
# 2025-05-24 22:45:42,395 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3212
# 2025-05-24 22:45:42,397 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.6080
# 2025-05-24 22:45:42,440 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.6492
# 2025-05-24 22:45:42,490 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3328
# 2025-05-24 22:45:42,490 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.6131
# 2025-05-24 22:45:42,533 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.5970
# 2025-05-24 22:45:42,571 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3790
# 2025-05-24 22:45:42,573 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.5754
# 2025-05-24 22:45:42,602 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.6131
# 2025-05-24 22:45:42,611 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3695
# 2025-05-24 22:45:42,613 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.6064
# 2025-05-24 22:45:42,653 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.6121
# 2025-05-24 22:45:42,698 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3228
# 2025-05-24 22:45:42,701 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.5932
# 2025-05-24 22:45:42,744 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.6507
# 2025-05-24 22:45:42,787 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3186
# 2025-05-24 22:45:42,789 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.6306
# 2025-05-24 22:45:42,830 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.6531
# 2025-05-24 22:45:42,869 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3802
# 2025-05-24 22:45:42,871 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 0.6124
# 2025-05-24 22:45:42,897 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.6127
# 2025-05-24 22:45:42,904 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3989
# 2025-05-24 22:45:42,906 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.6019
# 2025-05-24 22:45:42,949 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.6086
# 2025-05-24 22:45:42,988 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3697
# 2025-05-24 22:45:42,990 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.6120
# 2025-05-24 22:45:43,024 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.6089
# 2025-05-24 22:45:43,063 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4085
# 2025-05-24 22:45:43,065 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.6197
# 2025-05-24 22:45:43,105 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.6016
# 2025-05-24 22:45:43,143 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3004
# 2025-05-24 22:45:43,144 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.5908
# 2025-05-24 22:45:43,169 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.6066
# 2025-05-24 22:45:43,170 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.6108, Accuracy: 0.8107
# 2025-05-24 22:45:43,171 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:43,173 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:43,219 - flwr - INFO -
# INFO :      Received: evaluate message 634f3d74-d723-4e6b-8fad-ff110615007c
# 2025-05-24 22:45:43,219 - flwr - INFO - Received: evaluate message 634f3d74-d723-4e6b-8fad-ff110615007c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,224 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,231 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:43,318 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 0.5385, Accuracy: 0.8264
# INFO :      Sent reply
# 2025-05-24 22:45:43,320 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:43,337 - flwr - INFO -
# INFO :      Received: train message f17bfa1d-fe58-4ac7-ab5f-0d4645813467
# 2025-05-24 22:45:43,338 - flwr - INFO - Received: train message f17bfa1d-fe58-4ac7-ab5f-0d4645813467
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,341 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:43,345 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:43,357 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2996
# 2025-05-24 22:45:43,361 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.5267
# 2025-05-24 22:45:43,399 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 0.5909
# 2025-05-24 22:45:43,435 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.9119
# 2025-05-24 22:45:43,437 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.5359
# 2025-05-24 22:45:43,493 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.5525
# 2025-05-24 22:45:43,536 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.7276
# 2025-05-24 22:45:43,538 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.4834
# 2025-05-24 22:45:43,574 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.5708
# 2025-05-24 22:45:43,609 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3148
# 2025-05-24 22:45:43,610 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.5643
# 2025-05-24 22:45:43,633 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.5480
# 2025-05-24 22:45:43,640 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4511
# 2025-05-24 22:45:43,642 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.5593
# 2025-05-24 22:45:43,677 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.5307
# 2025-05-24 22:45:43,711 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2786
# 2025-05-24 22:45:43,712 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.6306
# 2025-05-24 22:45:43,747 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.5516
# 2025-05-24 22:45:43,781 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5337
# 2025-05-24 22:45:43,784 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.5107
# 2025-05-24 22:45:43,822 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.5274
# 2025-05-24 22:45:43,856 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2574
# 2025-05-24 22:45:43,858 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 0.5586
# 2025-05-24 22:45:43,879 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.5424
# 2025-05-24 22:45:43,885 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2857
# 2025-05-24 22:45:43,887 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.5282
# 2025-05-24 22:45:43,936 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.5122
# 2025-05-24 22:45:43,982 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3759
# 2025-05-24 22:45:43,984 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.5040
# 2025-05-24 22:45:44,024 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.5111
# 2025-05-24 22:45:44,059 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2468
# 2025-05-24 22:45:44,061 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.5611
# 2025-05-24 22:45:44,098 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.5393
# 2025-05-24 22:45:44,134 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6012
# 2025-05-24 22:45:44,136 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.5631
# 2025-05-24 22:45:44,159 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.5432
# 2025-05-24 22:45:44,160 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.5445, Accuracy: 0.8198
# 2025-05-24 22:45:44,162 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:44,164 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:44,216 - flwr - INFO -
# INFO :      Received: evaluate message 08879080-52ff-432d-bce1-8057dba1c15a
# 2025-05-24 22:45:44,218 - flwr - INFO - Received: evaluate message 08879080-52ff-432d-bce1-8057dba1c15a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,220 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,225 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:44,296 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 0.5241, Accuracy: 0.8057
# INFO :      Sent reply
# 2025-05-24 22:45:44,296 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:44,315 - flwr - INFO -
# INFO :      Received: train message 6a778bc8-f1bf-424b-b005-b24245b30832
# 2025-05-24 22:45:44,316 - flwr - INFO - Received: train message 6a778bc8-f1bf-424b-b005-b24245b30832
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,318 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:44,324 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:44,333 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4839
# 2025-05-24 22:45:44,337 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.5392
# 2025-05-24 22:45:44,379 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 0.5435
# 2025-05-24 22:45:44,420 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4653
# 2025-05-24 22:45:44,420 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.4967
# 2025-05-24 22:45:44,462 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.6581
# 2025-05-24 22:45:44,499 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2736
# 2025-05-24 22:45:44,501 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.4751
# 2025-05-24 22:45:44,548 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.5205
# 2025-05-24 22:45:44,592 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4723
# 2025-05-24 22:45:44,596 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.4771
# 2025-05-24 22:45:44,627 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.5342
# 2025-05-24 22:45:44,639 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5341
# 2025-05-24 22:45:44,644 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.5153
# 2025-05-24 22:45:44,685 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.4790
# 2025-05-24 22:45:44,725 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4502
# 2025-05-24 22:45:44,725 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.5255
# 2025-05-24 22:45:44,767 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.4870
# 2025-05-24 22:45:44,814 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.4387
# 2025-05-24 22:45:44,818 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.5543
# 2025-05-24 22:45:44,857 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.5775
# 2025-05-24 22:45:44,894 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.8658
# 2025-05-24 22:45:44,896 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 0.5018
# 2025-05-24 22:45:44,919 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.5347
# 2025-05-24 22:45:44,927 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.2951
# 2025-05-24 22:45:44,928 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.5344
# 2025-05-24 22:45:44,962 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.5257
# 2025-05-24 22:45:45,002 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6373
# 2025-05-24 22:45:45,003 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.5513
# 2025-05-24 22:45:45,038 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.4925
# 2025-05-24 22:45:45,071 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5860
# 2025-05-24 22:45:45,073 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.6318
# 2025-05-24 22:45:45,104 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.5430
# 2025-05-24 22:45:45,135 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3585
# 2025-05-24 22:45:45,137 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.4531
# 2025-05-24 22:45:45,154 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.5256
# 2025-05-24 22:45:45,154 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.5315, Accuracy: 0.8116
# 2025-05-24 22:45:45,154 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:45,160 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:45,208 - flwr - INFO -
# INFO :      Received: evaluate message e4e3f8a1-559c-4a4e-bde0-19b7dae8ba83
# 2025-05-24 22:45:45,211 - flwr - INFO - Received: evaluate message e4e3f8a1-559c-4a4e-bde0-19b7dae8ba83
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,212 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,219 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:45,309 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 0.5003, Accuracy: 0.8009
# INFO :      Sent reply
# 2025-05-24 22:45:45,311 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:45,340 - flwr - INFO -
# INFO :      Received: train message a30ac808-277f-43e7-a204-85b09a8fbfca
# 2025-05-24 22:45:45,343 - flwr - INFO - Received: train message a30ac808-277f-43e7-a204-85b09a8fbfca
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,346 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:45,351 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:45,364 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5577
# 2025-05-24 22:45:45,368 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.5805
# 2025-05-24 22:45:45,415 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 0.6356
# 2025-05-24 22:45:45,458 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.9941
# 2025-05-24 22:45:45,462 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.7157
# 2025-05-24 22:45:45,502 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.4483
# 2025-05-24 22:45:45,539 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5071
# 2025-05-24 22:45:45,545 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.5134
# 2025-05-24 22:45:45,584 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.5241
# 2025-05-24 22:45:45,622 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5467
# 2025-05-24 22:45:45,626 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.4613
# 2025-05-24 22:45:45,652 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.5214
# 2025-05-24 22:45:45,662 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5886
# 2025-05-24 22:45:45,666 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.4694
# 2025-05-24 22:45:45,710 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.3891
# 2025-05-24 22:45:45,749 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.5861
# 2025-05-24 22:45:45,753 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.4750
# 2025-05-24 22:45:45,788 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.5148
# 2025-05-24 22:45:45,832 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.5376
# 2025-05-24 22:45:45,834 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.5167
# 2025-05-24 22:45:45,876 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.4964
# 2025-05-24 22:45:45,918 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.1177
# 2025-05-24 22:45:45,920 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 0.6101
# 2025-05-24 22:45:45,947 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.5141
# 2025-05-24 22:45:45,954 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.3826
# 2025-05-24 22:45:45,956 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.5405
# 2025-05-24 22:45:45,997 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.4728
# 2025-05-24 22:45:46,031 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.2302
# 2025-05-24 22:45:46,031 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.6688
# 2025-05-24 22:45:46,070 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.4818
# 2025-05-24 22:45:46,104 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.6332
# 2025-05-24 22:45:46,107 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.4874
# 2025-05-24 22:45:46,147 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.4722
# 2025-05-24 22:45:46,184 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.3542
# 2025-05-24 22:45:46,184 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.5028
# 2025-05-24 22:45:46,210 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.5134
# 2025-05-24 22:45:46,210 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.5163, Accuracy: 0.7943
# 2025-05-24 22:45:46,212 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:46,212 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:46,262 - flwr - INFO -
# INFO :      Received: evaluate message 299fbe2a-eaac-4a39-a740-e2670f5134f1
# 2025-05-24 22:45:46,262 - flwr - INFO - Received: evaluate message 299fbe2a-eaac-4a39-a740-e2670f5134f1
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,266 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,272 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:46,351 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 0.5491, Accuracy: 0.8000
# INFO :      Sent reply
# 2025-05-24 22:45:46,351 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:46,380 - flwr - INFO -
# INFO :      Received: train message 8adc5c0d-d2d4-4ae4-a476-ef54d9d03f74
# 2025-05-24 22:45:46,382 - flwr - INFO - Received: train message 8adc5c0d-d2d4-4ae4-a476-ef54d9d03f74
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,384 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:46,389 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:46,400 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=3.9364
# 2025-05-24 22:45:46,403 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 0.6630
# 2025-05-24 22:45:46,446 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 1.2345
# 2025-05-24 22:45:46,484 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.7702
# 2025-05-24 22:45:46,486 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 0.6788
# 2025-05-24 22:45:46,525 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 0.6814
# 2025-05-24 22:45:46,566 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.7800
# 2025-05-24 22:45:46,566 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 0.5508
# 2025-05-24 22:45:46,614 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 0.5398
# 2025-05-24 22:45:46,650 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=3.3001
# 2025-05-24 22:45:46,650 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 0.5464
# 2025-05-24 22:45:46,679 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 0.8522
# 2025-05-24 22:45:46,686 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.7781
# 2025-05-24 22:45:46,690 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.5094
# 2025-05-24 22:45:46,734 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 0.4812
# 2025-05-24 22:45:46,775 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.2096
# 2025-05-24 22:45:46,781 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 3.7966
# 2025-05-24 22:45:46,825 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.4601
# 2025-05-24 22:45:46,865 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.0970
# 2025-05-24 22:45:46,868 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 0.6325
# 2025-05-24 22:45:46,908 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 0.7597
# 2025-05-24 22:45:46,946 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.5594
# 2025-05-24 22:45:46,956 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 3.7868
# 2025-05-24 22:45:46,986 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 0.8963
# 2025-05-24 22:45:46,995 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.7100
# 2025-05-24 22:45:46,995 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.5059
# 2025-05-24 22:45:47,036 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 0.8058
# 2025-05-24 22:45:47,081 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.4557
# 2025-05-24 22:45:47,081 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 0.8761
# 2025-05-24 22:45:47,122 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 0.7548
# 2025-05-24 22:45:47,154 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.0770
# 2025-05-24 22:45:47,164 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 0.8872
# 2025-05-24 22:45:47,196 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 0.4511
# 2025-05-24 22:45:47,240 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.7402
# 2025-05-24 22:45:47,240 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 0.7036
# 2025-05-24 22:45:47,274 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 0.7775
# 2025-05-24 22:45:47,274 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 0.8420, Accuracy: 0.7909
# 2025-05-24 22:45:47,276 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:47,279 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:47,348 - flwr - INFO -
# INFO :      Received: evaluate message 6c038920-71e8-46ac-9b46-e440d44f585a
# 2025-05-24 22:45:47,350 - flwr - INFO - Received: evaluate message 6c038920-71e8-46ac-9b46-e440d44f585a
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,352 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,356 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:47,419 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 3.8599, Accuracy: 0.7500
# INFO :      Sent reply
# 2025-05-24 22:45:47,421 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:47,439 - flwr - INFO -
# INFO :      Received: train message ab2b9165-579d-4942-8194-98f4d0060bc6
# 2025-05-24 22:45:47,440 - flwr - INFO - Received: train message ab2b9165-579d-4942-8194-98f4d0060bc6
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,442 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:47,447 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:47,458 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=4.8175
# 2025-05-24 22:45:47,462 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 16.5647
# 2025-05-24 22:45:47,511 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 7.8113
# 2025-05-24 22:45:47,550 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.8190
# 2025-05-24 22:45:47,550 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 3.8949
# 2025-05-24 22:45:47,598 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 16.5457
# 2025-05-24 22:45:47,638 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.5898
# 2025-05-24 22:45:47,640 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 10.1539
# 2025-05-24 22:45:47,688 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 4.2535
# 2025-05-24 22:45:47,727 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.4233
# 2025-05-24 22:45:47,727 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 6.5120
# 2025-05-24 22:45:47,754 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 7.7432
# 2025-05-24 22:45:47,758 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.9941
# 2025-05-24 22:45:47,758 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 0.6378
# 2025-05-24 22:45:47,807 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 7.2026
# 2025-05-24 22:45:47,855 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.1964
# 2025-05-24 22:45:47,855 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 3.8699
# 2025-05-24 22:45:47,890 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 4.2048
# 2025-05-24 22:45:47,935 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.7379
# 2025-05-24 22:45:47,935 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 7.1259
# 2025-05-24 22:45:47,976 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 1.1262
# 2025-05-24 22:45:48,016 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.8060
# 2025-05-24 22:45:48,016 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 3.9516
# 2025-05-24 22:45:48,043 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 7.2918
# 2025-05-24 22:45:48,049 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=2.5298
# 2025-05-24 22:45:48,052 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 7.1150
# 2025-05-24 22:45:48,086 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 4.7646
# 2025-05-24 22:45:48,119 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=4.6978
# 2025-05-24 22:45:48,119 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 7.5915
# 2025-05-24 22:45:48,148 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 4.4602
# 2025-05-24 22:45:48,189 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=1.7165
# 2025-05-24 22:45:48,191 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 7.0189
# 2025-05-24 22:45:48,224 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 10.5599
# 2025-05-24 22:45:48,261 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=5.5002
# 2025-05-24 22:45:48,263 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 10.7788
# 2025-05-24 22:45:48,283 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 7.2035
# 2025-05-24 22:45:48,284 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 7.4128, Accuracy: 0.7390
# 2025-05-24 22:45:48,286 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:48,288 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:48,338 - flwr - INFO -
# INFO :      Received: evaluate message f60e4009-4603-4f25-be36-5edadc1f860f
# 2025-05-24 22:45:48,341 - flwr - INFO - Received: evaluate message f60e4009-4603-4f25-be36-5edadc1f860f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:48,343 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:48,344 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:48,405 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 8.5216, Accuracy: 0.6981
# ...
# 2025-05-24 22:45:58,201 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 9.7829
# 2025-05-24 22:45:58,232 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 6.6151
# 2025-05-24 22:45:58,240 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0038
# 2025-05-24 22:45:58,242 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 6.6143
# 2025-05-24 22:45:58,284 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 6.4465
# 2025-05-24 22:45:58,329 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.1485
# 2025-05-24 22:45:58,331 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 0.6610
# 2025-05-24 22:45:58,374 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 0.2588
# 2025-05-24 22:45:58,410 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0266
# 2025-05-24 22:45:58,413 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 9.6775
# 2025-05-24 22:45:58,461 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 6.5572
# 2025-05-24 22:45:58,509 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0309
# 2025-05-24 22:45:58,510 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 6.5573
# 2025-05-24 22:45:58,539 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 5.5502
# 2025-05-24 22:45:58,549 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0634
# 2025-05-24 22:45:58,552 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 9.8547
# 2025-05-24 22:45:58,595 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 12.6879
# 2025-05-24 22:45:58,647 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=5.1526
# 2025-05-24 22:45:58,649 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 3.4437
# 2025-05-24 22:45:58,689 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 3.5520
# 2025-05-24 22:45:58,725 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0276
# 2025-05-24 22:45:58,725 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 6.6770
# 2025-05-24 22:45:58,765 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 12.9178
# 2025-05-24 22:45:58,803 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.1025
# 2025-05-24 22:45:58,805 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 13.0278
# 2025-05-24 22:45:58,831 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 6.3319
# 2025-05-24 22:45:58,832 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 6.1657, Accuracy: 0.8198
# 2025-05-24 22:45:58,833 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:58,836 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:58,899 - flwr - INFO -
# INFO :      Received: evaluate message 43062f98-035c-472a-8d58-4393458fb0ed
# 2025-05-24 22:45:58,899 - flwr - INFO - Received: evaluate message 43062f98-035c-472a-8d58-4393458fb0ed
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:58,903 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:58,908 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:58,976 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 3.0141, Accuracy: 0.8491
# INFO :      Sent reply
# 2025-05-24 22:45:58,976 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:58,998 - flwr - INFO -
# INFO :      Received: train message bcc5f76b-3171-4200-b1cb-a625446457f2
# 2025-05-24 22:45:59,001 - flwr - INFO - Received: train message bcc5f76b-3171-4200-b1cb-a625446457f2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,003 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,008 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:45:59,017 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0576
# 2025-05-24 22:45:59,020 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 12.9270
# 2025-05-24 22:45:59,079 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 9.7339
# 2025-05-24 22:45:59,128 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0029
# 2025-05-24 22:45:59,130 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 15.9158
# 2025-05-24 22:45:59,170 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 3.6241
# 2025-05-24 22:45:59,214 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0033
# 2025-05-24 22:45:59,216 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 12.7948
# 2025-05-24 22:45:59,253 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 12.9919
# 2025-05-24 22:45:59,294 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0231
# 2025-05-24 22:45:59,294 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 6.6169
# 2025-05-24 22:45:59,324 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 12.4201
# 2025-05-24 22:45:59,329 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0578
# 2025-05-24 22:45:59,336 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 12.9278
# 2025-05-24 22:45:59,386 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 22.5497
# 2025-05-24 22:45:59,417 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0961
# 2025-05-24 22:45:59,417 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 19.2350
# 2025-05-24 22:45:59,474 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 15.7193
# 2025-05-24 22:45:59,514 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=3.3934
# 2025-05-24 22:45:59,517 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 9.7938
# 2025-05-24 22:45:59,558 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 12.9242
# 2025-05-24 22:45:59,598 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0165
# 2025-05-24 22:45:59,600 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 3.4355
# 2025-05-24 22:45:59,622 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 10.6503
# 2025-05-24 22:45:59,633 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.1128
# 2025-05-24 22:45:59,637 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 0.5643
# 2025-05-24 22:45:59,686 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 9.6782
# 2025-05-24 22:45:59,725 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0338
# 2025-05-24 22:45:59,727 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 12.7315
# 2025-05-24 22:45:59,766 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 6.8100
# 2025-05-24 22:45:59,802 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0964
# 2025-05-24 22:45:59,806 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 6.3536
# 2025-05-24 22:45:59,850 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 6.4292
# 2025-05-24 22:45:59,890 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.1777
# 2025-05-24 22:45:59,892 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 6.9378
# 2025-05-24 22:45:59,916 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 9.3396
# 2025-05-24 22:45:59,917 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 10.8033, Accuracy: 0.7808
# 2025-05-24 22:45:59,918 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:45:59,919 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:45:59,950 - flwr - INFO -
# INFO :      Received: evaluate message 9e494b02-85e9-432f-9666-f17af7605e8b
# 2025-05-24 22:45:59,951 - flwr - INFO - Received: evaluate message 9e494b02-85e9-432f-9666-f17af7605e8b
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,954 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:45:59,959 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:46:00,008 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 3.0141, Accuracy: 0.8491
# INFO :      Sent reply
# 2025-05-24 22:46:00,008 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:46:00,064 - flwr - INFO -
# INFO :      Received: train message d0193cf9-89ee-40a4-887e-0471c676f786
# 2025-05-24 22:46:00,066 - flwr - INFO - Received: train message d0193cf9-89ee-40a4-887e-0471c676f786
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:00,069 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:00,073 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:46:00,083 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=55.4005
# 2025-05-24 22:46:00,087 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 0/34 - Loss: 3.8638
# 2025-05-24 22:46:00,135 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 5/34 - Loss: 3.7200
# 2025-05-24 22:46:00,194 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=66.9693
# 2025-05-24 22:46:00,198 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 10/34 - Loss: 13.3537
# 2025-05-24 22:46:00,246 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 15/34 - Loss: 16.1140
# 2025-05-24 22:46:00,284 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0831
# 2025-05-24 22:46:00,286 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 20/34 - Loss: 6.7504
# 2025-05-24 22:46:00,341 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 25/34 - Loss: 9.6773
# 2025-05-24 22:46:00,378 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0386
# 2025-05-24 22:46:00,382 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1/3 - Batch 30/34 - Loss: 6.4875
# 2025-05-24 22:46:00,407 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 1 complete - Loss: 10.0277
# 2025-05-24 22:46:00,415 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0313
# 2025-05-24 22:46:00,418 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 0/34 - Loss: 15.9849
# 2025-05-24 22:46:00,460 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 5/34 - Loss: 15.7218
# 2025-05-24 22:46:00,503 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0042
# 2025-05-24 22:46:00,503 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 10/34 - Loss: 12.7952
# 2025-05-24 22:46:00,548 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 15/34 - Loss: 3.3703
# 2025-05-24 22:46:00,585 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0175
# 2025-05-24 22:46:00,587 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 20/34 - Loss: 3.5000
# 2025-05-24 22:46:00,621 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 25/34 - Loss: 18.9770
# 2025-05-24 22:46:00,661 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0553
# 2025-05-24 22:46:00,666 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2/3 - Batch 30/34 - Loss: 9.8075
# 2025-05-24 22:46:00,696 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 2 complete - Loss: 12.0892
# 2025-05-24 22:46:00,704 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0795
# 2025-05-24 22:46:00,705 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 0/34 - Loss: 3.6298
# 2025-05-24 22:46:00,759 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 5/34 - Loss: 12.9179
# 2025-05-24 22:46:00,800 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0067
# 2025-05-24 22:46:00,801 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 10/34 - Loss: 9.6745
# 2025-05-24 22:46:00,837 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 15/34 - Loss: 6.6218
# 2025-05-24 22:46:00,878 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0631
# 2025-05-24 22:46:00,878 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 20/34 - Loss: 15.7913
# 2025-05-24 22:46:00,919 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 25/34 - Loss: 9.6136
# 2025-05-24 22:46:00,954 - DP_SA_FraminghamClient - INFO - Client 1 DP applied: grad_norm=0.0384
# 2025-05-24 22:46:00,961 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3/3 - Batch 30/34 - Loss: 15.9785
# 2025-05-24 22:46:00,983 - DP_SA_FraminghamClient - INFO - Client 1 - Epoch 3 complete - Loss: 11.3415
# 2025-05-24 22:46:00,983 - DP_SA_FraminghamClient - INFO - Client 1 training finished - Loss: 11.1528, Accuracy: 0.7726
# 2025-05-24 22:46:00,983 - DP_SA_FraminghamClient - INFO - Client 1 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:46:00,988 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:46:01,051 - flwr - INFO -
# INFO :      Received: evaluate message 5c02b967-06dc-4639-88e2-fb9498b8ec0f
# 2025-05-24 22:46:01,053 - flwr - INFO - Received: evaluate message 5c02b967-06dc-4639-88e2-fb9498b8ec0f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:01,055 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:46:01,059 - DP_SA_FraminghamClient - INFO - Client 1: parameters updated from server
# 2025-05-24 22:46:01,128 - DP_SA_FraminghamClient - INFO - Client 1 evaluation - Loss: 2.4572, Accuracy: 0.8528
# INFO :      Sent reply
# 2025-05-24 22:46:01,128 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:46:06,440 - flwr - INFO -
# INFO :      Received: reconnect message 0fe4d189-846b-4303-a2da-48700d3f40fa
# 2025-05-24 22:46:06,442 - flwr - INFO - Received: reconnect message 0fe4d189-846b-4303-a2da-48700d3f40fa
# 2025-05-24 22:46:06,491 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 22:46:06,494 - flwr - INFO - Disconnect and shut down
