# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import logging
import sys

# Setup logger globally so it can be accessed anywhere
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("DP_SA_FraminghamClient")

CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01,

    # Differential Privacy parameters
    "dp_enabled": True,
    "dp_noise_multiplier": 1.0,
    "dp_max_grad_norm": 1.0,
    "dp_epsilon": 8.0,
    "dp_delta": 1e-5,

    # Secure Aggregation parameters
    "sa_enabled": False,
    "sa_noise_scale": 1e-3,

    # Additional security flags
    "smpc_enabled": False,
    "he_enabled": False,
}

class DifferentialPrivacyMechanism:
    def __init__(self, noise_multiplier, max_grad_norm, epsilon, delta):
        self.noise_multiplier = noise_multiplier
        self.max_grad_norm = max_grad_norm
        self.epsilon = epsilon
        self.delta = delta
        logger.info(f"DP initialized: ε={epsilon}, δ={delta}, noise_multiplier={noise_multiplier}")

    def clip_gradients(self, model):
        total_norm = 0.0
        for param in model.parameters():
            if param.grad is not None:
                param_norm = param.grad.data.norm(2)
                total_norm += param_norm.item() ** 2
        total_norm = total_norm ** 0.5

        clip_coef = self.max_grad_norm / (total_norm + 1e-6)
        if clip_coef < 1:
            for param in model.parameters():
                if param.grad is not None:
                    param.grad.data.mul_(clip_coef)
        return total_norm

    def add_noise(self, model):
        noise_scale = self.noise_multiplier * self.max_grad_norm
        for param in model.parameters():
            if param.grad is not None:
                noise = torch.normal(0, noise_scale, size=param.grad.shape, device=param.grad.device)
                param.grad.data.add_(noise)

class SecureAggregation:
    def __init__(self, noise_scale=1e-3):
        self.noise_scale = noise_scale

    def add_random_mask(self, parameters):
        masked_params = []
        for param in parameters:
            mask = np.random.normal(0, self.noise_scale, param.shape)
            masked_params.append(param + mask)
        return masked_params

class PrivacyEnhancedHeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

class PrivacyAwareFedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super().__init__()
        self.base_criterion = base_criterion
        self.mu = mu

    def forward(self, y_pred, y_true, model_params, global_params):
        base_loss = self.base_criterion(y_pred, y_true)
        proximal_term = 0.0
        if global_params is not None:
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
            loss = base_loss + (self.mu / 2) * proximal_term
        else:
            loss = base_loss
        return loss

def load_data(data_path):
    try:
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Dropping {missing_values} rows with missing data")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing data: {df.shape}")
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' missing")
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        return dataloader, X.shape[1]
    except Exception as e:
        logger.error(f"Error loading data: {e}")
        raise

# UPDATED: Much more aggressive poisoning function
def poison_model_parameters(parameters):
    """
    MUCH MORE AGGRESSIVE poisoning that should be easily detectable.
    """
    logger.warning(f"🦠 EXECUTING AGGRESSIVE POISONING ATTACK!")
    poisoned_params = []
    
    total_original_norm = 0
    total_poisoned_norm = 0
    
    for i, p in enumerate(parameters):
        original_norm = np.linalg.norm(p)
        total_original_norm += original_norm
        
        # Multiple attack strategies combined:
        # 1. Very large random noise (50x larger than before)
        large_noise = np.random.normal(loc=0, scale=50.0, size=p.shape)
        
        # 2. Sign flipping with massive amplification
        sign_flipped = -p * 100  # 100x amplification
        
        # 3. Constant bias attack
        constant_bias = np.full(p.shape, 20.0)  # Large constant values
        
        # 4. Adversarial pattern injection
        adversarial_pattern = np.random.choice([-10.0, 10.0], size=p.shape)
        
        # Combine all attacks
        poisoned = p + large_noise + sign_flipped + constant_bias + adversarial_pattern
        poisoned_norm = np.linalg.norm(poisoned)
        total_poisoned_norm += poisoned_norm
        
        poisoned_params.append(poisoned)
        
        logger.warning(f"  Layer {i}: {original_norm:.6f} -> {poisoned_norm:.6f} ({poisoned_norm/(original_norm+1e-10):.1f}x)")
    
    amplification = total_poisoned_norm / (total_original_norm + 1e-10)
    logger.warning(f"  🚨 TOTAL AMPLIFICATION: {amplification:.1f}x")
    logger.warning(f"  🚨 POISONED NORM: {total_poisoned_norm:.6f}")
    
    return poisoned_params

class DP_SA_Client(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device, client_id, poisoning_enabled=False):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.global_params = None
        self.poisoning_enabled = poisoning_enabled

        # Log poisoning status clearly
        if self.poisoning_enabled:
            logger.warning(f"🚨 CLIENT {client_id} INITIALIZED AS MALICIOUS! 🚨")
        else:
            logger.info(f"✅ Client {client_id} initialized as honest")

        self.dp_enabled = CLIENT_CONFIG["dp_enabled"]
        if self.dp_enabled:
            self.dp_mechanism = DifferentialPrivacyMechanism(
                CLIENT_CONFIG["dp_noise_multiplier"],
                CLIENT_CONFIG["dp_max_grad_norm"],
                CLIENT_CONFIG["dp_epsilon"],
                CLIENT_CONFIG["dp_delta"]
            )

        self.sa_enabled = CLIENT_CONFIG["sa_enabled"]
        if self.sa_enabled:
            self.secure_agg = SecureAggregation(noise_scale=CLIENT_CONFIG["sa_noise_scale"])

    def get_parameters(self, config):
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]

        # Calculate original norm for logging
        original_norm = sum(np.linalg.norm(p) for p in params)
        logger.info(f"Client {self.client_id} original parameters norm: {original_norm:.6f}")

        if self.sa_enabled:
            params = self.secure_agg.add_random_mask(params)
            logger.info(f"Client {self.client_id} applied Secure Aggregation masking")

        # UPDATED: Much more aggressive poisoning
        if self.poisoning_enabled:
            logger.warning(f"🦠 Client {self.client_id} applying AGGRESSIVE poisoning attack!")
            params = poison_model_parameters(params)
            
            # Log final poisoned norm
            poisoned_norm = sum(np.linalg.norm(p) for p in params)
            logger.warning(f"🚨 Client {self.client_id} poisoned parameters norm: {poisoned_norm:.6f}")

        return params

    def set_parameters(self, parameters):
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")

    # UPDATED: Return obviously bad metrics for malicious clients
    def get_malicious_metrics(self, total_samples):
        """Generate obviously bad metrics for malicious client."""
        bad_metrics = {
            "loss": np.random.uniform(5.0, 15.0),      # Very high loss
            "accuracy": np.random.uniform(0.01, 0.15), # Very low accuracy
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id,
            "poisoning_active": True  # Clear indicator of malicious behavior
        }
        
        logger.warning(f"🚨 Client {self.client_id} reporting FAKE BAD METRICS:")
        logger.warning(f"   Fake Loss: {bad_metrics['loss']:.3f}")
        logger.warning(f"   Fake Accuracy: {bad_metrics['accuracy']:.3f}")
        
        return bad_metrics

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        criterion = nn.BCELoss()
        proximal_criterion = PrivacyAwareFedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        optimizer = torch.optim.Adam(self.model.parameters(), lr=CLIENT_CONFIG["learning_rate"], weight_decay=CLIENT_CONFIG["weight_decay"])

        total_loss, total_samples, correct = 0.0, 0, 0

        # UPDATED: For malicious clients, do minimal training or fake training
        if self.poisoning_enabled:
            logger.warning(f"🦠 Client {self.client_id} performing FAKE/MINIMAL training!")
            
            # Do minimal training (just 1 batch) or fake it entirely
            for epoch in range(1):  # Only 1 epoch instead of 3
                for batch_idx, (X, y) in enumerate(self.dataloader):
                    if batch_idx > 2:  # Only process 3 batches
                        break
                        
                    X, y = X.to(self.device), y.to(self.device)
                    y_pred = self.model(X)
                    
                    # Deliberately train poorly
                    loss = proximal_criterion(y_pred, y, self.model.parameters(), self.global_params)
                    optimizer.zero_grad()
                    loss.backward()
                    
                    # Add noise to gradients to make training worse
                    for param in self.model.parameters():
                        if param.grad is not None:
                            param.grad.data += torch.randn_like(param.grad.data) * 0.1
                    
                    optimizer.step()
                    
                    total_samples += X.size(0)
                    
                    logger.warning(f"🦠 Malicious client {self.client_id} fake training batch {batch_idx}")
            
            # Return poisoned parameters and fake bad metrics
            return self.get_parameters({}), total_samples, self.get_malicious_metrics(total_samples)
        
        else:
            # Normal training for honest clients
            for epoch in range(CLIENT_CONFIG["local_epochs"]):
                epoch_loss, epoch_samples = 0.0, 0
                for batch_idx, (X, y) in enumerate(self.dataloader):
                    X, y = X.to(self.device), y.to(self.device)
                    y_pred = self.model(X)
                    loss = proximal_criterion(y_pred, y, self.model.parameters(), self.global_params)
                    optimizer.zero_grad()
                    loss.backward()

                    if self.dp_enabled:
                        grad_norm = self.dp_mechanism.clip_gradients(self.model)
                        self.dp_mechanism.add_noise(self.model)
                        if batch_idx % 10 == 0:
                            logger.info(f"Client {self.client_id} DP applied: grad_norm={grad_norm:.4f}")

                    optimizer.step()

                    batch_loss = loss.item() * X.size(0)
                    total_loss += batch_loss
                    epoch_loss += batch_loss
                    total_samples += X.size(0)
                    epoch_samples += X.size(0)

                    predicted = (y_pred > 0.5).float()
                    correct += (predicted == y).sum().item()

                    if batch_idx % 5 == 0:
                        logger.info(f"Client {self.client_id} - Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - Batch {batch_idx}/{len(self.dataloader)} - Loss: {loss.item():.4f}")
                logger.info(f"Client {self.client_id} - Epoch {epoch+1} complete - Loss: {epoch_loss/epoch_samples:.4f}")

            avg_loss = total_loss / total_samples if total_samples else 0
            accuracy = correct / total_samples if total_samples else 0

            logger.info(f"✅ Client {self.client_id} honest training finished - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

            # Return normal metrics for honest clients
            return self.get_parameters({}), total_samples, {
                "loss": avg_loss,
                "accuracy": accuracy,
                "dp_enabled": int(self.dp_enabled),
                "sa_enabled": int(self.sa_enabled),
                "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
                "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
                "client_id": self.client_id,
                "poisoning_active": False
            }

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.BCELoss()

        loss, total, correct = 0.0, 0, 0

        # UPDATED: Malicious clients return fake bad evaluation metrics
        if self.poisoning_enabled:
            logger.warning(f"🦠 Client {self.client_id} returning FAKE evaluation metrics!")
            
            # Do minimal evaluation
            with torch.no_grad():
                for i, (X, y) in enumerate(self.dataloader):
                    if i > 1:  # Only evaluate 2 batches
                        break
                    X, y = X.to(self.device), y.to(self.device)
                    total += X.size(0)
            
            # Return fake bad metrics
            fake_loss = np.random.uniform(3.0, 8.0)
            fake_accuracy = np.random.uniform(0.05, 0.2)
            
            return float(fake_loss), total, {
                "accuracy": fake_accuracy,
                "dp_enabled": int(self.dp_enabled),
                "sa_enabled": int(self.sa_enabled),
                "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
                "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
                "client_id": self.client_id,
                "poisoning_active": True
            }
        
        else:
            # Normal evaluation for honest clients
            with torch.no_grad():
                for X, y in self.dataloader:
                    X, y = X.to(self.device), y.to(self.device)
                    y_pred = self.model(X)
                    batch_loss = criterion(y_pred, y).item()
                    loss += batch_loss * X.size(0)
                    total += X.size(0)
                    predicted = (y_pred > 0.5).float()
                    correct += (predicted == y).sum().item()

            avg_loss = loss / total if total else 0
            accuracy = correct / total if total else 0

            logger.info(f"✅ Client {self.client_id} honest evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

            return float(avg_loss), total, {
                "accuracy": accuracy,
                "dp_enabled": int(self.dp_enabled),
                "sa_enabled": int(self.sa_enabled),
                "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
                "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
                "client_id": self.client_id,
                "poisoning_active": False
            }

def start_client(client_id=0, server_address=None, poisoning_enabled=False):  # Changed default to False
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")

    data_path = f"framingham_part{client_id+1}.csv"
    if not os.path.exists(data_path):
        logger.error(f"Data file {data_path} not found")
        return

    dataloader, input_size = load_data(data_path)

    model = PrivacyEnhancedHeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size {input_size}")

    client = DP_SA_Client(model, dataloader, device, client_id, poisoning_enabled=poisoning_enabled)

    # Enhanced startup logging
    poisoning_status = "🚨 MALICIOUS" if poisoning_enabled else "✅ HONEST"
    print(f"\n===== DP+SA Framingham FL Client {client_id} ({poisoning_status}) =====")
    print(f"Server:              {CLIENT_CONFIG['server_address']}")
    print(f"Data file:           {data_path}")
    print(f"Local epochs:        {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:          {CLIENT_CONFIG['batch_size']}")
    print(f"Device:              {device}")
    print(f"Poisoning enabled:   {poisoning_enabled}")
    if poisoning_enabled:
        print(f"🦠 WARNING: This client will perform AGGRESSIVE attacks!")
    print("==============================================\n")

    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

if __name__ == "__main__":
    import argparse

    parser = argparse.ArgumentParser(description="DP+SA Framingham FL Client with Optional Poisoning")
    parser.add_argument("--id", type=int, default=0, help="Client ID")
    parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
    parser.add_argument("--disable-sa", action="store_true", help="Disable Secure Aggregation masking")
    parser.add_argument("--dp-epsilon", type=float, default=8.0, help="DP epsilon parameter")
    parser.add_argument("--dp-noise", type=float, default=1.0, help="DP noise multiplier")
    parser.add_argument("--poisoning", action="store_true", help="Enable AGGRESSIVE model poisoning attack simulation")

    args, unknown = parser.parse_known_args()

    CLIENT_CONFIG["dp_epsilon"] = args.dp_epsilon
    CLIENT_CONFIG["dp_noise_multiplier"] = args.dp_noise
    CLIENT_CONFIG["sa_enabled"] = not args.disable_sa

    # Enhanced argument logging
    if args.poisoning:
        print(f"🚨 MALICIOUS CLIENT MODE ACTIVATED FOR CLIENT {args.id}!")
    else:
        print(f"✅ Honest client mode for client {args.id}")

    start_client(args.id, args.server, poisoning_enabled=args.poisoning)
# Out:
# 2025-05-24 12:24:29,155 - DP_SA_FraminghamClient - INFO - Using device: cuda
# 2025-05-24 12:24:29,160 - DP_SA_FraminghamClient - INFO - Loaded framingham_part1.csv with shape (1060, 16)
# 2025-05-24 12:24:29,162 - DP_SA_FraminghamClient - INFO - Class distribution: {0: 884, 1: 176}
# 2025-05-24 12:24:29,170 - DP_SA_FraminghamClient - INFO - Model initialized with input size 15
# 2025-05-24 12:24:29,171 - DP_SA_FraminghamClient - INFO - ✅ Client 0 initialized as honest
# 2025-05-24 12:24:29,172 - DP_SA_FraminghamClient - INFO - DP initialized: ε=8.0, δ=1e-05, noise_multiplier=1.0
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 12:24:29,173 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 12:24:29,176 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 12:24:29,196 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 12:24:29,201 - flwr - DEBUG - ChannelConnectivity.READY
# INFO :
# 2025-05-24 12:24:29,207 - flwr - INFO -
# INFO :      Received: train message a45b0cb5-626a-4de0-8dab-cec51de5cc10
# 2025-05-24 12:24:29,209 - flwr - INFO - Received: train message a45b0cb5-626a-4de0-8dab-cec51de5cc10
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:29,211 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:29,218 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:29,232 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5971
# 2025-05-24 12:24:29,237 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.7023
# 2025-05-24 12:24:29,316 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6888
# ✅ Honest client mode for client 0
#
# ===== DP+SA Framingham FL Client 0 (✅ HONEST) =====
# Server:              localhost:8080
# Data file:           framingham_part1.csv
# Local epochs:        3
# Batch size:          32
# Device:              cuda
# Poisoning enabled:   False
# ==============================================
# 2025-05-24 12:24:29,405 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5368
# 2025-05-24 12:24:29,409 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.7012
# 2025-05-24 12:24:29,485 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.7051
# 2025-05-24 12:24:29,540 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5776
# 2025-05-24 12:24:29,543 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.6933
# 2025-05-24 12:24:29,585 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.6993
# 2025-05-24 12:24:29,623 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6126
# 2025-05-24 12:24:29,626 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.6768
# 2025-05-24 12:24:29,652 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.6900
# 2025-05-24 12:24:29,660 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5800
# 2025-05-24 12:24:29,662 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6969
# 2025-05-24 12:24:29,703 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.6725
# 2025-05-24 12:24:29,742 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5536
# 2025-05-24 12:24:29,746 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.6919
# 2025-05-24 12:24:29,786 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.6826
# 2025-05-24 12:24:29,830 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5571
# 2025-05-24 12:24:29,833 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.6910
# 2025-05-24 12:24:29,876 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6634
# 2025-05-24 12:24:29,930 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6514
# 2025-05-24 12:24:29,934 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.6803
# 2025-05-24 12:24:29,977 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.6804
# 2025-05-24 12:24:29,995 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4856
# 2025-05-24 12:24:29,999 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.6852
# 2025-05-24 12:24:30,048 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.6818
# 2025-05-24 12:24:30,100 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5394
# 2025-05-24 12:24:30,104 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.6706
# 2025-05-24 12:24:30,146 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.6687
# 2025-05-24 12:24:30,182 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5651
# 2025-05-24 12:24:30,184 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.6755
# 2025-05-24 12:24:30,220 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.6729
# 2025-05-24 12:24:30,260 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5475
# 2025-05-24 12:24:30,263 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6679
# 2025-05-24 12:24:30,286 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.6755
# 2025-05-24 12:24:30,287 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.6820, Accuracy: 0.6088
# 2025-05-24 12:24:30,288 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.282953
# 2025-05-24 12:24:30,290 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:30,293 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:30,373 - flwr - INFO -
# INFO :      Received: evaluate message fae59298-88d0-4d9d-9932-b7350f4efe74
# 2025-05-24 12:24:30,374 - flwr - INFO - Received: evaluate message fae59298-88d0-4d9d-9932-b7350f4efe74
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:30,377 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:30,382 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:30,457 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.6649, Accuracy: 0.8113
# INFO :      Sent reply
# 2025-05-24 12:24:30,460 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:30,477 - flwr - INFO -
# INFO :      Received: train message 5ac195d8-b629-4aed-89f5-05d25a596542
# 2025-05-24 12:24:30,479 - flwr - INFO - Received: train message 5ac195d8-b629-4aed-89f5-05d25a596542
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:30,481 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:30,486 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:30,495 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4848
# 2025-05-24 12:24:30,497 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.6891
# 2025-05-24 12:24:30,541 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6516
# 2025-05-24 12:24:30,587 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5585
# 2025-05-24 12:24:30,590 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.6615
# 2025-05-24 12:24:30,635 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.6521
# 2025-05-24 12:24:30,680 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5920
# 2025-05-24 12:24:30,684 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.6623
# 2025-05-24 12:24:30,729 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.6574
# 2025-05-24 12:24:30,773 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4402
# 2025-05-24 12:24:30,778 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.6549
# 2025-05-24 12:24:30,819 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.6658
# 2025-05-24 12:24:30,830 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.7494
# 2025-05-24 12:24:30,835 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6441
# 2025-05-24 12:24:30,881 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.6697
# 2025-05-24 12:24:30,921 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6141
# 2025-05-24 12:24:30,924 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.6587
# 2025-05-24 12:24:30,972 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.6473
# 2025-05-24 12:24:31,013 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4316
# 2025-05-24 12:24:31,015 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.6694
# 2025-05-24 12:24:31,058 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6501
# 2025-05-24 12:24:31,097 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4317
# 2025-05-24 12:24:31,101 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.6428
# 2025-05-24 12:24:31,152 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.6604
# 2025-05-24 12:24:31,164 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4389
# 2025-05-24 12:24:31,167 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.6803
# 2025-05-24 12:24:31,210 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.6492
# 2025-05-24 12:24:31,253 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4283
# 2025-05-24 12:24:31,255 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.6758
# 2025-05-24 12:24:31,297 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.6637
# 2025-05-24 12:24:31,334 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3918
# 2025-05-24 12:24:31,336 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.6923
# 2025-05-24 12:24:31,375 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.6586
# 2025-05-24 12:24:31,417 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5124
# 2025-05-24 12:24:31,420 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6480
# 2025-05-24 12:24:31,449 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.6533
# 2025-05-24 12:24:31,451 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.6598, Accuracy: 0.7333
# 2025-05-24 12:24:31,453 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.318125
# 2025-05-24 12:24:31,455 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:31,457 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:31,565 - flwr - INFO -
# INFO :      Received: evaluate message 272c3af9-5a25-42b5-9ca1-a0471231257d
# 2025-05-24 12:24:31,567 - flwr - INFO - Received: evaluate message 272c3af9-5a25-42b5-9ca1-a0471231257d
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:31,570 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:31,576 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:31,658 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.6427, Accuracy: 0.8302
# INFO :      Sent reply
# 2025-05-24 12:24:31,660 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:31,678 - flwr - INFO -
# INFO :      Received: train message 3bb1f979-44f9-40fc-a741-4a68b7f1696b
# 2025-05-24 12:24:31,680 - flwr - INFO - Received: train message 3bb1f979-44f9-40fc-a741-4a68b7f1696b
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:31,682 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:31,686 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:31,696 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4982
# 2025-05-24 12:24:31,700 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.6423
# 2025-05-24 12:24:31,747 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6486
# 2025-05-24 12:24:31,799 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4806
# 2025-05-24 12:24:31,802 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.6440
# 2025-05-24 12:24:31,854 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.6421
# 2025-05-24 12:24:31,899 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5251
# 2025-05-24 12:24:31,903 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.6544
# 2025-05-24 12:24:31,940 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.6385
# 2025-05-24 12:24:31,982 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6316
# 2025-05-24 12:24:31,984 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.6273
# 2025-05-24 12:24:32,007 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.6444
# 2025-05-24 12:24:32,017 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5419
# 2025-05-24 12:24:32,020 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6366
# 2025-05-24 12:24:32,061 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.6322
# 2025-05-24 12:24:32,110 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5423
# 2025-05-24 12:24:32,113 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.6283
# 2025-05-24 12:24:32,164 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.6479
# 2025-05-24 12:24:32,200 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5242
# 2025-05-24 12:24:32,203 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.6152
# 2025-05-24 12:24:32,240 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6416
# 2025-05-24 12:24:32,278 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4457
# 2025-05-24 12:24:32,281 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.6528
# 2025-05-24 12:24:32,332 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.6348
# 2025-05-24 12:24:32,348 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6328
# 2025-05-24 12:24:32,354 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.6110
# 2025-05-24 12:24:32,406 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.6364
# 2025-05-24 12:24:32,449 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4690
# 2025-05-24 12:24:32,453 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.6395
# 2025-05-24 12:24:32,492 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.6243
# 2025-05-24 12:24:32,530 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5244
# 2025-05-24 12:24:32,534 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.6115
# 2025-05-24 12:24:32,572 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.6239
# 2025-05-24 12:24:32,610 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4569
# 2025-05-24 12:24:32,612 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6708
# 2025-05-24 12:24:32,636 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.6297
# 2025-05-24 12:24:32,637 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.6363, Accuracy: 0.8060
# 2025-05-24 12:24:32,639 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.404003
# 2025-05-24 12:24:32,640 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:32,643 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:32,724 - flwr - INFO -
# INFO :      Received: evaluate message 2a9b0df5-c892-4c0f-8711-e972d302e7b7
# 2025-05-24 12:24:32,726 - flwr - INFO - Received: evaluate message 2a9b0df5-c892-4c0f-8711-e972d302e7b7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:32,728 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:32,733 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:32,844 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.6227, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 12:24:32,847 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:32,865 - flwr - INFO -
# INFO :      Received: train message ae80c8c2-b233-4927-b937-7fb2a99c18b2
# 2025-05-24 12:24:32,867 - flwr - INFO - Received: train message ae80c8c2-b233-4927-b937-7fb2a99c18b2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:32,869 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:32,875 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:32,884 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4058
# 2025-05-24 12:24:32,887 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.6268
# 2025-05-24 12:24:32,939 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6430
# 2025-05-24 12:24:32,981 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4714
# 2025-05-24 12:24:32,984 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.6077
# 2025-05-24 12:24:33,024 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.6597
# 2025-05-24 12:24:33,064 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5071
# 2025-05-24 12:24:33,067 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.6072
# 2025-05-24 12:24:33,106 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.6445
# 2025-05-24 12:24:33,161 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3652
# 2025-05-24 12:24:33,164 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.6302
# 2025-05-24 12:24:33,188 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.6232
# 2025-05-24 12:24:33,195 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3926
# 2025-05-24 12:24:33,198 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6328
# 2025-05-24 12:24:33,239 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.6144
# 2025-05-24 12:24:33,277 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5716
# 2025-05-24 12:24:33,280 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.6091
# 2025-05-24 12:24:33,317 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.6032
# 2025-05-24 12:24:33,353 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3123
# 2025-05-24 12:24:33,355 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.6489
# 2025-05-24 12:24:33,393 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6220
# 2025-05-24 12:24:33,430 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3405
# 2025-05-24 12:24:33,432 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.6387
# 2025-05-24 12:24:33,456 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.6196
# 2025-05-24 12:24:33,464 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5157
# 2025-05-24 12:24:33,467 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.5975
# 2025-05-24 12:24:33,505 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.6173
# 2025-05-24 12:24:33,544 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5546
# 2025-05-24 12:24:33,547 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.5941
# 2025-05-24 12:24:33,586 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.6166
# 2025-05-24 12:24:33,622 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5090
# 2025-05-24 12:24:33,625 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.6199
# 2025-05-24 12:24:33,665 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.6334
# 2025-05-24 12:24:33,701 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5428
# 2025-05-24 12:24:33,703 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6025
# 2025-05-24 12:24:33,727 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.6129
# 2025-05-24 12:24:33,728 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.6186, Accuracy: 0.8280
# 2025-05-24 12:24:33,730 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.471744
# 2025-05-24 12:24:33,731 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:33,735 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:33,859 - flwr - INFO -
# INFO :      Received: evaluate message 933f2d5e-d053-430f-a6da-cae1529e6ca2
# 2025-05-24 12:24:33,862 - flwr - INFO - Received: evaluate message 933f2d5e-d053-430f-a6da-cae1529e6ca2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:33,863 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:33,868 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:33,945 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.6034, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 12:24:33,947 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:33,969 - flwr - INFO -
# INFO :      Received: train message 43709dc5-53ad-4b5b-9f15-80c1c86ea31f
# 2025-05-24 12:24:33,974 - flwr - INFO - Received: train message 43709dc5-53ad-4b5b-9f15-80c1c86ea31f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:33,978 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:33,986 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:34,002 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2995
# 2025-05-24 12:24:34,008 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.6636
# 2025-05-24 12:24:34,062 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6131
# 2025-05-24 12:24:34,115 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2927
# 2025-05-24 12:24:34,118 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.6455
# 2025-05-24 12:24:34,173 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.6048
# 2025-05-24 12:24:34,225 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3766
# 2025-05-24 12:24:34,229 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.6305
# 2025-05-24 12:24:34,271 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.5664
# 2025-05-24 12:24:34,306 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5237
# 2025-05-24 12:24:34,309 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.5840
# 2025-05-24 12:24:34,330 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.6081
# 2025-05-24 12:24:34,339 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4881
# 2025-05-24 12:24:34,341 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.6070
# 2025-05-24 12:24:34,383 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.5891
# 2025-05-24 12:24:34,420 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4507
# 2025-05-24 12:24:34,424 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.6382
# 2025-05-24 12:24:34,458 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.5947
# 2025-05-24 12:24:34,492 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3293
# 2025-05-24 12:24:34,494 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.6234
# 2025-05-24 12:24:34,534 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6224
# 2025-05-24 12:24:34,569 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4254
# 2025-05-24 12:24:34,571 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.6049
# 2025-05-24 12:24:34,593 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.6042
# 2025-05-24 12:24:34,600 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5393
# 2025-05-24 12:24:34,603 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.5846
# 2025-05-24 12:24:34,638 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5966
# 2025-05-24 12:24:34,671 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3354
# 2025-05-24 12:24:34,674 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.6210
# 2025-05-24 12:24:34,722 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.6359
# 2025-05-24 12:24:34,761 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3526
# 2025-05-24 12:24:34,764 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.6317
# 2025-05-24 12:24:34,801 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.5861
# 2025-05-24 12:24:34,838 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2545
# 2025-05-24 12:24:34,841 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6572
# 2025-05-24 12:24:34,866 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.5985
# 2025-05-24 12:24:34,868 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.6036, Accuracy: 0.8299
# 2025-05-24 12:24:34,869 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.493725
# 2025-05-24 12:24:34,871 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:34,874 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:35,029 - flwr - INFO -
# INFO :      Received: evaluate message 33fe4410-9540-452a-8713-c44fc318d2b6
# 2025-05-24 12:24:35,031 - flwr - INFO - Received: evaluate message 33fe4410-9540-452a-8713-c44fc318d2b6
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:35,033 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:35,038 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:35,116 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.5907, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 12:24:35,118 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:35,145 - flwr - INFO -
# INFO :      Received: train message b9b19076-c023-406f-b710-6b3f2c697a75
# 2025-05-24 12:24:35,149 - flwr - INFO - Received: train message b9b19076-c023-406f-b710-6b3f2c697a75
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:35,152 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:35,160 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:35,172 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5357
# 2025-05-24 12:24:35,177 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.5650
# 2025-05-24 12:24:35,235 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6122
# 2025-05-24 12:24:35,288 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3705
# 2025-05-24 12:24:35,292 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.5988
# 2025-05-24 12:24:35,333 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.5772
# 2025-05-24 12:24:35,369 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5110
# 2025-05-24 12:24:35,371 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.5775
# 2025-05-24 12:24:35,412 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.5825
# 2025-05-24 12:24:35,447 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4501
# 2025-05-24 12:24:35,451 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.5806
# 2025-05-24 12:24:35,472 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.5916
# 2025-05-24 12:24:35,482 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4221
# 2025-05-24 12:24:35,485 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.5956
# 2025-05-24 12:24:35,523 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.5429
# 2025-05-24 12:24:35,566 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5269
# 2025-05-24 12:24:35,569 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.5622
# 2025-05-24 12:24:35,607 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.5938
# 2025-05-24 12:24:35,646 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4827
# 2025-05-24 12:24:35,649 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.5773
# 2025-05-24 12:24:35,692 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.5709
# 2025-05-24 12:24:35,747 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3943
# 2025-05-24 12:24:35,752 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.5947
# 2025-05-24 12:24:35,781 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.5903
# 2025-05-24 12:24:35,787 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4049
# 2025-05-24 12:24:35,790 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.5746
# 2025-05-24 12:24:35,829 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5383
# 2025-05-24 12:24:35,870 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3672
# 2025-05-24 12:24:35,872 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.5935
# 2025-05-24 12:24:35,909 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.5901
# 2025-05-24 12:24:35,945 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3518
# 2025-05-24 12:24:35,948 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.5950
# 2025-05-24 12:24:35,983 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.6367
# 2025-05-24 12:24:36,022 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4579
# 2025-05-24 12:24:36,026 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.5806
# 2025-05-24 12:24:36,051 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.5859
# 2025-05-24 12:24:36,052 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.5893, Accuracy: 0.8330
# 2025-05-24 12:24:36,055 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.580761
# 2025-05-24 12:24:36,056 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:36,058 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:36,173 - flwr - INFO -
# INFO :      Received: evaluate message a3cbd3b7-5413-4c0b-abda-52d8ac64d33f
# 2025-05-24 12:24:36,175 - flwr - INFO - Received: evaluate message a3cbd3b7-5413-4c0b-abda-52d8ac64d33f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:36,178 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:36,183 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:36,265 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.5776, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 12:24:36,267 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:36,309 - flwr - INFO -
# INFO :      Received: train message 367395ea-444a-42f7-937e-a71a29d41ce0
# 2025-05-24 12:24:36,314 - flwr - INFO - Received: train message 367395ea-444a-42f7-937e-a71a29d41ce0
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:36,318 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:36,327 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:36,353 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3998
# 2025-05-24 12:24:36,360 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.6066
# 2025-05-24 12:24:36,411 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.6073
# 2025-05-24 12:24:36,463 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4904
# 2025-05-24 12:24:36,466 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.5525
# 2025-05-24 12:24:36,508 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.5620
# 2025-05-24 12:24:36,553 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4029
# 2025-05-24 12:24:36,556 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.5765
# 2025-05-24 12:24:36,598 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.5479
# 2025-05-24 12:24:36,638 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3456
# 2025-05-24 12:24:36,641 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.6345
# 2025-05-24 12:24:36,666 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.5793
# 2025-05-24 12:24:36,674 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3967
# 2025-05-24 12:24:36,677 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.5760
# 2025-05-24 12:24:36,714 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.6184
# 2025-05-24 12:24:36,751 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3889
# 2025-05-24 12:24:36,753 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.5697
# 2025-05-24 12:24:36,794 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.5733
# 2025-05-24 12:24:36,833 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5195
# 2025-05-24 12:24:36,836 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.5497
# 2025-05-24 12:24:36,878 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.6125
# 2025-05-24 12:24:36,913 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4258
# 2025-05-24 12:24:36,916 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.5697
# 2025-05-24 12:24:36,946 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.5793
# 2025-05-24 12:24:36,954 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5329
# 2025-05-24 12:24:36,957 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.5356
# 2025-05-24 12:24:37,018 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5241
# 2025-05-24 12:24:37,080 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4567
# 2025-05-24 12:24:37,082 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.5794
# 2025-05-24 12:24:37,123 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.5672
# 2025-05-24 12:24:37,160 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5185
# 2025-05-24 12:24:37,162 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.5412
# 2025-05-24 12:24:37,201 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.6541
# 2025-05-24 12:24:37,236 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4243
# 2025-05-24 12:24:37,239 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.5772
# 2025-05-24 12:24:37,262 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.5759
# 2025-05-24 12:24:37,263 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.5782, Accuracy: 0.8336
# 2025-05-24 12:24:37,264 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 10.605106
# 2025-05-24 12:24:37,266 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:37,268 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:37,454 - flwr - INFO -
# INFO :      Received: evaluate message 0c3433fe-3818-4f66-829c-6c037f4d291c
# 2025-05-24 12:24:37,456 - flwr - INFO - Received: evaluate message 0c3433fe-3818-4f66-829c-6c037f4d291c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:37,458 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:37,464 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:37,535 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.5647, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 12:24:37,537 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:37,557 - flwr - INFO -
# INFO :      Received: train message 13d072ca-e634-4922-87a5-45e2c493c6fb
# 2025-05-24 12:24:37,559 - flwr - INFO - Received: train message 13d072ca-e634-4922-87a5-45e2c493c6fb
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:37,562 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:37,568 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:37,578 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3955
# 2025-05-24 12:24:37,582 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.5646
# 2025-05-24 12:24:37,650 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.5782
# 2025-05-24 12:24:37,699 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3602
# 2025-05-24 12:24:37,702 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.5703
# 2025-05-24 12:24:37,756 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.5513
# 2025-05-24 12:24:37,802 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4012
# 2025-05-24 12:24:37,806 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.5875
# 2025-05-24 12:24:37,851 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.5782
# 2025-05-24 12:24:37,891 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4885
# 2025-05-24 12:24:37,894 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.5379
# 2025-05-24 12:24:37,920 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.5718
# 2025-05-24 12:24:37,930 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4673
# 2025-05-24 12:24:37,932 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.5548
# 2025-05-24 12:24:37,976 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.5703
# 2025-05-24 12:24:38,019 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2748
# 2025-05-24 12:24:38,021 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.6028
# 2025-05-24 12:24:38,060 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.5812
# 2025-05-24 12:24:38,097 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3470
# 2025-05-24 12:24:38,100 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.5966
# 2025-05-24 12:24:38,139 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.5653
# 2025-05-24 12:24:38,178 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4584
# 2025-05-24 12:24:38,181 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.5187
# 2025-05-24 12:24:38,221 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.5602
# 2025-05-24 12:24:38,232 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3509
# 2025-05-24 12:24:38,236 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.6015
# 2025-05-24 12:24:38,294 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5412
# 2025-05-24 12:24:38,335 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4866
# 2025-05-24 12:24:38,339 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.5496
# 2025-05-24 12:24:38,379 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.5825
# 2025-05-24 12:24:38,418 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3453
# 2025-05-24 12:24:38,420 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.5968
# 2025-05-24 12:24:38,462 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.5449
# 2025-05-24 12:24:38,498 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3032
# 2025-05-24 12:24:38,501 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6013
# 2025-05-24 12:24:38,524 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.5606
# 2025-05-24 12:24:38,525 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.5642, Accuracy: 0.8336
# ...
# 2025-05-24 12:24:51,090 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.4977
# 2025-05-24 12:24:51,152 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.4916
# 2025-05-24 12:24:51,230 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4367
# 2025-05-24 12:24:51,233 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.5357
# 2025-05-24 12:24:51,285 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.4662
# 2025-05-24 12:24:51,334 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2928
# 2025-05-24 12:24:51,338 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.4413
# 2025-05-24 12:24:51,409 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.4578
# 2025-05-24 12:24:51,465 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2464
# 2025-05-24 12:24:51,469 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.4170
# 2025-05-24 12:24:51,506 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.4341
# 2025-05-24 12:24:51,514 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3186
# 2025-05-24 12:24:51,519 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.2676
# 2025-05-24 12:24:51,567 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.4544
# 2025-05-24 12:24:51,618 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3844
# 2025-05-24 12:24:51,621 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.4976
# 2025-05-24 12:24:51,664 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.4397
# 2025-05-24 12:24:51,701 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2740
# 2025-05-24 12:24:51,704 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.3283
# 2025-05-24 12:24:51,765 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.5717
# 2025-05-24 12:24:51,807 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5856
# 2025-05-24 12:24:51,810 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.6501
# 2025-05-24 12:24:51,836 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.4348
# 2025-05-24 12:24:51,837 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.4331, Accuracy: 0.8346
# 2025-05-24 12:24:51,839 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 11.610081
# 2025-05-24 12:24:51,840 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:51,842 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:51,927 - flwr - INFO -
# INFO :      Received: evaluate message 1cd30d61-cd88-4200-b305-5aea2c9172ac
# 2025-05-24 12:24:51,929 - flwr - INFO - Received: evaluate message 1cd30d61-cd88-4200-b305-5aea2c9172ac
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:51,931 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:51,937 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:52,061 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.4192, Accuracy: 0.8340
# INFO :      Sent reply
# 2025-05-24 12:24:52,062 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:52,079 - flwr - INFO -
# INFO :      Received: train message 2ce6e2fa-2451-4755-b19e-6e9df8c05ef9
# 2025-05-24 12:24:52,082 - flwr - INFO - Received: train message 2ce6e2fa-2451-4755-b19e-6e9df8c05ef9
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:52,084 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:52,090 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:52,098 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4490
# 2025-05-24 12:24:52,101 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.5962
# 2025-05-24 12:24:52,156 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.3781
# 2025-05-24 12:24:52,215 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2982
# 2025-05-24 12:24:52,221 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.3917
# 2025-05-24 12:24:52,292 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.4499
# 2025-05-24 12:24:52,338 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3733
# 2025-05-24 12:24:52,341 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.5138
# 2025-05-24 12:24:52,391 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.4872
# 2025-05-24 12:24:52,431 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3445
# 2025-05-24 12:24:52,434 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.4444
# 2025-05-24 12:24:52,457 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.4278
# 2025-05-24 12:24:52,465 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.5736
# 2025-05-24 12:24:52,468 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.5569
# 2025-05-24 12:24:52,513 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.4640
# 2025-05-24 12:24:52,591 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3969
# 2025-05-24 12:24:52,596 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.3984
# 2025-05-24 12:24:52,651 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.4182
# 2025-05-24 12:24:52,695 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3337
# 2025-05-24 12:24:52,699 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.3503
# 2025-05-24 12:24:52,741 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.3255
# 2025-05-24 12:24:52,783 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4589
# 2025-05-24 12:24:52,787 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.4849
# 2025-05-24 12:24:52,817 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.4263
# 2025-05-24 12:24:52,825 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3249
# 2025-05-24 12:24:52,828 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.3083
# 2025-05-24 12:24:52,884 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.3641
# 2025-05-24 12:24:52,943 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.6209
# 2025-05-24 12:24:52,945 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.2684
# 2025-05-24 12:24:52,988 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.3446
# 2025-05-24 12:24:53,026 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3646
# 2025-05-24 12:24:53,029 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.4400
# 2025-05-24 12:24:53,065 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.5167
# 2025-05-24 12:24:53,106 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4059
# 2025-05-24 12:24:53,108 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.5130
# 2025-05-24 12:24:53,131 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.4278
# 2025-05-24 12:24:53,132 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.4273, Accuracy: 0.8343
# 2025-05-24 12:24:53,134 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 11.712793
# 2025-05-24 12:24:53,135 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:53,137 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:53,248 - flwr - INFO -
# INFO :      Received: evaluate message 2184de35-67bf-4376-9604-a6fa2f4ab454
# 2025-05-24 12:24:53,252 - flwr - INFO - Received: evaluate message 2184de35-67bf-4376-9604-a6fa2f4ab454
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:53,255 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:53,262 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:53,342 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.4190, Accuracy: 0.8349
# INFO :      Sent reply
# 2025-05-24 12:24:53,344 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:53,368 - flwr - INFO -
# INFO :      Received: train message 2c6625dc-595e-401f-b358-8bf40b90f99d
# 2025-05-24 12:24:53,370 - flwr - INFO - Received: train message 2c6625dc-595e-401f-b358-8bf40b90f99d
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:53,372 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:53,378 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:53,388 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2599
# 2025-05-24 12:24:53,392 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 0/34 - Loss: 0.3183
# 2025-05-24 12:24:53,443 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 5/34 - Loss: 0.3581
# 2025-05-24 12:24:53,516 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2295
# 2025-05-24 12:24:53,520 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 10/34 - Loss: 0.3741
# 2025-05-24 12:24:53,582 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 15/34 - Loss: 0.4584
# 2025-05-24 12:24:53,628 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4508
# 2025-05-24 12:24:53,631 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 20/34 - Loss: 0.4849
# 2025-05-24 12:24:53,676 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 25/34 - Loss: 0.3767
# 2025-05-24 12:24:53,725 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3315
# 2025-05-24 12:24:53,728 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1/3 - Batch 30/34 - Loss: 0.3864
# 2025-05-24 12:24:53,757 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 1 complete - Loss: 0.4262
# 2025-05-24 12:24:53,768 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.9922
# 2025-05-24 12:24:53,771 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 0/34 - Loss: 0.7413
# 2025-05-24 12:24:53,842 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 5/34 - Loss: 0.3976
# 2025-05-24 12:24:53,895 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3854
# 2025-05-24 12:24:53,899 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 10/34 - Loss: 0.4880
# 2025-05-24 12:24:53,944 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 15/34 - Loss: 0.6167
# 2025-05-24 12:24:53,995 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2971
# 2025-05-24 12:24:53,999 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 20/34 - Loss: 0.4094
# 2025-05-24 12:24:54,043 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 25/34 - Loss: 0.4075
# 2025-05-24 12:24:54,088 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3366
# 2025-05-24 12:24:54,092 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2/3 - Batch 30/34 - Loss: 0.3040
# 2025-05-24 12:24:54,117 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 2 complete - Loss: 0.4350
# 2025-05-24 12:24:54,130 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2652
# 2025-05-24 12:24:54,133 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 0/34 - Loss: 0.4337
# 2025-05-24 12:24:54,177 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 5/34 - Loss: 0.5857
# 2025-05-24 12:24:54,244 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.2944
# 2025-05-24 12:24:54,249 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 10/34 - Loss: 0.3825
# 2025-05-24 12:24:54,301 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 15/34 - Loss: 0.3310
# 2025-05-24 12:24:54,339 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.4596
# 2025-05-24 12:24:54,341 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 20/34 - Loss: 0.5648
# 2025-05-24 12:24:54,398 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 25/34 - Loss: 0.3965
# 2025-05-24 12:24:54,456 - DP_SA_FraminghamClient - INFO - Client 0 DP applied: grad_norm=0.3184
# 2025-05-24 12:24:54,459 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3/3 - Batch 30/34 - Loss: 0.2351
# 2025-05-24 12:24:54,484 - DP_SA_FraminghamClient - INFO - Client 0 - Epoch 3 complete - Loss: 0.4281
# 2025-05-24 12:24:54,486 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest training finished - Loss: 0.4298, Accuracy: 0.8336
# 2025-05-24 12:24:54,487 - DP_SA_FraminghamClient - INFO - Client 0 original parameters norm: 11.774621
# 2025-05-24 12:24:54,489 - DP_SA_FraminghamClient - INFO - Client 0 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 12:24:54,491 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:54,661 - flwr - INFO -
# INFO :      Received: evaluate message fabdc224-296a-40da-bd92-36230fcf78ac
# 2025-05-24 12:24:54,664 - flwr - INFO - Received: evaluate message fabdc224-296a-40da-bd92-36230fcf78ac
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:54,668 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 12:24:54,675 - DP_SA_FraminghamClient - INFO - Client 0: parameters updated from server
# 2025-05-24 12:24:54,766 - DP_SA_FraminghamClient - INFO - ✅ Client 0 honest evaluation - Loss: 0.4206, Accuracy: 0.8349
# INFO :      Sent reply
# 2025-05-24 12:24:54,768 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 12:24:55,417 - flwr - INFO -
# INFO :      Received: reconnect message 9da98197-4372-4f1b-b108-0f0884483c18
# 2025-05-24 12:24:55,419 - flwr - INFO - Received: reconnect message 9da98197-4372-4f1b-b108-0f0884483c18
# 2025-05-24 12:24:55,456 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 12:24:55,459 - flwr - INFO - Disconnect and shut down
