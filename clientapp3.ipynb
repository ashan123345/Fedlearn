# %%
test version clinet 3 cuurently running

# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger("DP_SA_FraminghamClient")

CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01,

    # Differential Privacy parameters
    "dp_enabled": True,
    "dp_noise_multiplier": 1.0,
    "dp_max_grad_norm": 1.0,
    "dp_epsilon": 8.0,
    "dp_delta": 1e-5,

    # Secure Aggregation parameters
    "sa_enabled": True,
    "sa_noise_scale": 1e-3,

    # Additional security flags
    "smpc_enabled": False,
    "he_enabled": False,
}

class DifferentialPrivacyMechanism:
    def __init__(self, noise_multiplier, max_grad_norm, epsilon, delta):
        self.noise_multiplier = noise_multiplier
        self.max_grad_norm = max_grad_norm
        self.epsilon = epsilon
        self.delta = delta
        logger.info(f"DP initialized: ε={epsilon}, δ={delta}, noise_multiplier={noise_multiplier}")

    def clip_gradients(self, model):
        total_norm = 0.0
        for param in model.parameters():
            if param.grad is not None:
                param_norm = param.grad.data.norm(2)
                total_norm += param_norm.item() ** 2
        total_norm = total_norm ** 0.5

        clip_coef = self.max_grad_norm / (total_norm + 1e-6)
        if clip_coef < 1:
            for param in model.parameters():
                if param.grad is not None:
                    param.grad.data.mul_(clip_coef)
        return total_norm

    def add_noise(self, model):
        noise_scale = self.noise_multiplier * self.max_grad_norm
        for param in model.parameters():
            if param.grad is not None:
                noise = torch.normal(0, noise_scale, size=param.grad.shape, device=param.grad.device)
                param.grad.data.add_(noise)

class SecureAggregation:
    def __init__(self, noise_scale=1e-3):
        self.noise_scale = noise_scale

    def add_random_mask(self, parameters):
        masked_params = []
        for param in parameters:
            mask = np.random.normal(0, self.noise_scale, param.shape)
            masked_params.append(param + mask)
        return masked_params

class PrivacyEnhancedHeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

class PrivacyAwareFedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super().__init__()
        self.base_criterion = base_criterion
        self.mu = mu

    def forward(self, y_pred, y_true, model_params, global_params):
        base_loss = self.base_criterion(y_pred, y_true)
        proximal_term = 0.0
        if global_params is not None:
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
            loss = base_loss + (self.mu / 2) * proximal_term
        else:
            loss = base_loss
        return loss

def load_data(data_path):
    try:
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Dropping {missing_values} rows with missing data")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing data: {df.shape}")
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' missing")
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        return dataloader, X.shape[1]
    except Exception as e:
        logger.error(f"Error loading data: {e}")
        raise

class DP_SA_Client(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device, client_id):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.global_params = None

        self.dp_enabled = CLIENT_CONFIG["dp_enabled"]
        if self.dp_enabled:
            self.dp_mechanism = DifferentialPrivacyMechanism(
                CLIENT_CONFIG["dp_noise_multiplier"],
                CLIENT_CONFIG["dp_max_grad_norm"],
                CLIENT_CONFIG["dp_epsilon"],
                CLIENT_CONFIG["dp_delta"]
            )

        self.sa_enabled = CLIENT_CONFIG["sa_enabled"]
        if self.sa_enabled:
            self.secure_agg = SecureAggregation(noise_scale=CLIENT_CONFIG["sa_noise_scale"])

    def get_parameters(self, config):
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]

        if self.sa_enabled:
            params = self.secure_agg.add_random_mask(params)
            logger.info(f"Client {self.client_id} applied Secure Aggregation masking")

        return params

    def set_parameters(self, parameters):
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        criterion = nn.BCELoss()
        proximal_criterion = PrivacyAwareFedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        optimizer = torch.optim.Adam(self.model.parameters(), lr=CLIENT_CONFIG["learning_rate"], weight_decay=CLIENT_CONFIG["weight_decay"])

        total_loss, total_samples, correct = 0.0, 0, 0

        for epoch in range(CLIENT_CONFIG["local_epochs"]):
            epoch_loss, epoch_samples = 0.0, 0
            for batch_idx, (X, y) in enumerate(self.dataloader):
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                loss = proximal_criterion(y_pred, y, self.model.parameters(), self.global_params)
                optimizer.zero_grad()
                loss.backward()

                if self.dp_enabled:
                    grad_norm = self.dp_mechanism.clip_gradients(self.model)
                    self.dp_mechanism.add_noise(self.model)
                    if batch_idx % 10 == 0:
                        logger.info(f"Client {self.client_id} DP applied: grad_norm={grad_norm:.4f}")

                optimizer.step()

                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)

                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()

                if batch_idx % 5 == 0:
                    logger.info(f"Client {self.client_id} - Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - Batch {batch_idx}/{len(self.dataloader)} - Loss: {loss.item():.4f}")
            logger.info(f"Client {self.client_id} - Epoch {epoch+1} complete - Loss: {epoch_loss/epoch_samples:.4f}")

        avg_loss = total_loss / total_samples if total_samples else 0
        accuracy = correct / total_samples if total_samples else 0

        logger.info(f"Client {self.client_id} training finished - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Send security flags back in metrics including client ID
        return self.get_parameters({}), total_samples, {
            "loss": avg_loss,
            "accuracy": accuracy,
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id  # Send client ID here
        }

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.BCELoss()

        loss, total, correct = 0.0, 0, 0

        with torch.no_grad():
            for X, y in self.dataloader:
                X, y = X.to(self.device), y.to(self.device)
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                loss += batch_loss * X.size(0)
                total += X.size(0)
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()

        avg_loss = loss / total if total else 0
        accuracy = correct / total if total else 0

        logger.info(f"Client {self.client_id} evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

        # Send security flags back in metrics including client ID
        return float(avg_loss), total, {
            "accuracy": accuracy,
            "dp_enabled": int(self.dp_enabled),
            "sa_enabled": int(self.sa_enabled),
            "smpc_enabled": int(CLIENT_CONFIG.get("smpc_enabled", False)),
            "he_enabled": int(CLIENT_CONFIG.get("he_enabled", False)),
            "client_id": self.client_id  # Send client ID here
        }

def start_client(client_id=0, server_address=None):
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")

    data_path = f"framingham_part{client_id+1}.csv"
    if not os.path.exists(data_path):
        logger.error(f"Data file {data_path} not found")
        return

    dataloader, input_size = load_data(data_path)

    model = PrivacyEnhancedHeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size {input_size}")

    client = DP_SA_Client(model, dataloader, device, client_id)

    print(f"\n===== DP+SA Framingham FL Client {client_id} =====")
    print(f"Server:              {CLIENT_CONFIG['server_address']}")
    print(f"Data file:           {data_path}")
    print(f"Local epochs:        {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:          {CLIENT_CONFIG['batch_size']}")
    print(f"Device:              {device}")
    print("==============================================\n")

    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

if __name__ == "__main__":
    import sys
    import argparse

    if 'ipykernel' in sys.modules:
        start_client(client_id=2)
    else:
        parser = argparse.ArgumentParser(description="DP+SA Framingham FL Client")
        parser.add_argument("--id", type=int, default=0, help="Client ID")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--disable-sa", action="store_true", help="Disable Secure Aggregation masking")
        parser.add_argument("--dp-epsilon", type=float, default=8.0, help="DP epsilon parameter")
        parser.add_argument("--dp-noise", type=float, default=1.0, help="DP noise multiplier")
        args = parser.parse_args()

        CLIENT_CONFIG["dp_epsilon"] = args.dp_epsilon
        CLIENT_CONFIG["dp_noise_multiplier"] = args.dp_noise
        CLIENT_CONFIG["sa_enabled"] = not args.disable_sa

        start_client(args.id, args.server)
# Out:
# 2025-05-24 22:10:01,328 - DP_SA_FraminghamClient - INFO - Using device: cuda
# 2025-05-24 22:10:01,366 - DP_SA_FraminghamClient - INFO - Loaded framingham_part3.csv with shape (1060, 16)
# 2025-05-24 22:10:01,372 - DP_SA_FraminghamClient - INFO - Class distribution: {0: 898, 1: 162}
# 2025-05-24 22:10:01,503 - DP_SA_FraminghamClient - INFO - Model initialized with input size 15
# 2025-05-24 22:10:01,504 - DP_SA_FraminghamClient - INFO - DP initialized: ε=8.0, δ=1e-05, noise_multiplier=1.0
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 22:10:01,505 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 22:10:01,543 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 22:10:01,558 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 22:10:01,566 - flwr - DEBUG - ChannelConnectivity.READY
# ===== DP+SA Framingham FL Client 2 =====
# Server:              localhost:8080
# Data file:           framingham_part3.csv
# Local epochs:        3
# Batch size:          32
# Device:              cuda
# ==============================================
# INFO :
# 2025-05-24 22:10:02,032 - flwr - INFO -
# INFO :      Received: evaluate message 02e5129a-20e1-45c4-b122-cbb1e56fb490
# 2025-05-24 22:10:02,034 - flwr - INFO - Received: evaluate message 02e5129a-20e1-45c4-b122-cbb1e56fb490
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:02,037 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:02,085 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:02,221 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 0.7014, Accuracy: 0.8472
# INFO :      Sent reply
# 2025-05-24 22:10:02,224 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:02,243 - flwr - INFO -
# INFO :      Received: train message dcc7455b-2715-4bd9-8808-f7874678b15d
# 2025-05-24 22:10:02,247 - flwr - INFO - Received: train message dcc7455b-2715-4bd9-8808-f7874678b15d
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:02,248 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:02,255 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:04,108 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8084
# 2025-05-24 22:10:04,148 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.6489
# 2025-05-24 22:10:04,180 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 0.8946
# 2025-05-24 22:10:04,217 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2963
# 2025-05-24 22:10:04,219 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 0.5933
# 2025-05-24 22:10:04,252 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 0.4287
# 2025-05-24 22:10:04,285 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.7725
# 2025-05-24 22:10:04,288 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 1.1222
# 2025-05-24 22:10:04,319 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.7754
# 2025-05-24 22:10:04,350 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2899
# 2025-05-24 22:10:04,350 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.5852
# 2025-05-24 22:10:04,373 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 0.7108
# 2025-05-24 22:10:04,379 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3134
# 2025-05-24 22:10:04,381 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 0.5206
# 2025-05-24 22:10:04,413 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 0.7214
# 2025-05-24 22:10:04,441 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.8991
# 2025-05-24 22:10:04,446 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.7200
# 2025-05-24 22:10:04,479 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 0.9081
# 2025-05-24 22:10:04,509 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.4419
# 2025-05-24 22:10:04,510 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.6897
# 2025-05-24 22:10:04,543 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 0.6580
# 2025-05-24 22:10:04,572 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8218
# 2025-05-24 22:10:04,572 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 0.8471
# 2025-05-24 22:10:04,595 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 0.7088
# 2025-05-24 22:10:04,602 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.8323
# 2025-05-24 22:10:04,605 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.6685
# 2025-05-24 22:10:04,637 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 0.6450
# 2025-05-24 22:10:04,671 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2502
# 2025-05-24 22:10:04,674 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.4804
# 2025-05-24 22:10:04,710 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 0.6988
# 2025-05-24 22:10:04,741 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5299
# 2025-05-24 22:10:04,744 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 0.8426
# 2025-05-24 22:10:04,774 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 0.3691
# 2025-05-24 22:10:04,806 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4472
# 2025-05-24 22:10:04,809 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.6813
# 2025-05-24 22:10:04,827 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 0.6972
# 2025-05-24 22:10:04,828 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 0.7056, Accuracy: 0.8472
# 2025-05-24 22:10:04,830 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:04,832 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:05,222 - flwr - INFO -
# INFO :      Received: evaluate message 9a4945d3-bc7f-4d26-8f35-11739380cfc7
# 2025-05-24 22:10:05,225 - flwr - INFO - Received: evaluate message 9a4945d3-bc7f-4d26-8f35-11739380cfc7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:05,228 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:05,235 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:05,329 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 0.5548, Accuracy: 0.8472
# INFO :      Sent reply
# 2025-05-24 22:10:05,331 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:05,351 - flwr - INFO -
# INFO :      Received: train message f409b8a6-58b9-471b-b224-af63a51961cd
# 2025-05-24 22:10:05,354 - flwr - INFO - Received: train message f409b8a6-58b9-471b-b224-af63a51961cd
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:05,361 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:05,369 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:05,381 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4377
# 2025-05-24 22:10:05,385 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.4139
# 2025-05-24 22:10:05,432 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 0.6184
# 2025-05-24 22:10:05,472 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4510
# 2025-05-24 22:10:05,475 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 0.5102
# 2025-05-24 22:10:05,517 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 0.8265
# 2025-05-24 22:10:05,559 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4747
# 2025-05-24 22:10:05,561 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 0.5636
# 2025-05-24 22:10:05,601 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.8836
# 2025-05-24 22:10:05,639 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8109
# 2025-05-24 22:10:05,642 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.7664
# 2025-05-24 22:10:05,670 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 0.5854
# 2025-05-24 22:10:05,677 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.6171
# 2025-05-24 22:10:05,681 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 0.6590
# 2025-05-24 22:10:05,723 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 0.8113
# 2025-05-24 22:10:05,763 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.7807
# 2025-05-24 22:10:05,766 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.5702
# 2025-05-24 22:10:05,815 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 0.5628
# 2025-05-24 22:10:05,870 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3786
# 2025-05-24 22:10:05,872 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.4308
# 2025-05-24 22:10:05,914 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 0.4458
# 2025-05-24 22:10:05,957 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3638
# 2025-05-24 22:10:05,960 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 0.5169
# 2025-05-24 22:10:05,983 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 0.5641
# 2025-05-24 22:10:05,990 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3609
# 2025-05-24 22:10:05,993 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.5641
# 2025-05-24 22:10:06,031 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 0.5236
# 2025-05-24 22:10:06,072 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4939
# 2025-05-24 22:10:06,075 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.4703
# 2025-05-24 22:10:06,117 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 0.3670
# 2025-05-24 22:10:06,158 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2105
# 2025-05-24 22:10:06,160 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 0.3727
# 2025-05-24 22:10:06,198 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 0.6035
# 2025-05-24 22:10:06,237 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2693
# 2025-05-24 22:10:06,240 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.3490
# 2025-05-24 22:10:06,261 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 0.5794
# 2025-05-24 22:10:06,261 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 0.5763, Accuracy: 0.8459
# 2025-05-24 22:10:06,265 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:06,268 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:06,628 - flwr - INFO -
# INFO :      Received: evaluate message c77a4f21-0c2c-4e09-ba41-df12e04b88d2
# 2025-05-24 22:10:06,630 - flwr - INFO - Received: evaluate message c77a4f21-0c2c-4e09-ba41-df12e04b88d2
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:06,633 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:06,639 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:06,716 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 0.6199, Accuracy: 0.8472
# INFO :      Sent reply
# 2025-05-24 22:10:06,718 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:06,738 - flwr - INFO -
# INFO :      Received: train message 357a253a-1c0b-4fcd-9633-75ed5e97e3eb
# 2025-05-24 22:10:06,741 - flwr - INFO - Received: train message 357a253a-1c0b-4fcd-9633-75ed5e97e3eb
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:06,748 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:06,757 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:06,776 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3654
# 2025-05-24 22:10:06,782 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.3225
# 2025-05-24 22:10:06,851 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 0.4849
# 2025-05-24 22:10:06,903 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1182
# 2025-05-24 22:10:06,907 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 0.4224
# 2025-05-24 22:10:06,942 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 0.3518
# 2025-05-24 22:10:06,980 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.0603
# 2025-05-24 22:10:06,980 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 1.9296
# 2025-05-24 22:10:07,028 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.6478
# 2025-05-24 22:10:07,062 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.6197
# 2025-05-24 22:10:07,062 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.5889
# 2025-05-24 22:10:07,092 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 0.6669
# 2025-05-24 22:10:07,099 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.2456
# 2025-05-24 22:10:07,105 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 0.8501
# 2025-05-24 22:10:07,146 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 0.7381
# 2025-05-24 22:10:07,192 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.0210
# 2025-05-24 22:10:07,196 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.7657
# 2025-05-24 22:10:07,237 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 0.6807
# 2025-05-24 22:10:07,283 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5039
# 2025-05-24 22:10:07,286 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.4881
# 2025-05-24 22:10:07,331 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 0.9371
# 2025-05-24 22:10:07,370 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.2268
# 2025-05-24 22:10:07,373 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 0.6385
# 2025-05-24 22:10:07,399 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 0.6482
# 2025-05-24 22:10:07,408 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3694
# 2025-05-24 22:10:07,412 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.8929
# 2025-05-24 22:10:07,450 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 0.8470
# 2025-05-24 22:10:07,493 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.6650
# 2025-05-24 22:10:07,498 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.4147
# 2025-05-24 22:10:07,553 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 0.8752
# 2025-05-24 22:10:07,595 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8351
# 2025-05-24 22:10:07,598 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 0.5432
# 2025-05-24 22:10:07,633 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 0.5430
# 2025-05-24 22:10:07,667 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5238
# 2025-05-24 22:10:07,670 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.6219
# 2025-05-24 22:10:07,694 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 0.6489
# 2025-05-24 22:10:07,695 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 0.6546, Accuracy: 0.8453
# 2025-05-24 22:10:07,697 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:07,699 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:08,004 - flwr - INFO -
# INFO :      Received: evaluate message b434620c-146c-48a1-9b6e-f8e4da89f65e
# 2025-05-24 22:10:08,006 - flwr - INFO - Received: evaluate message b434620c-146c-48a1-9b6e-f8e4da89f65e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:08,010 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:08,018 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:08,094 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 0.6230, Accuracy: 0.8472
# INFO :      Sent reply
# 2025-05-24 22:10:08,094 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:08,127 - flwr - INFO -
# INFO :      Received: train message 7e4da06e-52e8-4170-83b6-06fc7bac1620
# 2025-05-24 22:10:08,129 - flwr - INFO - Received: train message 7e4da06e-52e8-4170-83b6-06fc7bac1620
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:08,136 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:08,143 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:08,157 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.1808
# 2025-05-24 22:10:08,163 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.8388
# 2025-05-24 22:10:08,225 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 0.8625
# 2025-05-24 22:10:08,267 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.8503
# 2025-05-24 22:10:08,272 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 1.5349
# 2025-05-24 22:10:08,316 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 0.8883
# 2025-05-24 22:10:08,362 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2303
# 2025-05-24 22:10:08,364 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 0.3067
# 2025-05-24 22:10:08,404 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.6681
# 2025-05-24 22:10:08,441 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8162
# 2025-05-24 22:10:08,444 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.5683
# 2025-05-24 22:10:08,470 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 0.6624
# 2025-05-24 22:10:08,477 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.1334
# 2025-05-24 22:10:08,480 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 0.6101
# 2025-05-24 22:10:08,524 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 0.4039
# 2025-05-24 22:10:08,571 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4959
# 2025-05-24 22:10:08,573 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.4578
# 2025-05-24 22:10:08,613 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 0.4668
# 2025-05-24 22:10:08,662 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.7732
# 2025-05-24 22:10:08,666 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.5602
# 2025-05-24 22:10:08,710 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 1.2242
# 2025-05-24 22:10:08,751 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.1154
# 2025-05-24 22:10:08,753 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 0.6800
# 2025-05-24 22:10:08,780 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 0.6547
# 2025-05-24 22:10:08,789 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.7594
# 2025-05-24 22:10:08,792 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 1.1899
# 2025-05-24 22:10:08,834 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 0.7249
# 2025-05-24 22:10:08,882 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3029
# 2025-05-24 22:10:08,886 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.4386
# 2025-05-24 22:10:08,940 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 0.4970
# 2025-05-24 22:10:08,978 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.6913
# 2025-05-24 22:10:08,981 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 0.9551
# 2025-05-24 22:10:09,017 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 1.1313
# 2025-05-24 22:10:09,051 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1252
# 2025-05-24 22:10:09,053 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.4325
# 2025-05-24 22:10:09,073 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 0.6623
# 2025-05-24 22:10:09,073 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 0.6598, Accuracy: 0.8478
# 2025-05-24 22:10:09,077 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:09,079 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:09,411 - flwr - INFO -
# INFO :      Received: evaluate message d728e25a-467c-4e08-bf7c-579b6d4e05ca
# 2025-05-24 22:10:09,413 - flwr - INFO - Received: evaluate message d728e25a-467c-4e08-bf7c-579b6d4e05ca
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:09,415 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:09,422 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:09,510 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 0.6784, Accuracy: 0.8472
# INFO :      Sent reply
# 2025-05-24 22:10:09,515 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:09,536 - flwr - INFO -
# INFO :      Received: train message 62508e3c-ba4e-4086-b940-2543137ea8ff
# 2025-05-24 22:10:09,538 - flwr - INFO - Received: train message 62508e3c-ba4e-4086-b940-2543137ea8ff
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:09,541 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:09,549 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:09,562 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.0065
# 2025-05-24 22:10:09,567 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.7043
# 2025-05-24 22:10:09,620 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 0.5995
# 2025-05-24 22:10:09,676 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5044
# 2025-05-24 22:10:09,681 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 0.5348
# 2025-05-24 22:10:09,742 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 0.6095
# 2025-05-24 22:10:09,785 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5042
# 2025-05-24 22:10:09,788 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 0.4218
# 2025-05-24 22:10:09,845 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.6071
# 2025-05-24 22:10:09,887 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3830
# 2025-05-24 22:10:09,890 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.4949
# 2025-05-24 22:10:09,913 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 0.7379
# 2025-05-24 22:10:09,924 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.6180
# 2025-05-24 22:10:09,927 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 0.9089
# 2025-05-24 22:10:09,973 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 0.4769
# 2025-05-24 22:10:10,025 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5567
# 2025-05-24 22:10:10,029 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.5765
# 2025-05-24 22:10:10,071 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 1.1135
# 2025-05-24 22:10:10,113 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.9286
# 2025-05-24 22:10:10,116 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.6972
# 2025-05-24 22:10:10,155 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 0.5699
# 2025-05-24 22:10:10,194 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1955
# 2025-05-24 22:10:10,197 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 0.4653
# 2025-05-24 22:10:10,222 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 0.7725
# 2025-05-24 22:10:10,229 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2928
# 2025-05-24 22:10:10,232 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.5192
# 2025-05-24 22:10:10,288 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 0.4388
# 2025-05-24 22:10:10,342 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3740
# 2025-05-24 22:10:10,345 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.3667
# 2025-05-24 22:10:10,406 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 0.4577
# 2025-05-24 22:10:10,448 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.4273
# 2025-05-24 22:10:10,450 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 1.4462
# 2025-05-24 22:10:10,482 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 0.5230
# 2025-05-24 22:10:10,518 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4174
# 2025-05-24 22:10:10,522 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.6300
# 2025-05-24 22:10:10,543 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 0.7353
# 2025-05-24 22:10:10,543 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 0.7486, Accuracy: 0.8428
# 2025-05-24 22:10:10,547 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:10,550 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:10,852 - flwr - INFO -
# INFO :      Received: evaluate message 7b82a98f-72dc-4268-98d1-b05ffed69d72
# 2025-05-24 22:10:10,855 - flwr - INFO - Received: evaluate message 7b82a98f-72dc-4268-98d1-b05ffed69d72
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:10,857 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:10,863 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:10,961 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 1.3326, Accuracy: 0.8453
# INFO :      Sent reply
# 2025-05-24 22:10:10,962 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:10,983 - flwr - INFO -
# INFO :      Received: train message 76061493-12a7-4bf5-8293-3dbc60c59524
# 2025-05-24 22:10:10,986 - flwr - INFO - Received: train message 76061493-12a7-4bf5-8293-3dbc60c59524
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:10,988 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:10,993 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:11,001 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1420
# 2025-05-24 22:10:11,005 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.3561
# 2025-05-24 22:10:11,054 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 0.6768
# 2025-05-24 22:10:11,097 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.7554
# 2025-05-24 22:10:11,100 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 1.1351
# 2025-05-24 22:10:11,136 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 1.3882
# 2025-05-24 22:10:11,177 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3410
# 2025-05-24 22:10:11,182 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 1.6031
# 2025-05-24 22:10:11,219 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.5142
# 2025-05-24 22:10:11,273 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.9538
# 2025-05-24 22:10:11,277 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.7120
# 2025-05-24 22:10:11,313 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 1.6534
# 2025-05-24 22:10:11,327 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.2611
# 2025-05-24 22:10:11,333 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 1.6644
# 2025-05-24 22:10:11,387 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 1.2484
# 2025-05-24 22:10:11,430 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.4473
# 2025-05-24 22:10:11,434 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.9444
# 2025-05-24 22:10:11,476 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 1.6638
# 2025-05-24 22:10:11,522 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.0584
# 2025-05-24 22:10:11,525 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.9511
# 2025-05-24 22:10:11,572 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 1.7146
# 2025-05-24 22:10:11,616 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.5590
# 2025-05-24 22:10:11,619 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 1.0875
# 2025-05-24 22:10:11,646 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 1.3361
# 2025-05-24 22:10:11,653 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3198
# 2025-05-24 22:10:11,657 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.4618
# 2025-05-24 22:10:11,699 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 0.4620
# 2025-05-24 22:10:11,740 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3877
# 2025-05-24 22:10:11,743 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 1.7035
# 2025-05-24 22:10:11,801 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 1.9743
# 2025-05-24 22:10:11,863 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3537
# 2025-05-24 22:10:11,866 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 1.5769
# 2025-05-24 22:10:11,909 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 1.1529
# 2025-05-24 22:10:11,945 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.5089
# 2025-05-24 22:10:11,948 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.9318
# 2025-05-24 22:10:11,970 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 1.4119
# 2025-05-24 22:10:11,971 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 1.4671, Accuracy: 0.8440
# 2025-05-24 22:10:11,973 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:11,976 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:12,367 - flwr - INFO -
# INFO :      Received: evaluate message 3851363f-c3ba-4a27-b0c2-d5e6a8b640a3
# 2025-05-24 22:10:12,369 - flwr - INFO - Received: evaluate message 3851363f-c3ba-4a27-b0c2-d5e6a8b640a3
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:12,371 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:12,376 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:12,440 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 1.3777, Accuracy: 0.8472
# INFO :      Sent reply
# 2025-05-24 22:10:12,440 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:12,479 - flwr - INFO -
# INFO :      Received: train message e85dcfac-c426-4609-8fdc-c566285144ac
# 2025-05-24 22:10:12,482 - flwr - INFO - Received: train message e85dcfac-c426-4609-8fdc-c566285144ac
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:12,484 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:12,490 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:12,500 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8063
# 2025-05-24 22:10:12,504 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.8757
# 2025-05-24 22:10:12,563 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 1.6547
# 2025-05-24 22:10:12,622 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.0768
# 2025-05-24 22:10:12,622 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 0.3548
# 2025-05-24 22:10:12,671 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 1.2255
# 2025-05-24 22:10:12,715 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.8633
# 2025-05-24 22:10:12,718 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 1.1217
# 2025-05-24 22:10:12,759 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 0.5150
# 2025-05-24 22:10:12,795 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.0744
# 2025-05-24 22:10:12,795 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 0.3538
# 2025-05-24 22:10:12,825 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 1.5109
# 2025-05-24 22:10:12,835 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.4320
# 2025-05-24 22:10:12,838 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 1.1957
# 2025-05-24 22:10:12,878 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 2.9200
# 2025-05-24 22:10:12,913 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.1207
# 2025-05-24 22:10:12,918 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.8949
# 2025-05-24 22:10:12,958 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 0.3848
# 2025-05-24 22:10:12,997 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1652
# 2025-05-24 22:10:12,999 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.3263
# 2025-05-24 22:10:13,039 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 1.1608
# 2025-05-24 22:10:13,078 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.1785
# 2025-05-24 22:10:13,080 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 2.1829
# 2025-05-24 22:10:13,112 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 1.4477
# 2025-05-24 22:10:13,121 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1842
# 2025-05-24 22:10:13,125 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.2768
# 2025-05-24 22:10:13,172 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 1.4367
# 2025-05-24 22:10:13,222 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.2965
# 2025-05-24 22:10:13,225 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 1.8075
# 2025-05-24 22:10:13,271 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 1.1862
# 2025-05-24 22:10:13,316 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.7472
# 2025-05-24 22:10:13,321 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 0.7584
# 2025-05-24 22:10:13,356 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 0.4619
# 2025-05-24 22:10:13,392 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.0719
# 2025-05-24 22:10:13,392 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 1.1738
# 2025-05-24 22:10:13,413 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 1.4958
# 2025-05-24 22:10:13,413 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 1.4848, Accuracy: 0.8447
# 2025-05-24 22:10:13,413 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:13,419 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:13,739 - flwr - INFO -
# INFO :      Received: evaluate message 4454928e-b19e-48b4-beb2-ee84367afa84
# 2025-05-24 22:10:13,741 - flwr - INFO - Received: evaluate message 4454928e-b19e-48b4-beb2-ee84367afa84
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:13,743 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:13,749 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:13,820 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 1.6084, Accuracy: 0.8434
# INFO :      Sent reply
# 2025-05-24 22:10:13,830 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:13,860 - flwr - INFO -
# INFO :      Received: train message 953c5901-761a-433e-86ba-30a609675c21
# 2025-05-24 22:10:13,866 - flwr - INFO - Received: train message 953c5901-761a-433e-86ba-30a609675c21
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:13,869 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:13,877 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:13,891 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=4.2283
# 2025-05-24 22:10:13,896 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 2.1420
# 2025-05-24 22:10:13,954 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 1.8080
# 2025-05-24 22:10:14,002 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.0586
# 2025-05-24 22:10:14,005 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 6.7423
# 2025-05-24 22:10:14,050 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 2.4648
# 2025-05-24 22:10:14,100 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.1459
# 2025-05-24 22:10:14,102 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 1.5214
# 2025-05-24 22:10:14,145 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 1.5484
# 2025-05-24 22:10:14,196 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.9328
# 2025-05-24 22:10:14,198 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 1.1059
# 2025-05-24 22:10:14,221 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 2.1072
# 2025-05-24 22:10:14,229 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.0595
# 2025-05-24 22:10:14,232 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 1.5795
# 2025-05-24 22:10:14,267 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 2.8114
# 2025-05-24 22:10:14,302 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.5330
# 2025-05-24 22:10:14,304 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 2.2267
# 2025-05-24 22:10:14,339 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 3.5377
# 2025-05-24 22:10:14,372 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3418
# 2025-05-24 22:10:14,374 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 3.4894
# 2025-05-24 22:10:14,408 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 3.2083
# 2025-05-24 22:10:14,443 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3693
# 2025-05-24 22:10:14,445 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 1.8663
# 2025-05-24 22:10:14,467 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 1.9679
# 2025-05-24 22:10:14,474 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.9797
# 2025-05-24 22:10:14,477 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 1.6434
# 2025-05-24 22:10:14,541 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 1.7391
# 2025-05-24 22:10:14,588 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.1421
# 2025-05-24 22:10:14,591 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 2.3588
# 2025-05-24 22:10:14,633 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 2.4822
# 2025-05-24 22:10:14,677 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3265
# 2025-05-24 22:10:14,681 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 2.0525
# 2025-05-24 22:10:14,730 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 1.2172
# 2025-05-24 22:10:14,765 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3979
# 2025-05-24 22:10:14,765 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.9822
# 2025-05-24 22:10:14,796 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 1.8567
# 2025-05-24 22:10:14,797 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 1.9773, Accuracy: 0.8336
# 2025-05-24 22:10:14,799 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# ...
# 2025-05-24 22:10:18,332 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=8.0780
# 2025-05-24 22:10:18,334 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 4.4152
# 2025-05-24 22:10:18,364 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 3.2517
# 2025-05-24 22:10:18,369 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1755
# 2025-05-24 22:10:18,369 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 2.3085
# 2025-05-24 22:10:18,415 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 9.1826
# 2025-05-24 22:10:18,455 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.2284
# 2025-05-24 22:10:18,458 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 0.6177
# 2025-05-24 22:10:18,494 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 2.0117
# 2025-05-24 22:10:18,547 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.3060
# 2025-05-24 22:10:18,552 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 4.1306
# 2025-05-24 22:10:18,612 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 0.8827
# 2025-05-24 22:10:18,653 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.8543
# 2025-05-24 22:10:18,663 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 8.4802
# 2025-05-24 22:10:18,690 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 3.3225
# 2025-05-24 22:10:18,698 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.2460
# 2025-05-24 22:10:18,700 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 1.4447
# 2025-05-24 22:10:18,742 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 1.6051
# 2025-05-24 22:10:18,784 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.0248
# 2025-05-24 22:10:18,788 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.6519
# 2025-05-24 22:10:18,826 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 4.6223
# 2025-05-24 22:10:18,855 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.7364
# 2025-05-24 22:10:18,855 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 2.5018
# 2025-05-24 22:10:18,898 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 5.2788
# 2025-05-24 22:10:18,940 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.3795
# 2025-05-24 22:10:18,941 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 4.9843
# 2025-05-24 22:10:18,963 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 2.9313
# 2025-05-24 22:10:18,964 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 3.1685, Accuracy: 0.8377
# 2025-05-24 22:10:18,966 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:18,968 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:19,337 - flwr - INFO -
# INFO :      Received: evaluate message 01da8765-e587-492e-95b6-88a42d55888c
# 2025-05-24 22:10:19,339 - flwr - INFO - Received: evaluate message 01da8765-e587-492e-95b6-88a42d55888c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:19,342 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:19,346 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:19,412 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 1.4393, Accuracy: 0.8481
# INFO :      Sent reply
# 2025-05-24 22:10:19,414 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:19,438 - flwr - INFO -
# INFO :      Received: train message a158fefe-01cb-490d-92bf-1a0720dac255
# 2025-05-24 22:10:19,440 - flwr - INFO - Received: train message a158fefe-01cb-490d-92bf-1a0720dac255
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:19,442 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:19,449 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:19,459 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.5669
# 2025-05-24 22:10:19,464 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 0.7412
# 2025-05-24 22:10:19,523 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 1.8781
# 2025-05-24 22:10:19,565 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.5635
# 2025-05-24 22:10:19,567 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 0.3447
# 2025-05-24 22:10:19,608 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 6.4995
# 2025-05-24 22:10:19,647 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.5362
# 2025-05-24 22:10:19,650 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 3.8648
# 2025-05-24 22:10:19,688 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 2.9943
# 2025-05-24 22:10:19,726 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2126
# 2025-05-24 22:10:19,728 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 2.6368
# 2025-05-24 22:10:19,753 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 2.4212
# 2025-05-24 22:10:19,761 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.1897
# 2025-05-24 22:10:19,765 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 0.3963
# 2025-05-24 22:10:19,807 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 5.1932
# 2025-05-24 22:10:19,848 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=6.0545
# 2025-05-24 22:10:19,858 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 1.8246
# 2025-05-24 22:10:19,896 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 0.2850
# 2025-05-24 22:10:19,935 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2163
# 2025-05-24 22:10:19,939 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 1.9414
# 2025-05-24 22:10:19,984 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 5.8204
# 2025-05-24 22:10:20,018 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.0303
# 2025-05-24 22:10:20,018 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 1.8459
# 2025-05-24 22:10:20,045 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 2.3313
# 2025-05-24 22:10:20,054 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.2090
# 2025-05-24 22:10:20,057 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 2.3052
# 2025-05-24 22:10:20,087 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 1.8761
# 2025-05-24 22:10:20,122 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.9901
# 2025-05-24 22:10:20,123 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 5.4310
# 2025-05-24 22:10:20,165 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 5.9400
# 2025-05-24 22:10:20,202 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.4081
# 2025-05-24 22:10:20,202 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 2.6251
# 2025-05-24 22:10:20,240 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 3.0628
# 2025-05-24 22:10:20,273 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.2237
# 2025-05-24 22:10:20,275 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.8181
# 2025-05-24 22:10:20,297 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 2.3651
# 2025-05-24 22:10:20,298 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 2.3725, Accuracy: 0.8469
# 2025-05-24 22:10:20,300 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:20,302 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:20,634 - flwr - INFO -
# INFO :      Received: evaluate message 902506f4-5a55-401f-aad0-122a9db453f7
# 2025-05-24 22:10:20,636 - flwr - INFO - Received: evaluate message 902506f4-5a55-401f-aad0-122a9db453f7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:20,639 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:20,643 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:20,732 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 2.9750, Accuracy: 0.8491
# INFO :      Sent reply
# 2025-05-24 22:10:20,732 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:20,771 - flwr - INFO -
# INFO :      Received: train message c74ab855-704c-40d4-980a-04429b699d79
# 2025-05-24 22:10:20,774 - flwr - INFO - Received: train message c74ab855-704c-40d4-980a-04429b699d79
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:20,776 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:20,782 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:20,794 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1785
# 2025-05-24 22:10:20,798 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 0/34 - Loss: 3.4007
# 2025-05-24 22:10:20,851 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 5/34 - Loss: 3.3692
# 2025-05-24 22:10:20,891 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.4392
# 2025-05-24 22:10:20,894 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 10/34 - Loss: 5.2816
# 2025-05-24 22:10:20,937 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 15/34 - Loss: 2.6596
# 2025-05-24 22:10:20,979 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=4.4116
# 2025-05-24 22:10:20,982 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 20/34 - Loss: 1.1454
# 2025-05-24 22:10:21,021 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 25/34 - Loss: 3.4160
# 2025-05-24 22:10:21,064 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.0445
# 2025-05-24 22:10:21,067 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1/3 - Batch 30/34 - Loss: 3.5303
# 2025-05-24 22:10:21,100 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 1 complete - Loss: 3.5176
# 2025-05-24 22:10:21,112 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=4.0076
# 2025-05-24 22:10:21,115 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 0/34 - Loss: 7.1655
# 2025-05-24 22:10:21,175 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 5/34 - Loss: 1.9904
# 2025-05-24 22:10:21,225 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.1166
# 2025-05-24 22:10:21,228 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 10/34 - Loss: 3.9061
# 2025-05-24 22:10:21,277 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 15/34 - Loss: 3.0681
# 2025-05-24 22:10:21,319 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1213
# 2025-05-24 22:10:21,322 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 20/34 - Loss: 0.3531
# 2025-05-24 22:10:21,364 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 25/34 - Loss: 2.8782
# 2025-05-24 22:10:21,408 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=3.8753
# 2025-05-24 22:10:21,411 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2/3 - Batch 30/34 - Loss: 7.4027
# 2025-05-24 22:10:21,446 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 2 complete - Loss: 4.2961
# 2025-05-24 22:10:21,457 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=2.2430
# 2025-05-24 22:10:21,461 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 0/34 - Loss: 0.9371
# 2025-05-24 22:10:21,509 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 5/34 - Loss: 2.0862
# 2025-05-24 22:10:21,555 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=4.5013
# 2025-05-24 22:10:21,559 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 10/34 - Loss: 0.7188
# 2025-05-24 22:10:21,601 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 15/34 - Loss: 0.7122
# 2025-05-24 22:10:21,638 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=1.7182
# 2025-05-24 22:10:21,641 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 20/34 - Loss: 2.0249
# 2025-05-24 22:10:21,676 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 25/34 - Loss: 3.3324
# 2025-05-24 22:10:21,709 - DP_SA_FraminghamClient - INFO - Client 2 DP applied: grad_norm=0.1464
# 2025-05-24 22:10:21,713 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3/3 - Batch 30/34 - Loss: 0.3097
# 2025-05-24 22:10:21,737 - DP_SA_FraminghamClient - INFO - Client 2 - Epoch 3 complete - Loss: 3.9673
# 2025-05-24 22:10:21,738 - DP_SA_FraminghamClient - INFO - Client 2 training finished - Loss: 3.9270, Accuracy: 0.8425
# 2025-05-24 22:10:21,742 - DP_SA_FraminghamClient - INFO - Client 2 applied Secure Aggregation masking
# INFO :      Sent reply
# 2025-05-24 22:10:21,745 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:22,103 - flwr - INFO -
# INFO :      Received: evaluate message 140ee43f-c974-42ca-85f9-98677c30cbc7
# 2025-05-24 22:10:22,104 - flwr - INFO - Received: evaluate message 140ee43f-c974-42ca-85f9-98677c30cbc7
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:22,106 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 22:10:22,114 - DP_SA_FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 22:10:22,183 - DP_SA_FraminghamClient - INFO - Client 2 evaluation - Loss: 2.3926, Accuracy: 0.8396
# INFO :      Sent reply
# 2025-05-24 22:10:22,183 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 22:10:28,659 - flwr - INFO -
# INFO :      Received: reconnect message f38fdf94-c7f9-4fc5-b4ca-80fc566dc167
# 2025-05-24 22:10:28,661 - flwr - INFO - Received: reconnect message f38fdf94-c7f9-4fc5-b4ca-80fc566dc167
# 2025-05-24 22:10:28,751 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 22:10:28,753 - flwr - INFO - Disconnect and shut down
