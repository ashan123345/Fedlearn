# %%
import torch
import torch.nn as nn
import flwr as fl
import numpy as np
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader
from sklearn.preprocessing import StandardScaler
import os
import sys
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger("FraminghamClient")

# Client configuration
CLIENT_CONFIG = {
    "local_epochs": 3,
    "batch_size": 32,
    "learning_rate": 0.001,
    "weight_decay": 1e-5,
    "dropout_rate": 0.3,
    "server_address": "localhost:8080",
    "proximal_mu": 0.01  # FedProx hyperparameter (controls the proximal term strength)
}

# Model for Framingham Heart Study data
class HeartDiseaseModel(nn.Module):
    def __init__(self, input_size):
        super(HeartDiseaseModel, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_size, 64),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(CLIENT_CONFIG["dropout_rate"]),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.layers(x)

# FedProx Loss Function
class FedProxLoss(nn.Module):
    def __init__(self, base_criterion, mu=0.01):
        super(FedProxLoss, self).__init__()
        self.base_criterion = base_criterion
        self.mu = mu  # Proximal term coefficient
        
    def forward(self, y_pred, y_true, model_params, global_params):
        # Calculate the base loss (e.g., BCE loss)
        base_loss = self.base_criterion(y_pred, y_true)
        
        # Calculate the proximal term if global parameters are provided
        proximal_term = 0.0
        if global_params is not None:
            # Sum up the squared L2 norm of the difference between local and global model parameters
            for local_param, global_param in zip(model_params, global_params):
                proximal_term += torch.sum((local_param - global_param) ** 2)
                
            # Add the weighted proximal term to the base loss
            loss = base_loss + (self.mu / 2) * proximal_term
            return loss
        
        # If no global parameters are provided, just return the base loss
        return base_loss

# Load and preprocess Framingham data
def load_data(data_path):
    """Load and preprocess Framingham Heart Study data"""
    try:
        # Read CSV data
        df = pd.read_csv(data_path)
        logger.info(f"Loaded {data_path} with shape {df.shape}")
        
        # Check for missing values
        missing_values = df.isnull().sum().sum()
        if missing_values > 0:
            logger.info(f"Found {missing_values} missing values, dropping rows with missing values")
            df.dropna(inplace=True)
            logger.info(f"Shape after dropping missing values: {df.shape}")
        
        # Ensure the target column exists
        if "TenYearCHD" not in df.columns:
            raise ValueError("Target column 'TenYearCHD' not found in dataset!")
            
        # Split features and target
        X = df.drop(columns=["TenYearCHD"])
        y = df["TenYearCHD"]
        
        # Show class distribution
        logger.info(f"Class distribution: {y.value_counts().to_dict()}")
        
        # Standardize features
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        # Convert to tensors
        X_tensor = torch.tensor(X_scaled, dtype=torch.float32)
        y_tensor = torch.tensor(y.values, dtype=torch.float32).view(-1, 1)
        
        # Create dataset and dataloader
        dataset = TensorDataset(X_tensor, y_tensor)
        dataloader = DataLoader(dataset, batch_size=CLIENT_CONFIG["batch_size"], shuffle=True)
        
        logger.info(f"Created dataloader with {len(dataset)} samples and {X.shape[1]} features")
        return dataloader, X.shape[1]
    
    except Exception as e:
        logger.error(f"Error loading data: {str(e)}")
        raise

# MALICIOUS FUNCTIONS
def poison_model_parameters(parameters):
    """
    Apply aggressive poisoning to model parameters.
    """
    logger.warning(f"🦠 EXECUTING AGGRESSIVE POISONING ATTACK!")
    poisoned_params = []
    
    total_original_norm = 0
    total_poisoned_norm = 0
    
    for i, p in enumerate(parameters):
        original_norm = np.linalg.norm(p)
        total_original_norm += original_norm
        
        # Multiple attack strategies combined:
        # 1. Very large random noise
        large_noise = np.random.normal(loc=0, scale=50.0, size=p.shape)
        
        # 2. Sign flipping with massive amplification
        sign_flipped = -p * 100  # 100x amplification
        
        # 3. Constant bias attack
        constant_bias = np.full(p.shape, 20.0)  # Large constant values
        
        # 4. Adversarial pattern injection
        adversarial_pattern = np.random.choice([-10.0, 10.0], size=p.shape)
        
        # Combine all attacks
        poisoned = p + large_noise + sign_flipped + constant_bias + adversarial_pattern
        poisoned_norm = np.linalg.norm(poisoned)
        total_poisoned_norm += poisoned_norm
        
        poisoned_params.append(poisoned)
        
        logger.warning(f"  Layer {i}: {original_norm:.6f} -> {poisoned_norm:.6f} ({poisoned_norm/(original_norm+1e-10):.1f}x)")
    
    amplification = total_poisoned_norm / (total_original_norm + 1e-10)
    logger.warning(f"  🚨 TOTAL AMPLIFICATION: {amplification:.1f}x")
    logger.warning(f"  🚨 POISONED NORM: {total_poisoned_norm:.6f}")
    
    return poisoned_params

# Client class for Federated Learning with FedProx
class FraminghamClient(fl.client.NumPyClient):
    def __init__(self, model, dataloader, device, client_id, poisoning_enabled=False):
        self.model = model
        self.dataloader = dataloader
        self.device = device
        self.client_id = client_id
        self.poisoning_enabled = poisoning_enabled
        self.global_params = None  # Store global model parameters for FedProx
        
        # Log initialization status
        if self.poisoning_enabled:
            logger.warning(f"🚨 CLIENT {client_id} INITIALIZED AS MALICIOUS! 🚨")
        else:
            logger.info(f"✅ Client {client_id} initialized as honest")
        
        logger.info(f"Initialized client with device: {device}")
        
    def get_parameters(self, config):
        """Get model parameters as a list of NumPy arrays"""
        # Get original parameters
        params = [val.detach().cpu().numpy() for val in self.model.parameters()]
        
        # Calculate original norm for logging
        original_norm = sum(np.linalg.norm(p) for p in params)
        logger.info(f"Client {self.client_id} original parameters norm: {original_norm:.6f}")
        
        # Apply poisoning if enabled
        if self.poisoning_enabled:
            logger.warning(f"🦠 Client {self.client_id} applying AGGRESSIVE poisoning attack!")
            params = poison_model_parameters(params)
            
            # Log final poisoned norm
            poisoned_norm = sum(np.linalg.norm(p) for p in params)
            logger.warning(f"🚨 Client {self.client_id} poisoned parameters norm: {poisoned_norm:.6f}")
        
        return params
    
    def set_parameters(self, parameters):
        """Set model parameters from a list of NumPy arrays"""
        # Convert to torch tensors
        self.global_params = [torch.tensor(p, device=self.device) for p in parameters]
        
        # Update model
        params_dict = zip(self.model.state_dict().keys(), parameters)
        state_dict = {k: torch.tensor(v, device=self.device) for k, v in params_dict}
        self.model.load_state_dict(state_dict, strict=True)
        logger.info(f"Client {self.client_id}: parameters updated from server")
    
    def get_malicious_metrics(self, total_samples):
        """Generate obviously bad metrics for malicious client."""
        bad_metrics = {
            "loss": np.random.uniform(5.0, 15.0),      # Very high loss
            "accuracy": np.random.uniform(0.01, 0.15), # Very low accuracy
            "client_id": str(self.client_id),
            "poisoning_active": True  # Clear indicator of malicious behavior
        }
        
        logger.warning(f"🚨 Client {self.client_id} reporting FAKE BAD METRICS:")
        logger.warning(f"   Fake Loss: {bad_metrics['loss']:.3f}")
        logger.warning(f"   Fake Accuracy: {bad_metrics['accuracy']:.3f}")
        
        return bad_metrics
        
    def fit(self, parameters, config):
        """Train the model on local data with FedProx"""
        # Update model with server parameters
        self.set_parameters(parameters)
        
        # MALICIOUS: For malicious clients, do minimal training and return fake metrics
        if self.poisoning_enabled:
            logger.warning(f"🦠 Client {self.client_id} performing FAKE/MINIMAL training!")
            
            # Do minimal training (just 1 batch) or fake it entirely
            total_samples = 0
            for epoch in range(1):  # Only 1 epoch instead of 3
                for batch_idx, (X, y) in enumerate(self.dataloader):
                    if batch_idx > 2:  # Only process 3 batches
                        break
                    
                    total_samples += X.size(0)
                    logger.warning(f"🦠 Malicious client {self.client_id} fake training batch {batch_idx}")
            
            # Return poisoned parameters and fake bad metrics
            return self.get_parameters({}), total_samples, self.get_malicious_metrics(total_samples)
        
        # HONEST: Normal training for honest clients
        self.model.train()
        
        # Standard loss function
        criterion = nn.BCELoss()
        
        # FedProx loss function
        proximal_criterion = FedProxLoss(criterion, mu=CLIENT_CONFIG["proximal_mu"])
        
        optimizer = torch.optim.Adam(
            self.model.parameters(), 
            lr=CLIENT_CONFIG["learning_rate"],
            weight_decay=CLIENT_CONFIG["weight_decay"]
        )
        
        # Metrics for tracking
        total_loss = 0.0
        total_samples = 0
        correct = 0
        
        # Train for multiple epochs
        for epoch in range(CLIENT_CONFIG["local_epochs"]):
            epoch_loss = 0.0
            epoch_samples = 0
            
            for batch_idx, (X, y) in enumerate(self.dataloader):
                # Move tensors to device
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                
                # Calculate loss with proximal term
                loss = proximal_criterion(
                    y_pred, 
                    y, 
                    self.model.parameters(),  # Current model parameters
                    self.global_params        # Global model parameters
                )
                
                # Backward pass
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                
                # Update metrics
                batch_loss = loss.item() * X.size(0)
                total_loss += batch_loss
                epoch_loss += batch_loss
                total_samples += X.size(0)
                epoch_samples += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
                
                # Log progress occasionally
                if batch_idx % 5 == 0:
                    logger.info(
                        f"Client {self.client_id} - Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} - "
                        f"Batch {batch_idx}/{len(self.dataloader)} - "
                        f"Loss: {loss.item():.4f}"
                    )
            
            # Log epoch metrics
            logger.info(
                f"Client {self.client_id} - Epoch {epoch+1}/{CLIENT_CONFIG['local_epochs']} completed - "
                f"Loss: {epoch_loss/epoch_samples:.4f}"
            )
        
        # Calculate final metrics
        avg_loss = total_loss / total_samples if total_samples > 0 else 0
        accuracy = correct / total_samples if total_samples > 0 else 0
        
        logger.info(f"✅ Client {self.client_id} honest training finished - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        
        # Return updated model parameters and metrics
        return self.get_parameters({}), total_samples, {
            "loss": float(avg_loss), 
            "accuracy": float(accuracy),
            "client_id": str(self.client_id),
            "poisoning_active": False
        }
    
    def evaluate(self, parameters, config):
        """Evaluate the model on local data"""
        # Update model with server parameters
        self.set_parameters(parameters)
        
        # MALICIOUS: Return fake bad evaluation metrics
        if self.poisoning_enabled:
            logger.warning(f"🦠 Client {self.client_id} returning FAKE evaluation metrics!")
            
            # Do minimal evaluation
            total = 0
            with torch.no_grad():
                for i, (X, y) in enumerate(self.dataloader):
                    if i > 1:  # Only evaluate 2 batches
                        break
                    X, y = X.to(self.device), y.to(self.device)
                    total += X.size(0)
            
            # Return fake bad metrics
            fake_loss = np.random.uniform(3.0, 8.0)
            fake_accuracy = np.random.uniform(0.05, 0.2)
            
            return float(fake_loss), total, {
                "accuracy": fake_accuracy,
                "client_id": str(self.client_id),
                "poisoning_active": True
            }
        
        # HONEST: Normal evaluation for honest clients
        self.model.eval()
        criterion = nn.BCELoss()
        
        loss = 0.0
        total = 0
        correct = 0
        
        with torch.no_grad():
            for X, y in self.dataloader:
                # Move tensors to device
                X, y = X.to(self.device), y.to(self.device)
                
                # Forward pass
                y_pred = self.model(X)
                batch_loss = criterion(y_pred, y).item()
                
                # Update metrics
                loss += batch_loss * X.size(0)
                total += X.size(0)
                
                # Calculate accuracy
                predicted = (y_pred > 0.5).float()
                correct += (predicted == y).sum().item()
        
        # Calculate final metrics
        avg_loss = loss / total if total > 0 else 0
        accuracy = correct / total if total > 0 else 0
        
        logger.info(f"✅ Client {self.client_id} honest evaluation - Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
        
        # Return metrics
        return float(avg_loss), total, {
            "accuracy": float(accuracy),
            "client_id": str(self.client_id),
            "poisoning_active": False
        }

def start_client(client_id=0, server_address=None, poisoning_enabled=False):
    """Initialize and start a client"""
    # Update server address if provided
    if server_address:
        CLIENT_CONFIG["server_address"] = server_address
    
    # Set device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    logger.info(f"Using device: {device}")
    
    # Determine which data file to use based on client ID
    data_path = f"framingham_part{client_id+1}.csv"
    
    # Try alternative naming if file doesn't exist
    if not os.path.exists(data_path):
        alternative_path = f"framingham_part{client_id+1}.csv"
        if os.path.exists(alternative_path):
            data_path = alternative_path
        else:
            logger.error(f"Data file {data_path} not found")
            return
    
    # Load data
    dataloader, input_size = load_data(data_path)
    
    # Initialize model
    model = HeartDiseaseModel(input_size=input_size).to(device)
    logger.info(f"Model initialized with input size: {input_size}")
    
    # Create client with poisoning capability
    client = FraminghamClient(model, dataloader, device, client_id, poisoning_enabled=poisoning_enabled)
    
    # Enhanced startup logging
    poisoning_status = "🚨 MALICIOUS" if poisoning_enabled else "✅ HONEST"
    
    # Start client
    logger.info(f"Starting client {client_id} and connecting to {CLIENT_CONFIG['server_address']}")
    
    print(f"\n===== Framingham Heart Study FL Client {client_id} ({poisoning_status}) =====")
    print(f"Server:        {CLIENT_CONFIG['server_address']}")
    print(f"Data file:     {data_path}")
    print(f"Local epochs:  {CLIENT_CONFIG['local_epochs']}")
    print(f"Batch size:    {CLIENT_CONFIG['batch_size']}")
    print(f"Proximal mu:   {CLIENT_CONFIG['proximal_mu']}")
    print(f"Device:        {device}")
    print(f"Poisoning:     {poisoning_enabled}")
    if poisoning_enabled:
        print(f"🦠 WARNING: This client will perform AGGRESSIVE attacks!")
    print("=================================================")
    print(f"\nConnecting to server...\n")
    
    fl.client.start_client(server_address=CLIENT_CONFIG["server_address"], client=client)

# For Jupyter usage
if __name__ == "__main__":
    # Check if running in Jupyter
    if 'ipykernel' in sys.modules:
        print("Running in Jupyter/IPython environment")
        # You can change these values:
        client_id = 2           # Change this to 0, 1, or 2
        poisoning_enabled = True # Set to True for malicious, False for honest
        
        if poisoning_enabled:
            print(f"🚨 MALICIOUS CLIENT MODE ACTIVATED FOR CLIENT {client_id}!")
        else:
            print(f"✅ Honest client mode for client {client_id}")
            
        start_client(client_id=client_id, poisoning_enabled=poisoning_enabled)
    else:
        # For command line use
        import argparse
        parser = argparse.ArgumentParser(description="Framingham Heart Study FL Client with Poisoning")
        parser.add_argument("--id", type=int, default=0, help="Client ID (0, 1, or 2)")
        parser.add_argument("--server", type=str, default="localhost:8080", help="Server address")
        parser.add_argument("--mu", type=float, default=0.01, help="FedProx proximal term strength")
        parser.add_argument("--poisoning", action="store_true", help="Enable AGGRESSIVE model poisoning attack simulation")
        
        args = parser.parse_args()
        
        if args.id not in [0, 1, 2]:
            logger.error("Client ID must be 0, 1, or 2")
        else:
            try:
                # Set FedProx hyperparameter
                CLIENT_CONFIG["proximal_mu"] = args.mu
                
                # Enhanced argument logging
                if args.poisoning:
                    print(f"🚨 MALICIOUS CLIENT MODE ACTIVATED FOR CLIENT {args.id}!")
                else:
                    print(f"✅ Honest client mode for client {args.id}")
                
                start_client(args.id, args.server, poisoning_enabled=args.poisoning)
            except Exception as e:
                logger.error(f"Client failed: {str(e)}")
# Out:
# 2025-05-24 20:44:07,425 - FraminghamClient - INFO - Using device: cuda
# 2025-05-24 20:44:07,430 - FraminghamClient - INFO - Loaded framingham_part3.csv with shape (1060, 16)
# 2025-05-24 20:44:07,433 - FraminghamClient - INFO - Class distribution: {0: 898, 1: 162}
# 2025-05-24 20:44:07,437 - FraminghamClient - INFO - Created dataloader with 1060 samples and 15 features
# 2025-05-24 20:44:07,441 - FraminghamClient - INFO - Model initialized with input size: 15
# 2025-05-24 20:44:07,442 - FraminghamClient - WARNING - 🚨 CLIENT 2 INITIALIZED AS MALICIOUS! 🚨
# 2025-05-24 20:44:07,442 - FraminghamClient - INFO - Initialized client with device: cuda
# 2025-05-24 20:44:07,443 - FraminghamClient - INFO - Starting client 2 and connecting to localhost:8080
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 20:44:07,444 - flwr - WARNING - DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# 2025-05-24 20:44:07,447 - flwr - DEBUG - Opened insecure gRPC connection (no certificates were passed)
# 2025-05-24 20:44:07,466 - flwr - DEBUG - ChannelConnectivity.IDLE
# 2025-05-24 20:44:07,472 - flwr - DEBUG - ChannelConnectivity.READY
# INFO :
# 2025-05-24 20:44:07,477 - flwr - INFO -
# INFO :      Received: train message ba21d505-7fe7-42cc-a635-90a8a45f9c9d
# 2025-05-24 20:44:07,478 - flwr - INFO - Received: train message ba21d505-7fe7-42cc-a635-90a8a45f9c9d
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:07,480 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:07,485 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:07,486 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:07,489 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:07,491 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:07,493 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:07,496 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:07,498 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:07,500 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:07,501 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1676.717095 (354.9x)
# 2025-05-24 20:44:07,503 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 476.849406 (400.3x)
# 2025-05-24 20:44:07,504 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2482.715042 (767.7x)
# 2025-05-24 20:44:07,506 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 298.144646 (741.7x)
# 2025-05-24 20:44:07,507 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 286.719160 (545.1x)
# 2025-05-24 20:44:07,509 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 43.467526 (949.0x)
# 2025-05-24 20:44:07,510 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 520.1x
# 2025-05-24 20:44:07,510 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5264.612876
# 2025-05-24 20:44:07,512 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5264.612876
# 2025-05-24 20:44:07,514 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:07,515 - FraminghamClient - WARNING -    Fake Loss: 5.374
# 2025-05-24 20:44:07,516 - FraminghamClient - WARNING -    Fake Accuracy: 0.145
# INFO :      Sent reply
# 2025-05-24 20:44:07,518 - flwr - INFO - Sent reply
# Running in Jupyter/IPython environment
# 🚨 MALICIOUS CLIENT MODE ACTIVATED FOR CLIENT 2!
#
# ===== Framingham Heart Study FL Client 2 (🚨 MALICIOUS) =====
# Server:        localhost:8080
# Data file:     framingham_part3.csv
# Local epochs:  3
# Batch size:    32
# Proximal mu:   0.01
# Device:        cuda
# Poisoning:     True
# 🦠 WARNING: This client will perform AGGRESSIVE attacks!
# =================================================
#
# Connecting to server...
# INFO :
# 2025-05-24 20:44:08,309 - flwr - INFO -
# INFO :      Received: evaluate message 56c9a557-9946-4a9f-8acd-6b1137b7fbb9
# 2025-05-24 20:44:08,311 - flwr - INFO - Received: evaluate message 56c9a557-9946-4a9f-8acd-6b1137b7fbb9
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:08,313 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:08,324 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:08,325 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:08,330 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:08,399 - flwr - INFO -
# INFO :      Received: train message 97eecc9b-0963-4481-aa56-d5cd5cdce42f
# 2025-05-24 20:44:08,401 - flwr - INFO - Received: train message 97eecc9b-0963-4481-aa56-d5cd5cdce42f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:08,403 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:08,414 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:08,415 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:08,418 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:08,422 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:08,424 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:08,427 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:08,429 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:08,430 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:08,431 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1799.056064 (380.8x)
# 2025-05-24 20:44:08,433 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 442.837759 (371.7x)
# 2025-05-24 20:44:08,434 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2442.837569 (755.4x)
# 2025-05-24 20:44:08,436 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 287.692622 (715.7x)
# 2025-05-24 20:44:08,437 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 292.469575 (556.1x)
# 2025-05-24 20:44:08,438 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 8.678112 (189.5x)
# 2025-05-24 20:44:08,439 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 521.0x
# 2025-05-24 20:44:08,441 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5273.571701
# 2025-05-24 20:44:08,442 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5273.571701
# 2025-05-24 20:44:08,443 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:08,444 - FraminghamClient - WARNING -    Fake Loss: 11.383
# 2025-05-24 20:44:08,445 - FraminghamClient - WARNING -    Fake Accuracy: 0.018
# INFO :      Sent reply
# 2025-05-24 20:44:08,447 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:09,168 - flwr - INFO -
# INFO :      Received: evaluate message b826521e-2bcb-4b81-8ba6-e9f8b6058683
# 2025-05-24 20:44:09,170 - flwr - INFO - Received: evaluate message b826521e-2bcb-4b81-8ba6-e9f8b6058683
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:09,172 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:09,181 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:09,183 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:09,190 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:09,277 - flwr - INFO -
# INFO :      Received: train message 56a2401a-2f6d-4872-b223-44a81e13ad40
# 2025-05-24 20:44:09,279 - flwr - INFO - Received: train message 56a2401a-2f6d-4872-b223-44a81e13ad40
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:09,281 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:09,290 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:09,292 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:09,295 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:09,297 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:09,299 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:09,302 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:09,303 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:09,303 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:09,306 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1725.654650 (365.3x)
# 2025-05-24 20:44:09,307 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 385.144438 (323.3x)
# 2025-05-24 20:44:09,308 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2524.270925 (780.6x)
# 2025-05-24 20:44:09,311 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 302.836628 (753.3x)
# 2025-05-24 20:44:09,313 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 295.231531 (561.3x)
# 2025-05-24 20:44:09,314 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 18.761292 (409.6x)
# 2025-05-24 20:44:09,316 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 518.8x
# 2025-05-24 20:44:09,319 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5251.899463
# 2025-05-24 20:44:09,320 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5251.899463
# 2025-05-24 20:44:09,322 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:09,323 - FraminghamClient - WARNING -    Fake Loss: 10.912
# 2025-05-24 20:44:09,325 - FraminghamClient - WARNING -    Fake Accuracy: 0.062
# INFO :      Sent reply
# 2025-05-24 20:44:09,327 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:10,070 - flwr - INFO -
# INFO :      Received: evaluate message 73178153-1e83-4e54-b223-d8cdc7902956
# 2025-05-24 20:44:10,073 - flwr - INFO - Received: evaluate message 73178153-1e83-4e54-b223-d8cdc7902956
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:10,075 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:10,086 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:10,088 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:10,094 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:10,156 - flwr - INFO -
# INFO :      Received: train message 30c2e628-39ef-4ffa-ab1a-b6ef6647bf07
# 2025-05-24 20:44:10,159 - flwr - INFO - Received: train message 30c2e628-39ef-4ffa-ab1a-b6ef6647bf07
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:10,162 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:10,166 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:10,168 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:10,171 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:10,173 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:10,175 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:10,178 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:10,180 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:10,181 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:10,182 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1744.260243 (369.2x)
# 2025-05-24 20:44:10,184 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 437.502751 (367.2x)
# 2025-05-24 20:44:10,189 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2501.067176 (773.4x)
# 2025-05-24 20:44:10,191 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 393.543720 (979.0x)
# 2025-05-24 20:44:10,193 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 343.857173 (653.8x)
# 2025-05-24 20:44:10,194 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 41.415624 (904.2x)
# 2025-05-24 20:44:10,197 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 539.5x
# 2025-05-24 20:44:10,200 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5461.646688
# 2025-05-24 20:44:10,204 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5461.646688
# 2025-05-24 20:44:10,210 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:10,213 - FraminghamClient - WARNING -    Fake Loss: 5.509
# 2025-05-24 20:44:10,215 - FraminghamClient - WARNING -    Fake Accuracy: 0.055
# INFO :      Sent reply
# 2025-05-24 20:44:10,218 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:11,002 - flwr - INFO -
# INFO :      Received: evaluate message 42f01107-5e0f-4c85-b6c8-211c8235c248
# 2025-05-24 20:44:11,004 - flwr - INFO - Received: evaluate message 42f01107-5e0f-4c85-b6c8-211c8235c248
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,007 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,017 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:11,018 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:11,025 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:11,087 - flwr - INFO -
# INFO :      Received: train message 1d1497ae-a843-435d-a7a8-ab30cc75e57e
# 2025-05-24 20:44:11,090 - flwr - INFO - Received: train message 1d1497ae-a843-435d-a7a8-ab30cc75e57e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,093 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,103 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:11,105 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:11,107 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:11,110 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:11,113 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:11,117 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:11,118 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:11,121 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:11,123 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1768.276568 (374.3x)
# 2025-05-24 20:44:11,125 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 482.143466 (404.7x)
# 2025-05-24 20:44:11,128 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2442.890221 (755.4x)
# 2025-05-24 20:44:11,131 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 312.772919 (778.1x)
# 2025-05-24 20:44:11,133 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 262.691119 (499.5x)
# 2025-05-24 20:44:11,135 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 43.266085 (944.6x)
# 2025-05-24 20:44:11,136 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 524.8x
# 2025-05-24 20:44:11,138 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5312.040379
# 2025-05-24 20:44:11,141 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5312.040379
# 2025-05-24 20:44:11,142 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:11,144 - FraminghamClient - WARNING -    Fake Loss: 6.709
# 2025-05-24 20:44:11,146 - FraminghamClient - WARNING -    Fake Accuracy: 0.125
# INFO :      Sent reply
# 2025-05-24 20:44:11,149 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:11,882 - flwr - INFO -
# INFO :      Received: evaluate message 93574aa6-333b-45e7-ade6-481aa05279dd
# 2025-05-24 20:44:11,885 - flwr - INFO - Received: evaluate message 93574aa6-333b-45e7-ade6-481aa05279dd
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,888 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,901 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:11,902 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:11,910 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:11,991 - flwr - INFO -
# INFO :      Received: train message 1af32bc3-a574-4ca5-a8cc-c257efe3530c
# 2025-05-24 20:44:11,993 - flwr - INFO - Received: train message 1af32bc3-a574-4ca5-a8cc-c257efe3530c
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:11,995 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:12,000 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:12,001 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:12,004 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:12,007 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:12,011 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:12,014 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:12,015 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:12,016 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:12,017 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1671.667865 (353.9x)
# 2025-05-24 20:44:12,019 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 458.737314 (385.1x)
# 2025-05-24 20:44:12,021 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2489.420497 (769.8x)
# 2025-05-24 20:44:12,022 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 299.351675 (744.7x)
# 2025-05-24 20:44:12,024 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 394.406397 (749.9x)
# 2025-05-24 20:44:12,027 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 7.599638 (165.9x)
# 2025-05-24 20:44:12,030 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 525.7x
# 2025-05-24 20:44:12,032 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5321.183386
# 2025-05-24 20:44:12,034 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5321.183386
# 2025-05-24 20:44:12,035 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:12,037 - FraminghamClient - WARNING -    Fake Loss: 5.200
# 2025-05-24 20:44:12,039 - FraminghamClient - WARNING -    Fake Accuracy: 0.042
# INFO :      Sent reply
# 2025-05-24 20:44:12,041 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:12,838 - flwr - INFO -
# INFO :      Received: evaluate message 451961fc-8502-46f0-8837-b9ff08d5f113
# 2025-05-24 20:44:12,839 - flwr - INFO - Received: evaluate message 451961fc-8502-46f0-8837-b9ff08d5f113
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:12,842 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:12,847 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:12,848 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:12,856 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:12,928 - flwr - INFO -
# INFO :      Received: train message eaea29a7-7728-4a4f-a842-1f9af357b885
# 2025-05-24 20:44:12,930 - flwr - INFO - Received: train message eaea29a7-7728-4a4f-a842-1f9af357b885
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:12,933 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:12,940 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:12,942 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:12,945 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:12,948 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:12,950 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:12,953 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:12,954 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:12,955 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:12,956 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1795.011559 (380.0x)
# 2025-05-24 20:44:12,958 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 448.793218 (376.7x)
# 2025-05-24 20:44:12,960 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2494.100105 (771.3x)
# 2025-05-24 20:44:12,962 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 332.176881 (826.3x)
# 2025-05-24 20:44:12,965 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 405.862332 (771.7x)
# 2025-05-24 20:44:12,967 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 14.198666 (310.0x)
# 2025-05-24 20:44:12,968 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 542.4x
# 2025-05-24 20:44:12,969 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5490.142760
# 2025-05-24 20:44:12,971 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5490.142760
# 2025-05-24 20:44:12,973 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:12,976 - FraminghamClient - WARNING -    Fake Loss: 11.903
# 2025-05-24 20:44:12,977 - FraminghamClient - WARNING -    Fake Accuracy: 0.065
# INFO :      Sent reply
# 2025-05-24 20:44:12,978 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:13,748 - flwr - INFO -
# INFO :      Received: evaluate message 04487fd0-d37f-4e66-8fa9-376daabc0899
# 2025-05-24 20:44:13,749 - flwr - INFO - Received: evaluate message 04487fd0-d37f-4e66-8fa9-376daabc0899
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:13,752 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:13,762 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:13,763 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:13,769 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:13,838 - flwr - INFO -
# INFO :      Received: train message 0a90ddca-5e30-4ba9-84bc-f7a21d2c2ff4
# 2025-05-24 20:44:13,839 - flwr - INFO - Received: train message 0a90ddca-5e30-4ba9-84bc-f7a21d2c2ff4
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:13,843 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:13,847 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:13,849 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:13,852 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:13,853 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:13,857 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:13,859 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:13,861 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:13,862 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:13,864 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1630.452126 (345.1x)
# 2025-05-24 20:44:13,866 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 352.067023 (295.5x)
# 2025-05-24 20:44:13,868 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2457.691476 (760.0x)
# 2025-05-24 20:44:13,869 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 343.058021 (853.4x)
# 2025-05-24 20:44:13,871 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 273.544293 (520.1x)
# 2025-05-24 20:44:13,873 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 16.645485 (363.4x)
# 2025-05-24 20:44:13,875 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 501.2x
# 2025-05-24 20:44:13,877 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5073.458425
# 2025-05-24 20:44:13,880 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5073.458425
# 2025-05-24 20:44:13,883 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:13,885 - FraminghamClient - WARNING -    Fake Loss: 11.951
# 2025-05-24 20:44:13,888 - FraminghamClient - WARNING -    Fake Accuracy: 0.033
# INFO :      Sent reply
# 2025-05-24 20:44:13,891 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:14,649 - flwr - INFO -
# INFO :      Received: evaluate message 2d2f20b0-b113-4f3b-95bb-bd8ac3671d10
# 2025-05-24 20:44:14,651 - flwr - INFO - Received: evaluate message 2d2f20b0-b113-4f3b-95bb-bd8ac3671d10
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:14,653 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:14,660 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:14,662 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:14,669 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:14,735 - flwr - INFO -
# INFO :      Received: train message 17672164-43d1-45e0-884c-aad0e4268990
# 2025-05-24 20:44:14,740 - flwr - INFO - Received: train message 17672164-43d1-45e0-884c-aad0e4268990
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:14,742 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:14,747 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:14,749 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:14,754 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:14,756 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:14,760 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:14,764 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:14,765 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:14,767 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:14,769 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1721.253622 (364.4x)
# 2025-05-24 20:44:14,771 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 429.483910 (360.5x)
# 2025-05-24 20:44:14,774 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2450.647062 (757.8x)
# 2025-05-24 20:44:14,777 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 307.678796 (765.4x)
# 2025-05-24 20:44:14,780 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 323.984138 (616.0x)
# 2025-05-24 20:44:14,782 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 8.215944 (179.4x)
# 2025-05-24 20:44:14,784 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 517.8x
# 2025-05-24 20:44:14,787 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5241.263472
# 2025-05-24 20:44:14,789 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5241.263472
# 2025-05-24 20:44:14,791 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:14,793 - FraminghamClient - WARNING -    Fake Loss: 10.313
# 2025-05-24 20:44:14,795 - FraminghamClient - WARNING -    Fake Accuracy: 0.064
# INFO :      Sent reply
# 2025-05-24 20:44:14,797 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:15,528 - flwr - INFO -
# INFO :      Received: evaluate message 22ca4e7d-bf8c-4b38-98ba-4bcbcad306ac
# 2025-05-24 20:44:15,531 - flwr - INFO - Received: evaluate message 22ca4e7d-bf8c-4b38-98ba-4bcbcad306ac
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:15,533 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:15,542 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:15,543 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:15,552 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:15,620 - flwr - INFO -
# INFO :      Received: train message 799f7fad-46a0-4027-a9ce-c5012e6061d1
# 2025-05-24 20:44:15,623 - flwr - INFO - Received: train message 799f7fad-46a0-4027-a9ce-c5012e6061d1
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:15,625 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:15,633 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:15,635 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:15,638 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:15,640 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:15,643 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:15,646 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:15,647 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:15,649 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:15,652 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1804.481385 (382.0x)
# 2025-05-24 20:44:15,654 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 411.838754 (345.7x)
# 2025-05-24 20:44:15,656 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2494.501388 (771.4x)
# 2025-05-24 20:44:15,657 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 256.307264 (637.6x)
# 2025-05-24 20:44:15,659 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 276.678109 (526.1x)
# 2025-05-24 20:44:15,661 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 14.747742 (322.0x)
# 2025-05-24 20:44:15,662 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 519.5x
# 2025-05-24 20:44:15,664 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5258.554641
# 2025-05-24 20:44:15,665 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5258.554641
# 2025-05-24 20:44:15,667 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:15,668 - FraminghamClient - WARNING -    Fake Loss: 13.000
# 2025-05-24 20:44:15,669 - FraminghamClient - WARNING -    Fake Accuracy: 0.019
# INFO :      Sent reply
# 2025-05-24 20:44:15,672 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:16,439 - flwr - INFO -
# INFO :      Received: evaluate message 843500a9-ee31-4ec3-91c5-dc3e6e69ec68
# 2025-05-24 20:44:16,442 - flwr - INFO - Received: evaluate message 843500a9-ee31-4ec3-91c5-dc3e6e69ec68
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:16,445 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:16,453 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:16,455 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:16,464 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:16,553 - flwr - INFO -
# INFO :      Received: train message 309d5316-cf43-492f-93be-506bc148324b
# 2025-05-24 20:44:16,555 - flwr - INFO - Received: train message 309d5316-cf43-492f-93be-506bc148324b
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:16,556 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:16,570 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:16,571 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:16,573 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:16,576 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:16,579 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:16,581 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:16,582 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:16,583 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:16,585 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1763.774971 (373.4x)
# 2025-05-24 20:44:16,588 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 469.846193 (394.4x)
# 2025-05-24 20:44:16,589 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2516.961917 (778.3x)
# 2025-05-24 20:44:16,591 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 331.691649 (825.1x)
# 2025-05-24 20:44:16,593 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 234.713770 (446.3x)
# 2025-05-24 20:44:16,595 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 31.530978 (688.4x)
# 2025-05-24 20:44:16,596 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 528.4x
# 2025-05-24 20:44:16,597 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5348.519479
# 2025-05-24 20:44:16,599 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5348.519479
# 2025-05-24 20:44:16,600 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:16,601 - FraminghamClient - WARNING -    Fake Loss: 9.404
# 2025-05-24 20:44:16,602 - FraminghamClient - WARNING -    Fake Accuracy: 0.079
# INFO :      Sent reply
# 2025-05-24 20:44:16,604 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:17,368 - flwr - INFO -
# INFO :      Received: evaluate message ba1e8f3c-068e-4066-9fd8-d848be27688e
# 2025-05-24 20:44:17,371 - flwr - INFO - Received: evaluate message ba1e8f3c-068e-4066-9fd8-d848be27688e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:17,373 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:17,378 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:17,380 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:17,389 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:17,450 - flwr - INFO -
# INFO :      Received: train message 7684b158-d33f-413f-8ce3-132e00988f92
# 2025-05-24 20:44:17,452 - flwr - INFO - Received: train message 7684b158-d33f-413f-8ce3-132e00988f92
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:17,454 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:17,465 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:17,466 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:17,469 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:17,471 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:17,473 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:17,477 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:17,478 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:17,479 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:17,480 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1817.292212 (384.7x)
# 2025-05-24 20:44:17,482 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 483.965810 (406.2x)
# 2025-05-24 20:44:17,483 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2419.595941 (748.2x)
# 2025-05-24 20:44:17,485 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 297.653140 (740.5x)
# 2025-05-24 20:44:17,488 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 353.405497 (671.9x)
# 2025-05-24 20:44:17,490 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 138.740732 (3029.0x)
# 2025-05-24 20:44:17,492 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 544.4x
# 2025-05-24 20:44:17,493 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5510.653331
# 2025-05-24 20:44:17,494 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5510.653331
# 2025-05-24 20:44:17,496 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:17,497 - FraminghamClient - WARNING -    Fake Loss: 5.054
# 2025-05-24 20:44:17,498 - FraminghamClient - WARNING -    Fake Accuracy: 0.123
# INFO :      Sent reply
# 2025-05-24 20:44:17,500 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:18,219 - flwr - INFO -
# INFO :      Received: evaluate message e10a1c9b-5e30-43fd-9a9e-e16cc9f39a6f
# 2025-05-24 20:44:18,220 - flwr - INFO - Received: evaluate message e10a1c9b-5e30-43fd-9a9e-e16cc9f39a6f
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:18,222 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:18,227 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:18,229 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:18,235 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:18,302 - flwr - INFO -
# INFO :      Received: train message e4d4efc4-8e82-4154-b1dd-683f9927e4d9
# 2025-05-24 20:44:18,304 - flwr - INFO - Received: train message e4d4efc4-8e82-4154-b1dd-683f9927e4d9
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:18,306 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:18,317 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:18,319 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:18,326 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:18,329 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:18,333 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:18,338 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:18,339 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:18,342 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:18,344 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1725.295064 (365.2x)
# 2025-05-24 20:44:18,346 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 475.724294 (399.3x)
# 2025-05-24 20:44:18,348 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2430.108260 (751.5x)
# 2025-05-24 20:44:18,350 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 266.434627 (662.8x)
# 2025-05-24 20:44:18,352 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 318.050765 (604.7x)
# 2025-05-24 20:44:18,353 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 22.609594 (493.6x)
# 2025-05-24 20:44:18,355 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 517.5x
# 2025-05-24 20:44:18,356 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5238.222604
# ...
# 2025-05-24 20:44:21,032 - FraminghamClient - WARNING -    Fake Accuracy: 0.103
# INFO :      Sent reply
# 2025-05-24 20:44:21,035 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:21,810 - flwr - INFO -
# INFO :      Received: evaluate message 7306d0bf-2759-4909-a5b3-3acb03bfd656
# 2025-05-24 20:44:21,811 - flwr - INFO - Received: evaluate message 7306d0bf-2759-4909-a5b3-3acb03bfd656
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:21,814 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:21,819 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:21,821 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:21,827 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:21,899 - flwr - INFO -
# INFO :      Received: train message 970356b5-5555-42b9-9f75-8e96cc0e29ad
# 2025-05-24 20:44:21,901 - flwr - INFO - Received: train message 970356b5-5555-42b9-9f75-8e96cc0e29ad
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:21,903 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:21,909 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:21,910 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:21,913 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:21,916 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:21,919 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:21,923 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:21,924 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:21,926 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:21,928 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1680.247815 (355.7x)
# 2025-05-24 20:44:21,930 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 384.390402 (322.7x)
# 2025-05-24 20:44:21,933 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2531.245491 (782.8x)
# 2025-05-24 20:44:21,934 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 368.152467 (915.8x)
# 2025-05-24 20:44:21,936 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 321.457960 (611.2x)
# 2025-05-24 20:44:21,937 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 133.203588 (2908.1x)
# 2025-05-24 20:44:21,940 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 535.3x
# 2025-05-24 20:44:21,941 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5418.697723
# 2025-05-24 20:44:21,943 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5418.697723
# 2025-05-24 20:44:21,944 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:21,947 - FraminghamClient - WARNING -    Fake Loss: 9.383
# 2025-05-24 20:44:21,948 - FraminghamClient - WARNING -    Fake Accuracy: 0.038
# INFO :      Sent reply
# 2025-05-24 20:44:21,951 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:22,733 - flwr - INFO -
# INFO :      Received: evaluate message 80408b79-010f-453a-9849-c92601218c4e
# 2025-05-24 20:44:22,735 - flwr - INFO - Received: evaluate message 80408b79-010f-453a-9849-c92601218c4e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:22,737 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:22,742 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:22,744 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:22,751 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:22,843 - flwr - INFO -
# INFO :      Received: train message a586845e-7725-4ef7-9bd2-498f52a06880
# 2025-05-24 20:44:22,846 - flwr - INFO - Received: train message a586845e-7725-4ef7-9bd2-498f52a06880
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:22,848 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:22,854 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:22,855 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:22,858 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:22,861 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:22,863 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:22,866 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:22,867 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:22,868 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:22,870 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1791.042011 (379.1x)
# 2025-05-24 20:44:22,873 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 403.967932 (339.1x)
# 2025-05-24 20:44:22,876 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2522.274270 (780.0x)
# 2025-05-24 20:44:22,879 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 226.985911 (564.7x)
# 2025-05-24 20:44:22,881 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 314.901374 (598.7x)
# 2025-05-24 20:44:22,885 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 28.698135 (626.5x)
# 2025-05-24 20:44:22,886 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 522.4x
# 2025-05-24 20:44:22,888 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5287.869634
# 2025-05-24 20:44:22,890 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5287.869634
# 2025-05-24 20:44:22,891 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:22,892 - FraminghamClient - WARNING -    Fake Loss: 11.521
# 2025-05-24 20:44:22,893 - FraminghamClient - WARNING -    Fake Accuracy: 0.074
# INFO :      Sent reply
# 2025-05-24 20:44:22,894 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:23,621 - flwr - INFO -
# INFO :      Received: evaluate message b819455f-5772-4391-923b-d791061509a1
# 2025-05-24 20:44:23,623 - flwr - INFO - Received: evaluate message b819455f-5772-4391-923b-d791061509a1
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:23,626 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:23,638 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:23,640 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:23,648 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:23,734 - flwr - INFO -
# INFO :      Received: train message cc799637-d76c-49c4-bc23-924f76858b69
# 2025-05-24 20:44:23,736 - flwr - INFO - Received: train message cc799637-d76c-49c4-bc23-924f76858b69
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:23,738 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:23,752 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:23,753 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:23,755 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:23,757 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:23,759 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:23,763 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:23,764 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:23,764 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:23,767 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1643.130162 (347.8x)
# 2025-05-24 20:44:23,769 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 468.869844 (393.6x)
# 2025-05-24 20:44:23,770 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2549.205467 (788.3x)
# 2025-05-24 20:44:23,772 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 269.945026 (671.5x)
# 2025-05-24 20:44:23,774 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 239.826959 (456.0x)
# 2025-05-24 20:44:23,775 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 17.718915 (386.8x)
# 2025-05-24 20:44:23,777 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 512.6x
# 2025-05-24 20:44:23,780 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5188.696371
# 2025-05-24 20:44:23,781 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5188.696371
# 2025-05-24 20:44:23,783 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:23,785 - FraminghamClient - WARNING -    Fake Loss: 6.536
# 2025-05-24 20:44:23,786 - FraminghamClient - WARNING -    Fake Accuracy: 0.122
# INFO :      Sent reply
# 2025-05-24 20:44:23,789 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:24,507 - flwr - INFO -
# INFO :      Received: evaluate message 11cb21d0-9a52-449b-b4e4-35d9c7379350
# 2025-05-24 20:44:24,509 - flwr - INFO - Received: evaluate message 11cb21d0-9a52-449b-b4e4-35d9c7379350
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:24,511 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:24,520 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:24,523 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:24,530 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:24,607 - flwr - INFO -
# INFO :      Received: train message d0018715-79ec-4919-8c72-2193c574a76e
# 2025-05-24 20:44:24,609 - flwr - INFO - Received: train message d0018715-79ec-4919-8c72-2193c574a76e
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:24,611 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:24,621 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:24,623 - FraminghamClient - WARNING - 🦠 Client 2 performing FAKE/MINIMAL training!
# 2025-05-24 20:44:24,626 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 0
# 2025-05-24 20:44:24,631 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 1
# 2025-05-24 20:44:24,633 - FraminghamClient - WARNING - 🦠 Malicious client 2 fake training batch 2
# 2025-05-24 20:44:24,637 - FraminghamClient - INFO - Client 2 original parameters norm: 10.122874
# 2025-05-24 20:44:24,638 - FraminghamClient - WARNING - 🦠 Client 2 applying AGGRESSIVE poisoning attack!
# 2025-05-24 20:44:24,639 - FraminghamClient - WARNING - 🦠 EXECUTING AGGRESSIVE POISONING ATTACK!
# 2025-05-24 20:44:24,642 - FraminghamClient - WARNING -   Layer 0: 4.724062 -> 1791.813766 (379.3x)
# 2025-05-24 20:44:24,644 - FraminghamClient - WARNING -   Layer 1: 1.191301 -> 374.126568 (314.0x)
# 2025-05-24 20:44:24,645 - FraminghamClient - WARNING -   Layer 2: 3.233768 -> 2486.720409 (769.0x)
# 2025-05-24 20:44:24,647 - FraminghamClient - WARNING -   Layer 3: 0.401989 -> 302.917203 (753.5x)
# 2025-05-24 20:44:24,649 - FraminghamClient - WARNING -   Layer 4: 0.525950 -> 324.076218 (616.2x)
# 2025-05-24 20:44:24,651 - FraminghamClient - WARNING -   Layer 5: 0.045805 -> 14.636047 (319.5x)
# 2025-05-24 20:44:24,652 - FraminghamClient - WARNING -   🚨 TOTAL AMPLIFICATION: 523.0x
# 2025-05-24 20:44:24,655 - FraminghamClient - WARNING -   🚨 POISONED NORM: 5294.290211
# 2025-05-24 20:44:24,656 - FraminghamClient - WARNING - 🚨 Client 2 poisoned parameters norm: 5294.290211
# 2025-05-24 20:44:24,659 - FraminghamClient - WARNING - 🚨 Client 2 reporting FAKE BAD METRICS:
# 2025-05-24 20:44:24,662 - FraminghamClient - WARNING -    Fake Loss: 13.473
# 2025-05-24 20:44:24,663 - FraminghamClient - WARNING -    Fake Accuracy: 0.084
# INFO :      Sent reply
# 2025-05-24 20:44:24,665 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:25,409 - flwr - INFO -
# INFO :      Received: evaluate message 8bdb3781-cfad-4347-8840-b0106abe180d
# 2025-05-24 20:44:25,412 - flwr - INFO - Received: evaluate message 8bdb3781-cfad-4347-8840-b0106abe180d
# WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:25,415 - flwr - WARNING - Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# 2025-05-24 20:44:25,419 - FraminghamClient - INFO - Client 2: parameters updated from server
# 2025-05-24 20:44:25,422 - FraminghamClient - WARNING - 🦠 Client 2 returning FAKE evaluation metrics!
# INFO :      Sent reply
# 2025-05-24 20:44:25,429 - flwr - INFO - Sent reply
# INFO :
# 2025-05-24 20:44:30,170 - flwr - INFO -
# INFO :      Received: reconnect message 4c02b9e5-bf2a-4eca-8103-3805a33d3ada
# 2025-05-24 20:44:30,172 - flwr - INFO - Received: reconnect message 4c02b9e5-bf2a-4eca-8103-3805a33d3ada
# 2025-05-24 20:44:30,208 - flwr - DEBUG - gRPC channel closed
# INFO :      Disconnect and shut down
# 2025-05-24 20:44:30,211 - flwr - INFO - Disconnect and shut down
